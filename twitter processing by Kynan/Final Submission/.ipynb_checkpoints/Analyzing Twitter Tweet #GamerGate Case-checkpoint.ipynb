# %% [markdown]
# # TATR: Using Content Analysis to Study Twitter Data
# ## Analyzing Twitter Tweet #GamerGate
#
# There are different methodologies and tactics to analyze Twitter tweets. From topic modeling to sentiment analysis. Therefore it is important for researcher to have the ability to manipulate tweets to suit their needed.
#
# This Juypter IPython Notebook uses #GamerGate Tweets as the example data for content analysis. It will cover aspects such as tokenization of text, extracting hashtags, graphing, providing content analysis categories similar to LIWC, etc.
#
# Note: The example data is already formatted into a CSV with all the information the IPython Notebook needs. These are the tweet text, time stamp of the tweet, and screen name.

# %% [markdown]
# # Import Libraries
#
# Before we begin we are going include all the needed requirements for the notebook. You do not need to know exactly all the functionality of the libraries, however any functionality used will be explained as they appear.
#
# Importing the required libraries for the projects. For installation instruction refer to the libraries / Jupyter home page.

# %%
# Importing more generic libraries
import glob
import os
import math
import csv
import ast
from collections import Counter

# Importing data structure libraries
import pandas as pd
import numpy as np

# Import graphing tools
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Ensure that any graphs produced appears in the notebook
# %matplotlib inline

# Import text analysist tools
import re
import nltk
from nltk.tokenize import RegexpTokenizer

# %% [markdown]
# # Gathering the Required Information From Original Tweet CSV
#
# The example CSV files contains a large amount of information about each tweet. From tweet texts to screen names. However we do not need all this information. For this notebook we are just going to need a few of these columns. Therefore we are going to selectively import only a select few.
#
# From there we are also going to do some additional formatting. The reason for this is to prepare the data for analysis later on. For example we do not need to know the exact second or hour of tweets. Therefore we can remove that extra information.
#
# ## Note:
# In this project I have chosen to extract all mentions and urls from the original text and replace them with "@MENTION" and "@LINK". To is done for a few reasons. Firstly it is so help with some later analysis. Second, it does not remove the original text, all it does it replace it with a placeholder in a new column. It will be discussed in the code on how to skip this process.
#
# Tweet text are also capitalized to make analysis easier.

# %% [markdown]
# # Helper Functions For Loading / Saving Files
#
# Before we do any work, it is important that we are able to save and load our work. This is because of the modularized nature of the notebook, that being to save and load files (especially when you analysis a large corpus) is vital.
#
# These are helper functions that help us load and save files. They each have their own use and applications. For more detail see their description in the code.
#
# Note: Some of the code references material that is not yet used or apparent early on.

# %%
# Loading multiple files in a path
# This is used when all the files that you want to load are all together in a folder
# Parameters:
# path           = Path to the folder
# colSelect      = Which columns in the CSV files would you like to load
# colNames       = The names of the columns that you have selected before
# need_convert   = Check to see if we need to convert list object
# column_convert = Which columns do you need to convert
def loading_multiple_file_path(path, colSelect, colNames, need_convert=None, column_convert=None):
    
    # Load all the files
    allFiles = glob.glob(path + "/*.csv")

    # Holds all the tweets
    dataframe = pd.DataFrame()

    # Holds the individual date tweets
    dataframe= []

    # Debugs to ensure the code is working
    print("Begin reading .csv in " + path + "....\n")
    
    # Check to see if some columns need to be converted back into a list object 
    if need_convert:
        
        # Create the function to convert to a list
        string_to_list = lambda x: ast.literal_eval(str(x))

        # Create the converter that will convert all the columns we tell it to back to a list object
        conv = {}
        for entry in column_convert:
            conv[entry] = string_to_list
        
        # Read every file
        for file_ in allFiles:

            # Debugs to ensure the code is working
            print("Reading and Converting file: " + str(file_) + "....")
            df = pd.read_csv(file_,  skiprows=1, usecols=colSelect, names=colNames)

            dataframe.append(df)
    else:
        # Read every file
        for file_ in allFiles:

            # Debugs to ensure the code is working
            print("Reading file: " + str(file_) + "....")
            df = read_frame
            df = pd.read_csv(file_,  skiprows=1, usecols=colSelect, names=colNames)

            dataframe.append(df)
    
    # Debugs to ensure the code is running
    print("\nFinished reading all files in " + path + "\n")
    
    print("Merge all individual file dataframes together into a single dataframe...\n")
    dataframe = pd.concat(dataframe)
    
    print("Finished merging all the files into a single dataframe.\n" )
    
    return dataframe

# Save the dataframe into a file
# Parameters:
# data_frame_name = Name of the dataframe to save
# name_of_file    = The name of the file you want to save it as
def save_frame(data_frame_name, name_of_file):
    
    print("Begin saving dataframe into a csv.\n")
    
    name = name_of_file + ".csv"
    # Save the dataframe
    data_frame_name.to_csv(name, sep=',', encoding='utf-8')
    
    print("Finish and saved into " + name + "\n")

# Loads the dataframe from a single file. By default it skips the 1st column (this is usually the index) 
# Parameters:
# csv_file_name   = Name of the file to load
# length          = The amount of columns to load (take the amount of columns + 1)
# custom          = If you want to load in a selective column amount turn true
# colList         = Which columns you want to load
# colNames        = The names of the columns that you want to load
def read_frame(csv_file_name, length=None, custom= False, colList = None, colNames = None):
    print("Reading csv " + csv_file_name)
    name = csv_file_name + ".csv"
    
    # Load csv by specifying which ones you want 
    if custom:
        return_frame = pd.read_csv(name,  usecols = colList)
    # Load csv by length skipping the first one (index)
    else: 
        return_frame = pd.read_csv(name,  usecols = range(1,length))
    print("Finish reading " + csv_file_name + "\n")
    return return_frame

# Similar to the one before except this converts the list present in the csv back into list objects to be used
# Parameters:
# csv_file_name   = Name of the file to load
# columnNames     = The names of the columns that you want to load
# length          = The amount of columns to load (take the amount of columns + 1)
# custom          = If you want to load in a selective column amount turn true
# colList         = Which columns you want to load
def read_frame_convert_list (csv_file_name, columnNames, length=None, custom= False, colList = None):
    
    # Create the function to convert to a list
    string_to_list = lambda x: ast.literal_eval(str(x))

    # Create the converter that will convert all the columns we tell it to back to a list object
    conv = {}
    
    # Assign the converter for each column to convert
    for entry in columnNames:
        conv[entry] = string_to_list
    
    print("Reading csv " + csv_file_name)
    name = csv_file_name + ".csv"

    # Load a specified amount of columns from the csv
    if custom:
        return_frame = pd.read_csv(name,  usecols = colList,  converters=conv)
    
    # Load the csv based on length
    else: 
        return_frame = pd.read_csv(name,  usecols = range(1,length),  converters=conv)
    print("Finish reading " + csv_file_name + "\n")
    
    return return_frame

# %% [markdown]
# # Defining Format Functions
#
# These functions below help with exacting and formatting different aspects of the tweets. This include extracting links, formatting dates, etc.
#
# ## Note:
# We save the extracted URLs and MENTIONs into their columns. Although when we save the data back into a csv it will not be a list object (it will appear as plain text). Therefore we are going to need to convert it back (hence the convert parameter in the previously made functions), and in order to do that we need to make sure that the values in these columns with list are in proper list format.

# %%
# Extract the links from a text
def extract_links(dataframe):
    
    # Regrex to extract all the links
    urls = re.findall(r"http\S+", dataframe['text'])
    
    # Replace the link with the placeholder @LINK
    dataframe['text'] = re.sub(r"http\S+", "@LINK", dataframe['text'])
    
    # Insert the URL into their own column
    if not urls:
        dataframe["URL"] = []
    else: 
        dataframe["URL"] = urls
    return dataframe
    
    
# Extract tweeter mentions in a text
def extract_mentions(dataframe):
    
    # Regrex to extract all the mentions
    mention = re.findall(r"@([A-Za-z0-9_]+)", dataframe['text'])
    
    # Replace the mention with the placeholder @MENTION
    dataframe['text'] = re.sub(r"@([A-Za-z0-9_]+)", "@MENTION", dataframe['text'])
    
    # Insert the mention into their own column
    if not mention:
        dataframe["MENTION"] = []
    else: 
        dataframe["MENTION"] = mention
    return dataframe

# Changes the date the declared format   
def format_date(dataframe, column_name, time_format):
    
    print("Start formatting date ")
    
    # Convert the time to date-time object
    dataframe[column_name] = pd.to_datetime(dataframe[column_name])
    
    # Convert the time to the desired format
    dataframe[column_name] = dataframe[column_name].apply(lambda x: x.strftime(time_format))  
    
    print("Finish formatting date \n") 
    
    return dataframe

# %% [markdown]
# # Setting up #GamerGate Tweets
#
# Now that we declared some helper functions we are going to load in the GamerGate tweets.
#
# From the example CSV, I will be using columns 1,2,4. These column contain the time_stamp of the tweet, text of the tweet, and screen name.
#
# ## Note:
# The analysis can take a very LONG time depending on the size of the dataset. Therefore upon finishing I saved them into a csv. This is to ensure I can load them in later and use them. If any lines regarding "saving" dataframe is commented out, it is because I have already calculated the results (just uncomment the code by removing the "//"). This also include other functions that run some form of algorithms/

# %%
# Start inital setup
MasterTweetFrame = loading_multiple_file_path("./Tweets", [1,2,4], ["time_stamp","text", "screen_name"])

print("Start extracting Mentions\n")

# Extract the mentions
MasterTweetFrame = MasterTweetFrame.apply(extract_mentions, axis=1)

print("End extracting Mentions\n")
print("Start extracting URL\n")

# Extract the URLS
MasterTweetFrame = MasterTweetFrame.apply(extract_links, axis=1)

print("End Extracting URL\n")

# Format the date to use have year, month, day
MasterTweetFrame = format_date(MasterTweetFrame, "time_stamp", "%Y-%m-%d")
# Out:
# Begin reading .csv in ./Tweets....
#
# Reading file: ./Tweets/datesorted-2016-08-04.csv....
# Reading file: ./Tweets/datesorted-2016-10-27.csv....
# Reading file: ./Tweets/datesorted-2016-09-15.csv....
# Reading file: ./Tweets/datesorted-2016-12-22.csv....
# Reading file: ./Tweets/datesorted-2016-12-08.csv....
# Reading file: ./Tweets/datesorted-2016-10-20.csv....
# Reading file: ./Tweets/datesorted-2016-12-01.csv....
# Reading file: ./Tweets/datesorted-2016-10-06.csv....
# Reading file: ./Tweets/datesorted-2016-08-18.csv....
# Reading file: ./Tweets/datesorted-2016-11-24.csv....
# Reading file: ./Tweets/datesorted-2016-11-17.csv....
# Reading file: ./Tweets/datesorted-2016-09-29.csv....
# Reading file: ./Tweets/datesorted-2016-12-15.csv....
# Reading file: ./Tweets/datesorted-2016-09-08.csv....
# Reading file: ./Tweets/datesorted-2016-11-10.csv....
# Reading file: ./Tweets/datesorted-2016-12-29-shortweek.csv....
# Reading file: ./Tweets/datesorted-2016-08-25.csv....
# Reading file: ./Tweets/datesorted-2016-09-01.csv....
# Reading file: ./Tweets/datesorted-2016-08-11.csv....
# Reading file: ./Tweets/datesorted-2016-11-03.csv....
# Reading file: ./Tweets/datesorted-2016-09-22.csv....
# Reading file: ./Tweets/datesorted-2016-10-13.csv....
#
# Finished reading all files in ./Tweets
#
# Merge all individual file dataframes together into a single dataframe...
#
# Finished merging all the files into a single dataframe.
#
# Start extracting Mentions
#
# End extracting Mentions
#
# Start extracting URL
#
# End Extracting URL
#
# Start formatting date
# Finish formatting date

# %%
# See first 5 entry of MasterTweetFrame
MasterTweetFrame[:5]
# Out:
#    time_stamp                                               text  \
# 0  2016-08-04  TOTALLY UNRELATED TO #GAMERGATE, THERE IS ONLY...
# 1  2016-08-04  Every morning at Konami, fuck you guys we let ...
# 2  2016-08-04          Come, come, come play the game #gamergate
# 3  2016-08-04  #GamerGate\nI told you these vidya gaem journo...
# 4  2016-08-04  @LINK #gamergate&gt;mobs r good if they serve ...
#
#        screen_name MENTION                                                URL
# 0  oh_my_gg_ebooks      []                                                 []
# 1          reribot      []                                                 []
# 2  gaming_for_kids      []                                                 []
# 3   Contragamer911      []                          [https://t.co/GzJpcimy7e]
# 4      Ash_Knight0      []  [https://t.co/ulfnGFAeFF, https://t.co/4GFXQr2...

# %% [markdown]
# # CheckPoint Save and Load (MasterTweetFrame)
#
# Now that we finished formatting MasterTweetFrame from the csv, we are going to save it and load it back (to prove that it saved correctly, feel free to start or stop at this point).
#
# ## Note:
# To verify the loaded dataframe is the same as the previous one, match the first 5 entries printed before the save with those after the load.

# %% [markdown]
# # Basic Characteristic of Tweets
#
# With a complete list of all the tweets formatted and saved into a dataframe (MasterTweetFrame), it is time to look at some characteristics of it.

# %%
# Find out how many unique exist in the dataset for each type
print("There are " + str(len(MasterTweetFrame.time_stamp)) + " tweets recorded in the dataset")
print("There are " + str(len(MasterTweetFrame.time_stamp.unique())) + " days recorded in the dataset")
print("There are " + str(len(MasterTweetFrame.screen_name.unique())) + " usernames in the dataset")
# Out:
# There are 90495 tweets recorded in the dataset
# There are 150 days recorded in the dataset
# There are 8859 usernames in the dataset

# %% [markdown]
# # Tweet Basic Statistic
#
# Now that we have a Master dataframe with the original formatted data. Now we are going to create a new dataframe to store some statistic about the MasterTweetFrame.
#
# ## Note:
# We are going use a feature called "groupby". This is a feature of dataframe that allow us to categorize a dataframe based on a column. In this example we are going to use it on "time_stamp".

# %%
# Create a new dataframe to hold the statistic and we are going to group them by day and count
TweetBasicStatistic = MasterTweetFrame.groupby("time_stamp").count()

# Rename the columns to reflect what we have done
TweetBasicStatistic.columns = ["text_count", "screen_name_count","URL_count","MENTION_count"]

# See how the first 5 entry in the dataframe look like
TweetBasicStatistic[:5]
# Out:
#             text_count  screen_name_count  URL_count  MENTION_count
# time_stamp
# 2016-08-04         516                516        516            516
# 2016-08-05         524                524        524            524
# 2016-08-06         452                452        452            452
# 2016-08-07         743                743        743            743
# 2016-08-08         628                628        628            628

# %% [markdown]
# # CheckPoint Save and Load (TweetBasicStatistic)
#
# We save and reload the dataframe to ensure the data is saved and we can reuse it.
#
# ## Note:
# This is slightly a bit different than the MasterTweetFrame. This is because "time_stamp" is an index not a column in this dataframe. Therefore before we save we are going to turn the index into a column. Afterwards when we load it back, we will return it back to being an index fort the dataframe. The reason for this is because the load function for the csvs skips the index when loading. (This can be changed by editing the load function. Afterwards make the appropriate changes to later code to address this change)

# %%
# Convert the time_stamp back into a column
TweetBasicStatistic = TweetBasicStatistic.reset_index()

# Save the dataframe
save_frame(TweetBasicStatistic, "TweetBasicStatistic")
    
# Load the dataframe from csv
TweetBasicStatistic = read_frame("TweetBasicStatistic", 6)

# Convert the column time_stamp back to an index
TweetBasicStatistic = TweetBasicStatistic.set_index("time_stamp")

# Check to see if the top 5 entry are correct
TweetBasicStatistic[:5]
# Out:
# Begin saving dataframe into a csv.
#
# Finish and saved into TweetBasicStatistic.csv
#
# Reading csv TweetBasicStatistic
# Finish reading TweetBasicStatistic
#             text_count  screen_name_count  URL_count  MENTION_count
# time_stamp
# 2016-08-04         516                516        516            516
# 2016-08-05         524                524        524            524
# 2016-08-06         452                452        452            452
# 2016-08-07         743                743        743            743
# 2016-08-08         628                628        628            628

# %% [markdown]
# # Graphing Functions
#
# Now that we have done some basic analysis of the tweet text. It is time to create some functions that help us graph the results. Here we declare 2 extra parameter to save the graph if needed. These do not have to be used. There will be example of both chooisng to save the graph created or not choosing to.
#
# ## Note:
# The titles are hard coded for the example dataset used. In order to change it simply change the line with "fig.suptitle" with a new title.

# %%
# Plot a column value over time 
# Parameters:
# column        = Columns to be used for the data
# date          = The index with the dates
# dataframe     = The dataframe of the data
# intervalValue = Set intervals for date, larger the number the bigger the interval between date stamp on graph
# saveImage     = True to save image, false to skip
# fileName      = Name of the save file
def basic_plot_generator(column, date, dataframe, intervalValue = 1, saveImage=False, fileName = None):
    # Plot how many tweets there are over the whole duration
    fig,ax = plt.subplots()

    # Set title for the graph
    fig.suptitle("GamerGate " + column + " Over Time", fontsize="x-large")

    # Create subplot of Tweet Count over time using a the default 1 month interval
    ax.plot(pd.to_datetime(date), dataframe[column], label=column)

    # Set the interval to be the default 1 month 
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=intervalValue))
    
    # Set the date format
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    fig.autofmt_xdate()
    
    # Calculate the average
    countMean = [dataframe[column].mean()]*len(pd.to_datetime(date))
    mean_line = ax.plot(pd.to_datetime(date),countMean, label='Average Overall Count', linestyle='--')

    # Create a legend for the subplot
    legend = ax.legend(loc='upper center', shadow=True)
    
    # Saving the Plot as an Image
    if saveImage:
        fig.savefig(fileName)
    
    # Show Plot
    plt.show()

# Plot different columns against eachother over time
# Parameters:
# column        = Columns to be used for the data
# date          = The index with the dates
# dataframe     = The dataframe of the data
# intervalValue = Set intervals for date, larger the number the bigger the interval between date stamp on graph
# saveImage     = True to save image, false to skip
# fileName      = Name of the save file
def plot_compare_generator(column, date, dataframe, intervalValue = 1, saveImage=False, fileName = None):
    
    # Plot how many tweets there are over the whole duration
    fig,ax = plt.subplots()

    # Generate Title
    title = "Comparing GamerGate Sentiements: "

    # Add all columns to the title
    for element in column:
        title = title + " " + element 
    
    title = title + " Over time"
    
    # Set title for the graph
    fig.suptitle(title, fontsize="x-large")
    
    for element in column:
        # Create subplot of Tweet Count over time using a 3 month interval
        ax.plot(pd.to_datetime(date), dataframe[element], label=element)
        
    # Set the interval to be default 1 month 
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=intervalValue))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    fig.autofmt_xdate()
    
    # Create a legend for the subplot
    legend = ax.legend(loc='upper center', shadow=True)
    
    # Saving the Plot as an Image
    if saveImage:
        fig.savefig(fileName)
    
    # Show Plot
    plt.show()

# %% [markdown]
# # Plotting TweetBasicStatistic
#
# Now that we declared some graphing functions it is time to use them.

# %%
# Plot each category as well as their corresponding averages
for columns in TweetBasicStatistic:
    # This is an example of not choosing to save the image
    basic_plot_generator(columns, TweetBasicStatistic.index, TweetBasicStatistic)

# %% [markdown]
# # Advance Analysis Helper Function
#
# In order to conduct different types of text analysis we are going break up the text into 'tokens'. This just refers to separate each word in a tweet. Therefore we are going to create a new dataframe that contained tokened sentences (separate via sentences) and words (separated by word) and their respective token count. This is done using nltk library.

# %%
# Calculate sentence length
def tokenize_text(dataframe):
    # Calculate number of sentences
    sentence = nltk.sent_tokenize(dataframe["text"]) 
    dataframe['sentence'] = sentence
    dataframe['num_sentence'] = len(sentence)
    
    # Calculate length of sentences
    sentence_length = []
    tokens = []
    for line in sentence:
        
        # Set tokenizer to reconize words + the shorthand @MENTION and @LINK
        tokenizer = RegexpTokenizer(r'\w+|@[A-Za-z0-9_-]*')
        words = tokenizer.tokenize(line)
        
        # Add the amount of tokens to the list 
        tokens = tokens + words
        sentence_length.append(len(words))

    # Calculate average sentence length
    dataframe['average_sentence_length'] = math.ceil(sum(sentence_length)/len(sentence_length))
        
    # Save Tokenized text
    dataframe['tokens'] = tokens
    
    # Save Token Count
    dataframe['count_tokens'] = len(tokens)
    
    return dataframe

# %% [markdown]
# # Advance Analysis Segmentation
#
# Given that some dataset can be very large and the amount of time it takes to run an algorthmn over such as large dataset. It is important to have the ability to break larger dataset into smaller chuncks. Although this does not neccessarily speed up the process, it allows us to insert debugs to track our progress. In addition, it also allows us to restart from a segement if there is a crash rather than restart from the beginning.
#
# At this time we are also going to save completed chunks into their own csv. This is to ensure our progress is not lost. We can load them all back in because we have a function that can read multiple files from a file that was created at the start of the notebook.
#
# ## Note:
# This function below allows the user to select which alogrithm to use. Therefore if there exist an algorithm that is not in this notebook, you can easily add it in. All that is needed is to add another condition in the for loop with a new algorithm and another number to represent it.
#
# Some of the algorithms will make more sense/explained later on in the notebook

# %%
# Section off the tweets into smaller chuncks and save it into csv
# Parameters:
# size            = The size of each segement of the data (if given the total size of the dataframe, it will be 1 file)
# Frame           = The dataframe to look at
# Filename        = The name of the csv (a numbering will be attached to the end of the name)
# algorithm       = The algorithm that is being chosen
# savedirectory   = The folder name to save the csv
def create_save_section(size, Frame, Filename, algorithm, savedirectory):
    
    # Create the file directory if it does not exist
    if not os.path.exists(savedirectory):
        os.makedirs(savedirectory)
    
    # Divide the dataframe into smaller chunk to work with
    # Set size of each chunk
    n = size

    #Create a list of the frame section
    FrameList = [Frame[i:i+n] for i in range(0,Frame.shape[0],n)]
    
    # Iterate through each section in the list
    for section in range(0,len(FrameList)):
        
        # Use the corresponding algorithm
        # if you want to add a new one this is where it is done
        if algorithm == 1:
            # Print debug and tokenize the text
            print("Looking at section: " + str(section+1))
            newFrame = FrameList[section].apply(tokenize_text, axis=1)
            print("Finish looking at section: " + str(section+1))
        
        if algorithm == 2:
            # Print debug and extract hashtag from dataframe
            print("Looking at section: " + str(section+1))
            newFrame = FrameList[section].apply(extract_hashtag, axis=1)
            print("Finish looking at section: " + str(section+1))
            
        if algorithm == 3:
            # Print debug and update the dictionary of categories
            print("Looking at section: " + str(section+1))
            newFrame = FrameList[section].apply(update_values_category, axis=1)
            print("Finish looking at section: " + str(section+1))
        
        # Create the name of the save location based on file and directory
        saveLocation = "./" + savedirectory + "/" + Filename 
        
        # Print debug and save the section into a csv
        print("Saving the section: " + str(section+1) + " into csv")
        newFrame.to_csv(saveLocation + "_" + str(section+1) + ".csv", sep=',', encoding='utf-8')
        print("Finish saving into " + saveLocation + "_" + str(section+1) + ".csv")
    
    print("Finised saving all the files into " + saveLocation)

# %% [markdown]
# # Generating Segmented Tokenized Tweets
#
# We now move onto the next segment of the notebook about how to tokenize tweets. In the section we are again going to create a new dataframe to hold all this information. To begin we will copy over some columns from MasterTweetFrame.
#
# Afterwards we will move onto tokenizing the tweets based on words and sentences. T Depending on the size of the dataset, the reason for support both methods is due to the fact that, depending on your needs, both aspect may be important. However depending on the amount of text in the corpus his may take a large amount of time. Therefore we will be conducting this tokenization in parts using the function "create_save_section" made eariler.
#
# ## Note:
# The helper function "create_save_section" does not return us a dataframe to use, it merely just saves it. Therefore we will need to load the files back in.

# %%
# Copy the columns we want into new dataframe
TokenTweetFrame = MasterTweetFrame[['time_stamp','text']].copy()

# Tokenize and Save the Tweets (each section has 10000 entries) 
# 1 refers to algorithm 1 in the create_save_frame (to tokenize text)
create_save_section(10000, TokenTweetFrame, "TokenTweet", 1, "Tweets_Tokenize")

# Loading the csvs into a dataframe
# Since all the csv are located in "Tweets_Tokenize we can just load from there
TokenTweetFrame = loading_multiple_file_path("./Tweets_Tokenize", [1,2,3,4,5,6,7], ["time_stamp","text","sentence","num_sentence","average_sentence_length","tokens","count_tokens"])
# Out:
# Looking at section: 1
# Finish looking at section: 1
# Saving the section: 1 into csv
# Finish saving into ./Tweets_Tokenize/TokenTweet_1.csv
# Looking at section: 2
# Finish looking at section: 2
# Saving the section: 2 into csv
# Finish saving into ./Tweets_Tokenize/TokenTweet_2.csv
# Looking at section: 3
# Finish looking at section: 3
# Saving the section: 3 into csv
# Finish saving into ./Tweets_Tokenize/TokenTweet_3.csv
# Looking at section: 4
# Finish looking at section: 4
# Saving the section: 4 into csv
# Finish saving into ./Tweets_Tokenize/TokenTweet_4.csv
# Looking at section: 5
# Finish looking at section: 5
# Saving the section: 5 into csv
# Finish saving into ./Tweets_Tokenize/TokenTweet_5.csv
# Looking at section: 6
# Finish looking at section: 6
# Saving the section: 6 into csv
# Finish saving into ./Tweets_Tokenize/TokenTweet_6.csv
# Looking at section: 7
# Finish looking at section: 7
# Saving the section: 7 into csv
# Finish saving into ./Tweets_Tokenize/TokenTweet_7.csv
# Looking at section: 8
# Finish looking at section: 8
# Saving the section: 8 into csv
# Finish saving into ./Tweets_Tokenize/TokenTweet_8.csv
# Looking at section: 9
# Finish looking at section: 9
# Saving the section: 9 into csv
# Finish saving into ./Tweets_Tokenize/TokenTweet_9.csv
# Looking at section: 10
# Finish looking at section: 10
# Saving the section: 10 into csv
# Finish saving into ./Tweets_Tokenize/TokenTweet_10.csv
# Finised saving all the files into ./Tweets_Tokenize/TokenTweet
# Begin reading .csv in ./Tweets_Tokenize....
#
# Reading file: ./Tweets_Tokenize/TokenTweet_5.csv....
# Reading file: ./Tweets_Tokenize/TokenTweet_3.csv....
# Reading file: ./Tweets_Tokenize/TokenTweet_8.csv....
# Reading file: ./Tweets_Tokenize/TokenTweet_6.csv....
# Reading file: ./Tweets_Tokenize/TokenTweet_1.csv....
# Reading file: ./Tweets_Tokenize/TokenTweet_4.csv....
# Reading file: ./Tweets_Tokenize/TokenTweet_7.csv....
# Reading file: ./Tweets_Tokenize/TokenTweet_10.csv....
# Reading file: ./Tweets_Tokenize/TokenTweet_9.csv....
# Reading file: ./Tweets_Tokenize/TokenTweet_2.csv....
#
# Finished reading all files in ./Tweets_Tokenize
#
# Merge all individual file dataframes together into a single dataframe...
#
# Finished merging all the files into a single dataframe.
#       time_stamp                                               text  \
# 0     2016-11-18  @LINK #GamerGate [SOCJUS] Sweden opens "manspl...
# 1     2016-11-18  Are games causing violence? Anyone who has wor...
# 2     2016-11-18           Whats old is new again. #GamerGate @LINK
# 3     2016-11-18  THE\nMAXIMUM\nTRUMP\n\n@LINK\n\n#gamergate #sa...
# 4     2016-11-18                               Your life #gamergate
# 5     2016-11-18  God of War: Ghost of Sparta encourages transge...
# 6     2016-11-18  @LINK #GamerGate Jordan Peterson and Dave Rubi...
# 7     2016-11-18  @MENTION If something isn't a thing, why do pe...
# 8     2016-11-18  I just had a burrito. It was all right. #Gamer...
# 9     2016-11-18  HAS #GAMERGATE EVER SPOKEN TO YOU: about sardi...
# 10    2016-11-18   @MENTION Or worked on a help desk.\n\n#gamergate
# 11    2016-11-18  @MENTION I happen to be trans and in full supp...
# 12    2016-11-18  @LINK #GamerGate [Drama] David Jaffe says Kyle...
# 13    2016-11-18                     all games is stinky #gamergate
# 14    2016-11-18  Mike helping Trump and #GamerGate to #DrainThe...
# 15    2016-11-18  #GamerGate Top story Trump’s victory, a surpri...
# 16    2016-11-18  For some reason, claims of harassment by #Game...
# 17    2016-11-18  Hey @MENTION @MENTION, did you know being pro ...
# 18    2016-11-18  @LINK #GamerGate Ethics rules bar Steve Bannon...
# 19    2016-11-18                                   #GamerGate @LINK
# 20    2016-11-18                  Don't play hard to get #gamergate
# 21    2016-11-18  "NO"\n\nIS A SHALLOW PART\nOF MY CUNT\n\n&gt;O...
# 22    2016-11-18  "We're not Jack Thompson." "Journalism has no ...
# 23    2016-11-18    Kirby's Dream Land encourages sodomy #gamergate
# 24    2016-11-18  Gonna do a lazy afternoon stream, pals. Let's ...
# 25    2016-11-18  Well, #GamerGate, looks like the old "games ca...
# 26    2016-11-18  @MENTION Lynch mobs, real or virtual, never ne...
# 27    2016-11-18  @LINK #GamerGate There's an undeniable paralle...
# 28    2016-11-18              all games should be banned #gamergate
# 29    2016-11-18  #gamergate @LINK this is a fantastic illustrat...
# ...          ...                                                ...
# 9970  2016-10-23  Light another cigarette and let yourself go #g...
# 9971  2016-10-23  I was groped in Virtual Reality in 2005. \nHe ...
# 9972  2016-10-23  @LINK #GamerGate The Untold Rise and Fall Stor...
# 9973  2016-10-23  @LINK #GamerGate [Humor] Driver viciously assa...
# 9974  2016-10-23                        @LINK via /r/KiA #gamergate
# 9975  2016-10-23                        @LINK via /r/KiA #gamergate
# 9976  2016-10-23  @LINK #GamerGate [SocJus] [Based Mom] Columbia...
# 9977  2016-10-23  This is your average KotakuInAction mod. #game...
# 9978  2016-10-23  The latest From Game to Tech Daily! @LINK Than...
# 9979  2016-10-23  I just had a pumpkin. It was wonderful! #Gamer...
# 9980  2016-10-23  Women are sexually assaulted in EVERY MULTIPLA...
# 9981  2016-10-23  @LINK #GamerGate [Humor] Male feminists be lik...
# 9982  2016-10-23  @LINK #GamerGate [Opinion] Mr Enter About the ...
# 9983  2016-10-23  Mailing goals\n@LINK\n&amp;\n@LINK\n\nOther\n@...
# 9984  2016-10-23  Just a friendly reminder that I spend most of ...
# 9985  2016-10-23                       It's a free world #gamergate
# 9986  2016-10-23  @MENTION \n\n1.Take a dump on your brand.\n2.L...
# 9987  2016-10-23   I just ate a pita. It was delectable. #GamergAte
# 9988  2016-10-23      all you have to do is fall in love #gamergate
# 9989  2016-10-23  o_o #gamergate keep being mention in my timeli...
# 9990  2016-10-23  @MENTION @MENTION #GamerGate\n#altRight\nPlay ...
# 9991  2016-10-23                                @MENTION #GamerGate
# 9992  2016-10-23                        @LINK via /r/KiA #gamergate
# 9993  2016-10-23  @MENTION you are the egg of the king Mike #ALt...
# 9994  2016-10-23  Looks like #4chan banning of #GamerGate was a ...
# 9995  2016-10-23  #GamerGate Top story Vivian Second year wallpa...
# 9996  2016-10-23                                   #GamerGate @LINK
# 9997  2016-10-23  it's 2016 and yet people are still pro- #gamer...
# 9998  2016-10-23       the game industry must be stopped #gamergate
# 9999  2016-10-23                          @MENTION #gamergate @LINK
#
#                                                sentence  num_sentence  \
# 0     ['@LINK #GamerGate [SOCJUS] Sweden opens "mans...             1
# 1     ['Are games causing violence?', 'Anyone who ha...             2
# 2       ['Whats old is new again.', '#GamerGate @LINK']             2
# 3     ['THE\nMAXIMUM\nTRUMP\n\n@LINK\n\n#gamergate #...             1
# 4                              ['Your life #gamergate']             1
# 5     ['God of War: Ghost of Sparta encourages trans...             1
# 6     ['@LINK #GamerGate Jordan Peterson and Dave Ru...             1
# 7     ['@MENTION If something isn\'t a thing, why do...             2
# 8     ['I just had a burrito.', 'It was all right.',...             3
# 9     ['HAS #GAMERGATE EVER SPOKEN TO YOU: about sar...             1
# 10    ['@MENTION Or worked on a help desk.', '#gamer...             2
# 11    ['@MENTION I happen to be trans and in full su...             2
# 12    ['@LINK #GamerGate [Drama] David Jaffe says Ky...             1
# 13                   ['all games is stinky #gamergate']             1
# 14    ['Mike helping Trump and #GamerGate to #DrainT...             1
# 15    ['#GamerGate Top story Trump’s victory, a surp...             2
# 16    ['For some reason, claims of harassment by #Ga...             1
# 17    ['Hey @MENTION @MENTION, did you know being pr...             2
# 18    ['@LINK #GamerGate Ethics rules bar Steve Bann...             1
# 19                                 ['#GamerGate @LINK']             1
# 20                ["Don't play hard to get #gamergate"]             1
# 21    ['"NO"\n\nIS A SHALLOW PART\nOF MY CUNT\n\n&gt...             1
# 22    ['"We\'re not Jack Thompson."', '"Journalism h...             4
# 23    ["Kirby's Dream Land encourages sodomy #gamerg...             1
# 24    ['Gonna do a lazy afternoon stream, pals.', "L...             3
# 25    ['Well, #GamerGate, looks like the old "games ...             2
# 26    ['@MENTION Lynch mobs, real or virtual, never ...             2
# 27    ["@LINK #GamerGate There's an undeniable paral...             1
# 28            ['all games should be banned #gamergate']             1
# 29    ['#gamergate @LINK this is a fantastic illustr...             1
# ...                                                 ...           ...
# 9970  ['Light another cigarette and let yourself go ...             1
# 9971  ['I was groped in Virtual Reality in 2005.', '...             2
# 9972  ['@LINK #GamerGate The Untold Rise and Fall St...             1
# 9973  ['@LINK #GamerGate [Humor] Driver viciously as...             1
# 9974                    ['@LINK via /r/KiA #gamergate']             1
# 9975                    ['@LINK via /r/KiA #gamergate']             1
# 9976  ['@LINK #GamerGate [SocJus] [Based Mom] Columb...             2
# 9977  ['This is your average KotakuInAction mod.', '...             2
# 9978  ['The latest From Game to Tech Daily!', '@LINK...             2
# 9979  ['I just had a pumpkin.', 'It was wonderful!',...             3
# 9980  ['Women are sexually assaulted in EVERY MULTIP...             1
# 9981  ['@LINK #GamerGate [Humor] Male feminists be l...             1
# 9982  ['@LINK #GamerGate [Opinion] Mr Enter About th...             1
# 9983  ['Mailing goals\n@LINK\n&amp;\n@LINK\n\nOther\...             1
# 9984  ['Just a friendly reminder that I spend most o...             2
# 9985                   ["It's a free world #gamergate"]             1
# 9986  ['@MENTION \n\n1.Take a dump on your brand.', ...             4
# 9987  ['I just ate a pita.', 'It was delectable.', '...             3
# 9988  ['all you have to do is fall in love #gamergate']             1
# 9989  ['o_o #gamergate keep being mention in my time...             2
# 9990  ['@MENTION @MENTION #GamerGate\n#altRight\nPla...             1
# 9991                            ['@MENTION #GamerGate']             1
# 9992                    ['@LINK via /r/KiA #gamergate']             1
# 9993  ['@MENTION you are the egg of the king Mike #A...             1
# 9994  ['Looks like #4chan banning of #GamerGate was ...             2
# 9995  ['#GamerGate Top story Vivian Second year wall...             1
# 9996                               ['#GamerGate @LINK']             1
# 9997  ["it's 2016 and yet people are still pro- #gam...             1
# 9998   ['the game industry must be stopped #gamergate']             1
# 9999                      ['@MENTION #gamergate @LINK']             1
#
#       average_sentence_length  \
# 0                           7
# 1                          11
# 2                           4
# 3                          11
# 4                           3
# 5                           9
# 6                          16
# 7                          12
# 8                           4
# 9                           9
# 10                          4
# 11                         13
# 12                         20
# 13                          5
# 14                          8
# 15                          9
# 16                         20
# 17                          9
# 18                         11
# 19                          2
# 20                          7
# 21                         17
# 22                          4
# 23                          7
# 24                          5
# 25                         10
# 26                          9
# 27                         17
# 28                          6
# 29                         14
# ...                       ...
# 9970                        8
# 9971                        8
# 9972                       18
# 9973                        8
# 9974                        5
# 9975                        5
# 9976                        8
# 9977                        5
# 9978                        7
# 9979                        3
# 9980                       12
# 9981                        7
# 9982                       15
# 9983                       10
# 9984                       10
# 9985                        6
# 9986                        6
# 9987                        3
# 9988                       10
# 9989                        8
# 9990                        9
# 9991                        2
# 9992                        5
# 9993                       13
# 9994                        9
# 9995                       15
# 9996                        2
# 9997                       10
# 9998                        7
# 9999                        3
#
#                                                  tokens  count_tokens
# 0     ['@LINK', 'GamerGate', 'SOCJUS', 'Sweden', 'op...             7
# 1     ['Are', 'games', 'causing', 'violence', 'Anyon...            21
# 2     ['Whats', 'old', 'is', 'new', 'again', 'GamerG...             7
# 3     ['THE', 'MAXIMUM', 'TRUMP', '@LINK', 'gamergat...            11
# 4                         ['Your', 'life', 'gamergate']             3
# 5     ['God', 'of', 'War', 'Ghost', 'of', 'Sparta', ...             9
# 6     ['@LINK', 'GamerGate', 'Jordan', 'Peterson', '...            16
# 7     ['@MENTION', 'If', 'something', 'isn', 't', 'a...            23
# 8     ['I', 'just', 'had', 'a', 'burrito', 'It', 'wa...            10
# 9     ['HAS', 'GAMERGATE', 'EVER', 'SPOKEN', 'TO', '...             9
# 10    ['@MENTION', 'Or', 'worked', 'on', 'a', 'help'...             8
# 11    ['@MENTION', 'I', 'happen', 'to', 'be', 'trans...            25
# 12    ['@LINK', 'GamerGate', 'Drama', 'David', 'Jaff...            20
# 13        ['all', 'games', 'is', 'stinky', 'gamergate']             5
# 14    ['Mike', 'helping', 'Trump', 'and', 'GamerGate...             8
# 15    ['GamerGate', 'Top', 'story', 'Trump', 's', 'v...            17
# 16    ['For', 'some', 'reason', 'claims', 'of', 'har...            20
# 17    ['Hey', '@MENTION', '@MENTION', 'did', 'you', ...            17
# 18    ['@LINK', 'GamerGate', 'Ethics', 'rules', 'bar...            11
# 19                               ['GamerGate', '@LINK']             2
# 20    ['Don', 't', 'play', 'hard', 'to', 'get', 'gam...             7
# 21    ['NO', 'IS', 'A', 'SHALLOW', 'PART', 'OF', 'MY...            17
# 22    ['We', 're', 'not', 'Jack', 'Thompson', 'Journ...            16
# 23    ['Kirby', 's', 'Dream', 'Land', 'encourages', ...             7
# 24    ['Gonna', 'do', 'a', 'lazy', 'afternoon', 'str...            14
# 25    ['Well', 'GamerGate', 'looks', 'like', 'the', ...            20
# 26    ['@MENTION', 'Lynch', 'mobs', 'real', 'or', 'v...            17
# 27    ['@LINK', 'GamerGate', 'There', 's', 'an', 'un...            17
# 28    ['all', 'games', 'should', 'be', 'banned', 'ga...             6
# 29    ['gamergate', '@LINK', 'this', 'is', 'a', 'fan...            14
# ...                                                 ...           ...
# 9970  ['Light', 'another', 'cigarette', 'and', 'let'...             8
# 9971  ['I', 'was', 'groped', 'in', 'Virtual', 'Reali...            15
# 9972  ['@LINK', 'GamerGate', 'The', 'Untold', 'Rise'...            18
# 9973  ['@LINK', 'GamerGate', 'Humor', 'Driver', 'vic...             8
# 9974          ['@LINK', 'via', 'r', 'KiA', 'gamergate']             5
# 9975          ['@LINK', 'via', 'r', 'KiA', 'gamergate']             5
# 9976  ['@LINK', 'GamerGate', 'SocJus', 'Based', 'Mom...            16
# 9977  ['This', 'is', 'your', 'average', 'KotakuInAct...             9
# 9978  ['The', 'latest', 'From', 'Game', 'to', 'Tech'...            13
# 9979  ['I', 'just', 'had', 'a', 'pumpkin', 'It', 'wa...             9
# 9980  ['Women', 'are', 'sexually', 'assaulted', 'in'...            12
# 9981  ['@LINK', 'GamerGate', 'Humor', 'Male', 'femin...             7
# 9982  ['@LINK', 'GamerGate', 'Opinion', 'Mr', 'Enter...            15
# 9983  ['Mailing', 'goals', '@LINK', 'amp', '@LINK', ...            10
# 9984  ['Just', 'a', 'friendly', 'reminder', 'that', ...            20
# 9985     ['It', 's', 'a', 'free', 'world', 'gamergate']             6
# 9986  ['@MENTION', '1', 'Take', 'a', 'dump', 'on', '...            23
# 9987  ['I', 'just', 'ate', 'a', 'pita', 'It', 'was',...             9
# 9988  ['all', 'you', 'have', 'to', 'do', 'is', 'fall...            10
# 9989  ['o_o', 'gamergate', 'keep', 'being', 'mention...            15
# 9990  ['@MENTION', '@MENTION', 'GamerGate', 'altRigh...             9
# 9991                          ['@MENTION', 'GamerGate']             2
# 9992          ['@LINK', 'via', 'r', 'KiA', 'gamergate']             5
# 9993  ['@MENTION', 'you', 'are', 'the', 'egg', 'of',...            13
# 9994  ['Looks', 'like', '4chan', 'banning', 'of', 'G...            18
# 9995  ['GamerGate', 'Top', 'story', 'Vivian', 'Secon...            15
# 9996                             ['GamerGate', '@LINK']             2
# 9997  ['it', 's', '2016', 'and', 'yet', 'people', 'a...            10
# 9998  ['the', 'game', 'industry', 'must', 'be', 'sto...             7
# 9999                 ['@MENTION', 'gamergate', '@LINK']             3
#
# [90495 rows x 7 columns]

# %% [markdown]
# # Examining TokenTweetsFrame
#
# Now that we have the TokenTweets dataframe loaded back into the dataframe. We will a look at the dataframe itself as well as some properties of it.

# %%
# Look at the first 5 entries of TokenTweet
TokenTweetFrame[:5]
# Out:
#    time_stamp                                               text  \
# 0  2016-11-18  @LINK #GamerGate [SOCJUS] Sweden opens "manspl...
# 1  2016-11-18  Are games causing violence? Anyone who has wor...
# 2  2016-11-18           Whats old is new again. #GamerGate @LINK
# 3  2016-11-18  THE\nMAXIMUM\nTRUMP\n\n@LINK\n\n#gamergate #sa...
# 4  2016-11-18                               Your life #gamergate
#
#                                             sentence  num_sentence  \
# 0  ['@LINK #GamerGate [SOCJUS] Sweden opens "mans...             1
# 1  ['Are games causing violence?', 'Anyone who ha...             2
# 2    ['Whats old is new again.', '#GamerGate @LINK']             2
# 3  ['THE\nMAXIMUM\nTRUMP\n\n@LINK\n\n#gamergate #...             1
# 4                           ['Your life #gamergate']             1
#
#    average_sentence_length                                             tokens  \
# 0                        7  ['@LINK', 'GamerGate', 'SOCJUS', 'Sweden', 'op...
# 1                       11  ['Are', 'games', 'causing', 'violence', 'Anyon...
# 2                        4  ['Whats', 'old', 'is', 'new', 'again', 'GamerG...
# 3                       11  ['THE', 'MAXIMUM', 'TRUMP', '@LINK', 'gamergat...
# 4                        3                      ['Your', 'life', 'gamergate']
#
#    count_tokens
# 0             7
# 1            21
# 2             7
# 3            11
# 4             3

# %%
# Find out how many unique exist in the dataset
print("There is an average of " + str(TokenTweetFrame["num_sentence"].mean()) + " sentences in the dataset")
print("The overall average sentence length per tweet is " + str(TokenTweetFrame["average_sentence_length"].mean()))
# Out:
# There is an average of 1.5850378473948836 sentences in the dataset
# The overall average sentence length per tweet is 9.847560638709322

# %% [markdown]
# # Calculating Overall Averages
#
# Although we have number of sentences and average sentence length for each tweet, we might want the average of these statistic for each day. Therefore we are going to create a new dataframe with these values to use. We will also include in this new dataframe the number of words in the tweets

# %%
# Convert the column time_stamp back to an index
TokenTweetFrame = TokenTweetFrame.set_index("time_stamp")

# Resort the index (This is because we read from Mulitple Files)
TokenTweetFrame.sort_index(inplace=True)

# Calculate average on num_sentence, averaege_sentence_length and group by time_stamp
TokenGraphFrame = TokenTweetFrame[['num_sentence','average_sentence_length','count_tokens']].copy()

# Calculate average per day and save them into their own dataframe for graphing
TokenGraphFrame = TokenGraphFrame[['num_sentence','average_sentence_length','count_tokens']].groupby(["time_stamp"]).mean()

# See what the first 5 entry look likes of token graph
TokenGraphFrame[:5]

# %% [markdown]
# # Graphing TokenTweetFrame
#
# Now we are going to graph both the number of tweets and the average sentence length over time. Before we can accomplish this we need to set the time_stamp column back to being an index.

# %%
# Using the graph function we made we will plot these averages
for columns in TokenGraphFrame[["num_sentence", "average_sentence_length","count_tokens"]]:
    basic_plot_generator(columns, TokenGraphFrame.index, TokenGraphFrame)

# %% [markdown]
# # CheckPoint Save and Load (TokenGraphFrame)
#
# Now that we calculated some basic stylistic on the tweets we are going to save the work we have done into a csv.
#
# ## Note:
# The reason for not having a checkpoint for the previous dataframe (TokenTweetFrame) is because the information is already saved into a csv upon creation. Therefore all the data can just be loaded back in and therefore the need for a singular file to hold the information of the multiple files created is just extra redundancy. If you do wish to save it into a singular file, use the "save_frame" function and give it "TokenTweetFrame"

# %%
# Convert the time_stamp into a column
TokenGraphFrame = TokenGraphFrame.reset_index()

# Save the dataframe
save_frame(TokenGraphFrame, "TokenGraphFrame")
    
# Load the dataframe from csv
TokenGraphFrame = read_frame("TokenGraphFrame", 5)

# Convert the column time_stamp back to an index
TokenGraphFrame = TokenGraphFrame.set_index("time_stamp")
# Out:
# Begin saving dataframe into a csv.
#
# Finish and saved into TokenGraphFrame.csv
#
# Reading csv TokenGraphFrame
# Finish reading TokenGraphFrame

# %% [markdown]
# # Examining HASHTAGS
#
# We will now move onto examining HASHTAGS. Before we can begin we are going to define a function that helps us extract hashtags from the tokenized text.
#
# ## Note:
# In this notebook we are removing the "#gamergate" from analysis. This is because all tweets gathered had this hashtag, therefore we want to know all the other hashtags used and how many there were of them. This includes removing duplicates of the "gamegate" hashtag. If you would rather keep it in or chose to remove your own chosen hashtag it can be done here.
#
# In addition it is important to recall that all hashtags are stored in capital letters

# %%
# Extract out the hashtags and count how many there are
def extract_hashtag(dataframe):
    
    # Finds all the hashtags with regrex and capitalize them with ".upper()"
    hashtag = re.findall(r"#(\w+)", dataframe["text"].upper())

    # Remove all instances GAMERGATE hashtag (since all tweets has it) This includes duplicates
    # If you would like to keep them comment out the while loop
    # If you would like to remove a different hashtag you can copy the following two lines and change the word
    # Remember all tokens are capitalized
    while "GAMERGATE" in hashtag:
        hashtag.remove("GAMERGATE")

    # Insert hashtag and count into dataframe
    if hashtag:
        dataframe['HASHTAG'] = hashtag
        dataframe['count_hashtag'] = len(hashtag)
    else:
        dataframe['HASHTAG'] = []
        dataframe['count_hashtag'] = 0
        
    return dataframe

# %% [markdown]
# # Extracting Hashtag and Gathering Statistics
#
# Before we begin we are yet again going to copy over parts of MasterTweetFrame into a new dataframe. Afterwards we will extract the hashtag from it, however depending on the dataset this may take a while. Therefore it is safer to do the calculation in parts (again we will use create_save_section to do so).
#
# ## Note:
# All hashtags are recorded in capitals. This is to simplify some aspects for analysis later on when we examine the occurance of each hashtag.

# %%
# Create new dataframe with information we need from MasterTweetFrame
HashtagStatisticFrame = MasterTweetFrame[['time_stamp','text']].copy()

# Create sections using the extract hashtag
create_save_section(10000,HashtagStatisticFrame , "HashtagStatistic", 2, "Hashtag_Stat")

# Load back the csv (Note the files are saved in a folder)
HashtagStatisticFrame = loading_multiple_file_path("./Hashtag_Stat", [1,2,3,4], ["time_stamp","text","HASHTAG","count_hashtag"])

# Convert the column time_stamp to an index
HashtagStatisticFrame = HashtagStatisticFrame.set_index("time_stamp")
# Out:
# Looking at section: 1
# Finish looking at section: 1
# Saving the section: 1 into csv
# Finish saving into ./Hashtag_Stat/HashtagStatistic_1.csv
# Looking at section: 2
# Finish looking at section: 2
# Saving the section: 2 into csv
# Finish saving into ./Hashtag_Stat/HashtagStatistic_2.csv
# Looking at section: 3
# Finish looking at section: 3
# Saving the section: 3 into csv
# Finish saving into ./Hashtag_Stat/HashtagStatistic_3.csv
# Looking at section: 4
# Finish looking at section: 4
# Saving the section: 4 into csv
# Finish saving into ./Hashtag_Stat/HashtagStatistic_4.csv
# Looking at section: 5
# Finish looking at section: 5
# Saving the section: 5 into csv
# Finish saving into ./Hashtag_Stat/HashtagStatistic_5.csv
# Looking at section: 6
# Finish looking at section: 6
# Saving the section: 6 into csv
# Finish saving into ./Hashtag_Stat/HashtagStatistic_6.csv
# Looking at section: 7
# Finish looking at section: 7
# Saving the section: 7 into csv
# Finish saving into ./Hashtag_Stat/HashtagStatistic_7.csv
# Looking at section: 8
# Finish looking at section: 8
# Saving the section: 8 into csv
# Finish saving into ./Hashtag_Stat/HashtagStatistic_8.csv
# Looking at section: 9
# Finish looking at section: 9
# Saving the section: 9 into csv
# Finish saving into ./Hashtag_Stat/HashtagStatistic_9.csv
# Looking at section: 10
# Finish looking at section: 10
# Saving the section: 10 into csv
# Finish saving into ./Hashtag_Stat/HashtagStatistic_10.csv
# Finised saving all the files into ./Hashtag_Stat/HashtagStatistic
# Begin reading .csv in ./Hashtag_Stat....
#
# Reading file: ./Hashtag_Stat/HashtagStatistic_6.csv....
# Reading file: ./Hashtag_Stat/HashtagStatistic_1.csv....
# Reading file: ./Hashtag_Stat/HashtagStatistic_7.csv....
# Reading file: ./Hashtag_Stat/HashtagStatistic_9.csv....
# Reading file: ./Hashtag_Stat/HashtagStatistic_4.csv....
# Reading file: ./Hashtag_Stat/HashtagStatistic_8.csv....
# Reading file: ./Hashtag_Stat/HashtagStatistic_3.csv....
# Reading file: ./Hashtag_Stat/HashtagStatistic_5.csv....
# Reading file: ./Hashtag_Stat/HashtagStatistic_2.csv....
# Reading file: ./Hashtag_Stat/HashtagStatistic_10.csv....
#
# Finished reading all files in ./Hashtag_Stat
#
# Merge all individual file dataframes together into a single dataframe...
#
# Finished merging all the files into a single dataframe.

# %% [markdown]
# # Plotting Hashtag Graph
#
# Simialr to before, we are going to graph some results.

# %%
# Using the graph function we made we will plot these averages
HashtagGraphFrame = HashtagStatisticFrame.groupby(["time_stamp"]).mean()

for columns in HashtagGraphFrame[["count_hashtag"]]:
    basic_plot_generator(columns, HashtagGraphFrame.index, HashtagGraphFrame, intervalValue=3)

# %% [markdown]
# # Popular Hashtag
#
# We now are going to move onto examining popular hashtags. To do so we fight are going to define a simple function that can get us the occurance of a particular hashtag.

# %%
# Helper function that calculates what hashtag appear the most
def get_max_word(dataframe):
    
    # Calculates what is most popular
    popular = max(set(dataframe["HASHTAG"]), key=dataframe["HASHTAG"].count)
    
    # Assigns the values
    dataframe["most_popular"] = popular
    
    return dataframe

# %% [markdown]
# # Most Popular Hashtag
#
# Now that we have the hashtags in a dataframe, let's create a dateframe that looks into how popular a particular hashtag is. This is done by first collapsing the dates together and combining the hashtag list. Afterwards count how many of each hashtag are there. However getting the occurrence of a hashtag for each tweet does not provide a lot of useful information, therefore we will collapse the tweets by date and get the most popular ones by date
#
# ## Note:
#
# It is important to know that during this process we save and load back the dataframe after we made a copy of it. The reason for this is because HashtagStatisticFrame column "HASHTAG" are stored in a "string" that so happens to look like a python "list". Therefore we need the dataframe to re-evaluate this column to be a "list" and not a "string". One method to do so is to use the functioned created called "read_frame_convert_list" which would 1. reads the file (which the data of HashtagStatisticFrame is stored as) and 2. read the "HASHTAG" column as a "list".

# %%
# Create a new dataframe with just HASHTAG and count
HashtagPopularFrame = HashtagStatisticFrame[["HASHTAG","count_hashtag"]].copy()

# Unset time_stamp to save
HashtagPopularFrame = HashtagPopularFrame.reset_index()

# Save Frame
save_frame(HashtagPopularFrame, "HashtagPopularFrame")

# Load back the Frame except run it under the covnerter to get a list not object
HashtagPopularFrame = read_frame_convert_list("HashtagPopularFrame", ["HASHTAG"], length = 4)

# Reset index back to date
HashtagPopularFrame = HashtagPopularFrame.set_index("time_stamp")

# Collapsing the dataframe Hashtags and Count
HashtagPopularFrame = HashtagPopularFrame[["HASHTAG","count_hashtag"]].groupby('time_stamp').agg({'HASHTAG': 'sum', 'count_hashtag': 'sum'})

# See what the first 5 results looks like
HashtagPopularFrame[:5]
# Out:
# Begin saving dataframe into a csv.
#
# Finish and saved into HashtagPopularFrame.csv
#
# Reading csv HashtagPopularFrame
# Finish reading HashtagPopularFrame
#                                                       HASHTAG  count_hashtag
# time_stamp
# 2016-08-04  [GG16, FEMINISMISCANCER, OPSKYNET, AUGLIVESMAT...            180
# 2016-08-05  [AMERICA, IMWITHHER, TRUMPPENCE16, DONALDTRUMP...            151
# 2016-08-06  [JAYZ, FEMINISTS, FEMINIST, INFOWARS, 4CHAN, A...            200
# 2016-08-07  [ONMYTWITTERRESUME, MEGALIA4, KILLSTREAM, SJW,...            283
# 2016-08-08  [BLM, FEMINISM, BIBLE, KINGDAVID, JOAB, TRUMP2...            186

# %% [markdown]
# # Finding the Most Popular Hashtag
#
# Before we look into the most popular Hashtag we can collapse all the HASHTAGS in one date together and get the count. Then afterwards find the most popular hashtag in each date and see how it does over the whole period.

# %%
# Now lets save the top most popular word by day into their own column
HashtagPopularFrame = HashtagPopularFrame.apply(lambda x: get_max_word(x), axis = 1)

# Print out the first 5 entry
HashtagPopularFrame[:5]
# Out:
#                                                       HASHTAG  count_hashtag  \
# time_stamp
# 2016-08-04  [GG16, FEMINISMISCANCER, OPSKYNET, AUGLIVESMAT...            180
# 2016-08-05  [AMERICA, IMWITHHER, TRUMPPENCE16, DONALDTRUMP...            151
# 2016-08-06  [JAYZ, FEMINISTS, FEMINIST, INFOWARS, 4CHAN, A...            200
# 2016-08-07  [ONMYTWITTERRESUME, MEGALIA4, KILLSTREAM, SJW,...            283
# 2016-08-08  [BLM, FEMINISM, BIBLE, KINGDAVID, JOAB, TRUMP2...            186
#
#              most_popular
# time_stamp
# 2016-08-04       OPSKYNET
# 2016-08-05  NOTYOURSHIELD
# 2016-08-06         GAMING
# 2016-08-07       FREEMILO
# 2016-08-08       OPSKYNET

# %% [markdown]
# # CheckPoint Save and Load (HashtagPopularFrame)
#
# This is just to save the work currently done into its own file.
#
# ## Note:
# Another reason for creating a save point here is because in the next section we will looking at occurance of hashtags. This involves editing this dataframe, therefore having a "blank" dataframe to be reused is useful.

# %%
# Reset Index
HashtagPopularFrame = HashtagPopularFrame.reset_index()

# Save Frame
save_frame(HashtagPopularFrame, "HashtagPopularFrame")

# Load back the Frame except run it under the covnerter to get a list not object
HashtagPopularFrame = read_frame_convert_list("HashtagPopularFrame", ["HASHTAG"], length = 5)

# Set Index
HashtagPopularFrame = HashtagPopularFrame.set_index("time_stamp")

# %% [markdown]
# # Occurance of Hashtag
#
# Using the information gathered from HashtagPopularFrame we can see that "NOTYOURSHIELD" seems to be a popular hashtag. Therefore lets see how popular it was over time, this is done by counting its occurance over time. Therefore we are going to need a function that will help us accomplish this.

# %%
# Counts the occurance of a word
def countOccurance(dateframe, word):
    # Count the amount of hashtag in the list
    count = Counter(dateframe["HASHTAG"])
    title = "count_" + word
    dateframe[title] = count[word]
    return dateframe

# %% [markdown]
# # Calculating Occurance of "NOTYOURSHIELD"
#
# To do this we will apply the previously created function to the dataframe looking for "NOTYOURSHIELD". Therefore if we want to see other hashtags over time we can just run the algorthmn agian with a different hashtag.

# %%
# Acquire count of "NOTYOURSHIELD"
HashtagPopularFrame = HashtagPopularFrame.apply(lambda x: countOccurance(x, "NOTYOURSHIELD"), axis = 1)

# Show the first 5
HashtagPopularFrame[:5]
# Out:
#                                                       HASHTAG  count_hashtag  \
# time_stamp
# 2016-08-04  [GG16, FEMINISMISCANCER, OPSKYNET, AUGLIVESMAT...            180
# 2016-08-05  [AMERICA, IMWITHHER, TRUMPPENCE16, DONALDTRUMP...            151
# 2016-08-06  [JAYZ, FEMINISTS, FEMINIST, INFOWARS, 4CHAN, A...            200
# 2016-08-07  [ONMYTWITTERRESUME, MEGALIA4, KILLSTREAM, SJW,...            283
# 2016-08-08  [BLM, FEMINISM, BIBLE, KINGDAVID, JOAB, TRUMP2...            186
#
#              most_popular  count_NOTYOURSHIELD
# time_stamp
# 2016-08-04       OPSKYNET                    8
# 2016-08-05  NOTYOURSHIELD                    9
# 2016-08-06         GAMING                    4
# 2016-08-07       FREEMILO                    7
# 2016-08-08       OPSKYNET                    5

# %% [markdown]
# # Graphing the HASHTAG
#
# Now that we had occurance of "NOTYOURSHIELD" we are going to graph it over time.

# %%
# Using the graph function we made we will plot these averages
for columns in HashtagPopularFrame[["count_NOTYOURSHIELD"]]:
    # Example of saving the file
    basic_plot_generator(columns, HashtagPopularFrame.index, HashtagPopularFrame, saveImage=True, fileName="count_NOTYOURSHIELD")

# %% [markdown]
# # Content Analysis
#
# We have looked at both hashtags, word count, and other factors. Now we are going to look at content analysis. In this notebook the following code mimics the functionalities of LIWC (Lingustic Inquiry Word Count). This type of analysis pairs words with different categories (Postive, Negative, etc) and counts how many time a text fits into them.
#
# This requires a dictionary of words and categories. These can be found here
# http://www.wjh.harvard.edu/~inquirer/spreadsheet_guide.htm
#
# With the dictionary and the token count (or word count) we can divide the number found in a particular category and the total token count of the tweet to get a percentage.
#
# ## Note:
# I collapsed some of the aspects of the spreadsheet. This is because in the original there are multiple definition of a word. I have choosen to treat the all instances of the same word as the same and fused together their related categories.
#
# Therefore I have only kept the categories and nothing else in this notebook.

# %% [markdown]
# # Loading the Words and Categories
#
# First we are going to load the csv files (provided at the site above) and convert it to a dictionary. This allows us to do a much faster search on the list to fill a dataframe later on.

# %%
# The csv name of the inquirer dictionary
csvFile = "inquirerbasic.csv"

# Create a list of rows to hold the values
listOfRows = []

# Reading the csv 
with open(csvFile, 'r') as file: # This makes sure that file is closed after reading
    data = csv.reader(file)
    
    # For every row in the fie save it
    for row in data:
        listOfRows.append(row)

# Close the file
file.closed

# Format the category
categories = listOfRows[0]

# We do not need the first 2 category (they have the word, and the source of it)
# The last two columns are description of the words in question. We also do not need that
# Note the csv also as additional 4 empty columns at the end (that is why we have -6)
categories = categories[2:len(categories)-6]

# Check on how many categories
print("Length of category " + str(len(categories)))

# Print out the first 5 categories
print(categories[:5])
# Out:
# Length of category 182
# ['Positiv', 'Negativ', 'Pstv', 'Affil', 'Ngtv']

# %% [markdown]
# # Helper Functions
#
# Before we can simulate LIWC, we are going to need to define helper functions that deals with column managements, keeping track of counts, and so forth.

# %%
# Set all the categories of a word into a set if that word did not exist already
def new_attribute_set(row):
    # The reason for a set because it is faster to laod
    attributeSet = set()
    
    # If you belong to a category add it into the set
    for element in row:
        if element != "":
            attributeSet.add(element)
    return attributeSet;

# Combine with pre-existing set with any new additions
def combine_attribute_set(row, oldset):
    # The reason for a set because it is faster to laod
    newSet = set()
    
    # If you belong to a category add it into the set
    for element in row:
        if element != "":
            newSet.add(element)
    
    # Return a new updated set without duplicates
    return (oldset | newSet)

# Assign every word with the categories (in a set)
def get_dictionary_list(listOfRows,categories):
    returnDict = {}

    # For every row create the set of categories that belong to it
    for row in listOfRows:
        
        # Reduce the word to the base. This is because the csv has LOVE#1, LOVE#2 to symbolize different meanings
        # In this anaylsis we can going to collapse them together
        word = row[0].split("#", 1)[0]
    
        # Check to see if the word is in the dictionary already
        if word in returnDict:
            returnDict[word] = combine_attribute_set(row[2:len(categories)-2], returnDict[word])
        else:
            returnDict[word] = new_attribute_set(row[2:len(categories)-2])
        
    return returnDict

# Creates the columns we need and fills them with how many of each categories the text belongs to
def update_values_category(dataframe):
    # Finds and counts all the categories it belongs to
    resultDictionary = find_category(dataframe["tokens"])
    # Iterate through the results
    for k, v in resultDictionary.items():
        # Create columns for every category
        dataframe[k] = v
    return dataframe

# Looks through the tokens and increments the appropriate categories that it belongs to
def find_category(tokens):
    # Set all categories to 0 as default
    tweetCategories = {el:0 for el in categories}
    # Iterate through all tokens
    for element in tokens:
        # If it exist increment the value
        if element.upper() in dictWords:
            inside = dictWords[element.upper()]
    
            # Increment the category
            for element in inside:
                tweetCategories[element] += 1
    
    return tweetCategories

# %% [markdown]
# # Creating the Catgories Dataframe
#
# Now that we have the categories we can now move onto creating a new dataframe that has all these categories listed. To do so we will be copying over a few columns from TokenTweetFrame (we do not need all of it).
#
# Important note. When you are loading the csv into a panda it does not load the exact object type back. For example we saved 'tokens' as a list. However when we load it back it is not in that exact type. Therefore one method to do this is when we read the csv we run a converter. This would transform it back into the object type we want. It is also sometimes faster to save the frame and reload it with the converter when we need it (no point in converting it if we are not going to use it).

# %%
# Copy the 3 columns we need
# Note since TokenTweetFrame had "time_stamp" as an index we are going to need to reset it before
# we can copy it over
CategoryTweetFrame = TokenTweetFrame.reset_index()[['time_stamp','tokens','count_tokens']].copy()

# Saving the file away
save_frame(CategoryTweetFrame, "CategoryTweetFrame")

# Read the csv using the made function that deals with converting and covert "tokens" column
CategoryTweetFrame = read_frame_convert_list("CategoryTweetFrame", ['tokens'], length=4)

# Set index 
CategoryTweetFrame = CategoryTweetFrame.set_index("time_stamp")

# See first 5 entries
CategoryTweetFrame[:5]
# Out:
# Begin saving dataframe into a csv.
#
# Finish and saved into CategoryTweetFrame.csv
#
# Reading csv CategoryTweetFrame
# Finish reading CategoryTweetFrame
#                                                        tokens  count_tokens
# time_stamp
# 2016-08-04  [GamerGate, didn, t, help, my, career, at, all...            24
# 2016-08-04                        [egalitarianism, gamergate]             2
# 2016-08-04  [@LINK, GamerGate, Gaming, Polygon, doesn, t, ...            12
# 2016-08-04  [@LINK, GamerGate, Discussion, Are, the, old, ...            21
# 2016-08-04  [LIVE, NOW, Doxing, What, is, Public, Vs, Priv...            19

# %% [markdown]
# # Creating the Dictionary of Categories
#
# Now we are going to need to create the dictionary for the categories.

# %%
# Create dictionary of words which category they belong to
dictWords = get_dictionary_list(listOfRows[1:], categories)

# Have a look at the dictionary
dictWords
# Out:
# {'ABIDE': {'Active', 'Affil', 'Doctrin', 'IAV', 'Positiv'},
#  'ABILITY': {'ABS', 'Abs@', 'EVAL', 'MeansLw', 'Positiv', 'Strong', 'Virtue'},
#  'ABLE': {'EVAL', 'MeansLw', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'ABOUND': {'IAV', 'Increas', 'Passive', 'Positiv'},
#  'ABSOLVE': {'Active', 'ComForm', 'IAV', 'Positiv', 'SocRel'},
#  'ABSORBENT': {'Increas', 'IndAdj', 'Positiv'},
#  'ABSORPTION': {'Affil', 'Increas', 'Positiv'},
#  'ABUNDANCE': {'ECON',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Quan',
#   'Strong',
#   'WltOth',
#   'WltTot'},
#  'ABUNDANT': {'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Quan',
#   'Strong',
#   'WltOth',
#   'WltTot'},
#  'ACCEDE': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot'},
#  'ACCENTUATE': {'Active', 'IAV', 'Ovrst', 'Positiv'},
#  'ACCEPT': {'IAV', 'Passive', 'PosAff', 'Positiv', 'Pstv', 'SocRel', 'Submit'},
#  'ACCEPTABLE': {'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'ACCEPTANCE': {'Affil', 'Passive', 'PosAff', 'Positiv', 'Pstv', 'SocRel'},
#  'ACCESSIBLE': {'IPadj', 'Positiv', 'Virtue'},
#  'ACCESSION': {'Increas', 'Positiv', 'Strong'},
#  'ACCLAIM': {'ComForm', 'Positiv', 'Virtue'},
#  'ACCLAMATION': {'ComForm', 'Positiv', 'Virtue'},
#  'ACCOLADE': {'ComForm', 'Positiv', 'Virtue'},
#  'ACCOMMODATE': {'Active',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Vary'},
#  'ACCOMMODATION': {'PLACE', 'Positiv', 'PowCoop', 'PowTot', 'Virtue'},
#  'ACCOMPANIMENT': {'Positiv', 'SocRel'},
#  'ACCOMPLISH': {'Active',
#   'Complet',
#   'EndsLw',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'ACCOMPLISHMENT': {'Active',
#   'EndsLw',
#   'Goal',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'ACCORD': {'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Means',
#   'PosAff',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'TrnGain'},
#  'ACCORDANCE': {'Know', 'Positiv', 'PowCoop', 'PowTot', 'Pstv'},
#  'ACCOUNTABLE': {'Causal', 'IndAdj', 'Positiv'},
#  'ACCRUE': {'Active', 'DAV', 'ECON', 'Econ@', 'Increas', 'Positiv'},
#  'ACCURACY': {'ABS',
#   'Abs@',
#   'EnlOth',
#   'EnlTot',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Virtue'},
#  'ACCURATE': {'EnlOth', 'EnlTot', 'Ovrst', 'Positiv', 'Pstv', 'Virtue'},
#  'ACCURATENESS': {'Ovrst', 'Positiv', 'Virtue'},
#  'ACHIEVE': {'Active',
#   'Complet',
#   'EndsLw',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Strong'},
#  'ACHIEVEMENT': {'Active', 'EndsLw', 'Goal', 'Positiv', 'Power', 'Pstv'},
#  'ACKNOWLEDGEMENT': {'ComForm', 'Ovrst', 'Positiv'},
#  'ACQUAINT': {'EnlGain', 'EnlTot', 'IAV', 'Positiv', 'Pstv', 'Solve'},
#  'ACQUAINTANCE': {'AffOth',
#   'AffTot',
#   'Affil',
#   'HU',
#   'Positiv',
#   'Pstv',
#   'Role'},
#  'ACQUIT': {'DAV', 'Legal', 'Positiv', 'Solve'},
#  'ACQUITTAL': {'Legal', 'Positiv', 'Solve'},
#  'ACTUAL': {'Ovrst', 'Positiv', 'Pstv', 'SureLw', 'Virtue'},
#  'ACTUALITY': {'Doctrin', 'Positiv', 'Pstv', 'SureLw', 'Virtue'},
#  'ADAMANT': {'Arousal', 'IndAdj', 'Know', 'Positiv', 'Strong'},
#  'ADAPTABILITY': {'Positiv', 'Strong', 'Vary', 'Virtue'},
#  'ADAPTABLE': {'IndAdj', 'Positiv', 'Strong', 'Vary', 'Virtue'},
#  'ADAPTATION': {'Positiv', 'Strong', 'Vary', 'Virtue'},
#  'ADAPTIVE': {'IndAdj', 'Positiv', 'Strong', 'Vary', 'Virtue'},
#  'ADEPT': {'EVAL', 'Positiv', 'Pstv', 'SklOth', 'SklToT', 'Strong', 'Virtue'},
#  'ADEPTNESS': {'Positiv', 'Strong', 'Virtue'},
#  'ADEQUATE': {'EVAL', 'EndsLw', 'Positiv', 'Pstv', 'Undrst', 'Virtue'},
#  'ADHERENCE': {'Affil', 'Positiv', 'RcEthic', 'RcTot'},
#  'ADHERENT': {'Affil', 'IndAdj', 'Positiv'},
#  'ADHESION': {'Positiv', 'Rel'},
#  'ADHESIVE': {'IndAdj', 'Positiv', 'Rel'},
#  'ADJUNCT': {'Increas', 'Positiv', 'Rel'},
#  'ADJUST': {'IAV',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Submit',
#   'TrnGain',
#   'Virtue',
#   'WlbPsyc',
#   'WlbTot',
#   'Work'},
#  'ADJUSTABLE': {'IndAdj', 'Positiv', 'Vary'},
#  'ADJUSTMENT': {'Passive', 'Positiv', 'Pstv', 'Virtue'},
#  'ADMIRABLE': {'Eval@', 'IPadj', 'Positiv', 'RcTot', 'RspOth', 'Virtue'},
#  'ADMIRATION': {'EMOT',
#   'Pleasur',
#   'Positiv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'ADMIRE': {'Affil',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot',
#   'SV',
#   'Submit'},
#  'ADMIRER': {'EMOT', 'HU', 'Positiv', 'Strong'},
#  'ADMIT': {'ComForm',
#   'DAV',
#   'IAV',
#   'Ovrst',
#   'Passive',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'RspLoss',
#   'RspTot',
#   'SocRel',
#   'Submit',
#   'Weak'},
#  'ADMITTANCE': {'Active', 'Positiv', 'Travel'},
#  'ADORABLE': {'Eval@', 'IndAdj', 'Positiv', 'Virtue'},
#  'ADORE': {'Active', 'EMOT', 'Pleasur', 'Positiv', 'SV'},
#  'ADORN': {'Active', 'Eval@', 'IAV', 'Positiv', 'Strong'},
#  'ADORNMENT': {'Eval@', 'Positiv', 'Virtue'},
#  'ADROIT': {'IndAdj', 'Positiv', 'Strong', 'Virtue'},
#  'ADROITLY': {'Positiv', 'Strong', 'Virtue'},
#  'ADULATION': {'ComForm', 'EMOT', 'Eval@', 'Pleasur', 'Positiv', 'Strong'},
#  'ADULT': {'HU',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'Strong',
#   'Virtue',
#   'WlbPt',
#   'WlbTot'},
#  'ADVANCE': {'Active',
#   'EndsLw',
#   'IAV',
#   'Means',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Time@',
#   'Travel',
#   'Virtue'},
#  'ADVANCEMENT': {'EndsLw', 'Increas', 'Positiv', 'Pstv'},
#  'ADVANTAGE': {'ABS',
#   'Abs@',
#   'ECON',
#   'MeansLw',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'ADVANTAGEOUS': {'MeansLw', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'ADVENT': {'Begin', 'Positiv'},
#  'ADVENTURESOME': {'Active', 'IndAdj', 'Positiv', 'Strong'},
#  'ADVENTUROUS': {'Active', 'IndAdj', 'PosAff', 'Positiv', 'Strong'},
#  'ADVISABLE': {'Eval@', 'IPadj', 'Know', 'PosAff', 'Positiv', 'Quality'},
#  'ADVOCACY': {'Affil', 'ComForm', 'Positiv'},
#  'AFFABILITY': {'Positiv', 'Virtue'},
#  'AFFABLE': {'IPadj', 'Positiv', 'Virtue'},
#  'AFFECTION': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'EMOT',
#   'Positiv',
#   'Pstv'},
#  'AFFECTIONATE': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'EMOT',
#   'Positiv',
#   'Pstv'},
#  'AFFILIATE': {'Active', 'Affil', 'IAV', 'Positiv', 'PowCoop', 'PowTot'},
#  'AFFILIATION': {'Affil', 'Positiv'},
#  'AFFINITY': {'Positiv', 'Strong', 'Virtue'},
#  'AFFIRM': {'ComForm', 'IAV', 'Positiv', 'Power', 'Pstv', 'Strong', 'TrnGain'},
#  'AFFIRMATION': {'ComForm', 'Eval@', 'Positiv'},
#  'AFFIRMATIVE': {'Positiv'},
#  'AFFIX': {'Active', 'Affil', 'DAV', 'Exert', 'Positiv'},
#  'AFFLUENCE': {'Econ@', 'Positiv', 'Quality', 'WltOth', 'WltTot'},
#  'AFFLUENT': {'Econ@', 'IndAdj', 'Positiv', 'Quality'},
#  'AFLOAT': {'Econ@', 'IndAdj', 'Positiv', 'Strong'},
#  'AGGREGATE': {'Positiv', 'Quan'},
#  'AGGREGATION': {'Positiv', 'Quan'},
#  'AGILE': {'IndAdj', 'Positiv', 'Strong', 'Virtue'},
#  'AGILITY': {'Positiv', 'Strong', 'Virtue'},
#  'AGREEABLE': {'ComForm', 'EVAL', 'Positiv', 'PowCoop', 'PowTot', 'Pstv'},
#  'AGREEMENT': {'Affil',
#   'COM',
#   'ComForm',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Strong'},
#  'AID': {'Active',
#   'Affil',
#   'IAV',
#   'MeansLw',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'Virtue'},
#  'ALERTNESS': {'Positiv', 'Think', 'Virtue'},
#  'ALIGHT': {'IndAdj', 'Ovrst', 'Positiv', 'Virtue'},
#  'ALIVE': {'Active',
#   'NatrPro',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'WlbPhys',
#   'WlbTot'},
#  'ALLEGIANCE': {'AffOth', 'AffTot', 'Affil', 'Positiv', 'Virtue'},
#  'ALLEVIATE': {'Active',
#   'Affil',
#   'Decreas',
#   'Exert',
#   'IAV',
#   'Positiv',
#   'TrnGain'},
#  'ALLIANCE': {'COLL',
#   'HU',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'ALLIED': {'Affil',
#   'IAV',
#   'Polit@',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong'},
#  'ALLIES': {'Affil', 'HU', 'Positiv', 'Role', 'SocRel'},
#  'ALLOW': {'IAV',
#   'Passive',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Solve',
#   'TranLw'},
#  'ALLOWABLE': {'Eval@', 'IPadj', 'Positiv', 'Quality'},
#  'ALLOWANCE': {'Econ@', 'Positiv', 'Quan', 'WltOth', 'WltTot'},
#  'ALLURE': {'Positiv', 'Virtue'},
#  'ALLY': {'Affil',
#   'HU',
#   'IAV',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Role',
#   'SocRel',
#   'Strong'},
#  'ALMIGHTY': {'EMOT',
#   'IndAdj',
#   'Positiv',
#   'Power',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'ALTRUISTIC': {'Affil', 'Fetch', 'IPadj', 'Positiv', 'Virtue'},
#  'AMAZEMENT': {'Positiv', 'Power', 'Strong'},
#  'AMAZING': {'IndAdj', 'Ovrst', 'Positiv', 'Power', 'Strong'},
#  'AMELIORATE': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'TrnGain'},
#  'AMENABLE': {'Affil', 'IndAdj', 'Positiv', 'Vary', 'Virtue'},
#  'AMENITY': {'Object', 'Positiv'},
#  'AMIABILITY': {'Affil', 'Positiv', 'Virtue'},
#  'AMIABLE': {'Affil', 'IPadj', 'Positiv', 'Virtue'},
#  'AMICABLE': {'AffOth', 'AffTot', 'Affil', 'IPadj', 'Positiv', 'Virtue'},
#  'AMNESTY': {'Doctrin', 'Legal', 'Positiv', 'Power'},
#  'AMOUR': {'EMOT', 'Pleasur', 'Positiv'},
#  'AMPLE': {'EndsLw', 'Positiv', 'Pstv', 'Quan', 'Strong'},
#  'AMPLIFY': {'Active', 'DAV', 'Increas', 'Positiv', 'Strong'},
#  'AMPLY': {'Increas', 'Positiv', 'Strong'},
#  'AMUSE': {'Active', 'EMOT', 'IAV', 'Pleasur', 'Positiv', 'WlbGain', 'WlbTot'},
#  'AMUSEMENT': {'Pleasur', 'Positiv', 'WlbPsyc', 'WlbTot'},
#  'ANGEL': {'Affil', 'HU', 'Positiv', 'Relig', 'Role', 'Virtue'},
#  'ANGELIC': {'Affil', 'IndAdj', 'Positiv', 'Relig', 'Virtue'},
#  'ANOINT': {'Active', 'Affil', 'DAV', 'Exert', 'Positiv'},
#  'APOCALYPSE': {'Perceiv', 'Pleasur', 'Positiv', 'Think'},
#  'APPEAL': {'Affil',
#   'COM',
#   'ComForm',
#   'EndsLw',
#   'IAV',
#   'Legal',
#   'Passive',
#   'Pleasur',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Submit'},
#  'APPEASE': {'Active', 'IAV', 'Positiv', 'PowGain', 'PowTot', 'Submit'},
#  'APPEND': {'Active', 'DAV', 'Increas', 'Positiv'},
#  'APPLAUD': {'Active', 'ComForm', 'DAV', 'Eval@', 'Positiv'},
#  'APPLAUSE': {'COM', 'ComForm', 'Positiv', 'Pstv', 'RspOth', 'RspTot'},
#  'APPOINT': {'Active',
#   'DAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel'},
#  'APPRECIABLE': {'Ovrst', 'Perceiv', 'Positiv', 'Pstv', 'Strong'},
#  'APPRECIATE': {'Affil',
#   'Arousal',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot',
#   'SV',
#   'Submit'},
#  'APPRECIATION': {'Affil',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot'},
#  'APPRECIATIVE': {'Eval@', 'IPadj', 'Pleasur', 'Positiv', 'SocRel'},
#  'APPREHEND': {'Active', 'DAV', 'Fetch', 'Positiv'},
#  'APPROACH': {'Active',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Means',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Travel'},
#  'APPROPRIATE': {'IAV',
#   'Ovrst',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'SocRel',
#   'Strong',
#   'Virtue',
#   'WltTot',
#   'WltTran'},
#  'APPROVAL': {'Affil',
#   'COM',
#   'ComForm',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot'},
#  'APPROVE': {'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'APT': {'Ovrst', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'APTITUDE': {'Positiv', 'Strong', 'Virtue'},
#  'ARBITER': {'Affil', 'ComForm', 'HU', 'Positiv', 'Role', 'SocRel', 'Solve'},
#  'ARBITRATE': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'SocRel',
#   'Solve'},
#  'ARBITRATION': {'Affil',
#   'ComForm',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'SocRel',
#   'Solve'},
#  'ARDENT': {'Affil', 'IndAdj', 'PosAff', 'Positiv', 'Power', 'Strong'},
#  'ARISEN': {'Begin', 'Increas', 'IndAdj', 'Positiv'},
#  'ARISTOCRACY': {'Econ@', 'HU', 'Positiv', 'Power', 'Role'},
#  'ARISTOCRAT': {'Econ@', 'HU', 'Positiv', 'Power', 'Role'},
#  'ARISTOCRATIC': {'Econ@', 'IndAdj', 'Positiv', 'Power'},
#  'ARREST': {'Active',
#   'DAV',
#   'EVAL',
#   'Exert',
#   'Hostile',
#   'Legal',
#   'Negativ',
#   'Ngtv',
#   'Ovrst',
#   'Positiv',
#   'PowLoss',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Stay',
#   'Strong',
#   'Virtue'},
#  'ART': {'Academ',
#   'COM',
#   'ComnObj',
#   'Doctrin',
#   'EnlOth',
#   'EnlTot',
#   'Exprsv',
#   'Object',
#   'Positiv',
#   'Pstv',
#   'SV',
#   'SklAsth',
#   'SklOth',
#   'SklToT'},
#  'ASCRIBE': {'Active',
#   'Affil',
#   'Doctrin',
#   'EnlGain',
#   'EnlTot',
#   'IAV',
#   'Positiv'},
#  'ASPIRATION': {'Goal', 'Positiv', 'Think'},
#  'ASPIRE': {'Active', 'EndsLw', 'Goal', 'Positiv', 'SV', 'Try'},
#  'ASSENT': {'Affil', 'ComForm', 'Positiv', 'PowOth', 'PowTot'},
#  'ASSERTION': {'Arousal', 'ComForm', 'Know', 'Positiv', 'Strong'},
#  'ASSET': {'Affil', 'MeansLw', 'Positiv', 'Strong'},
#  'ASSIST': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'Virtue'},
#  'ASSISTANCE': {'Active',
#   'Affil',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'ASSISTANT': {'Active', 'HU', 'Positiv', 'Pstv', 'Role', 'Submit'},
#  'ASSOCIATE': {'Active',
#   'AffGain',
#   'AffTot',
#   'ECON',
#   'Econ@',
#   'EnlOth',
#   'EnlTot',
#   'HU',
#   'IAV',
#   'Passive',
#   'Positiv',
#   'PowPt',
#   'PowTot',
#   'Pstv',
#   'Rel',
#   'Role',
#   'Solve'},
#  'ASSOCIATION': {'Active',
#   'Affil',
#   'COLL',
#   'EnlOth',
#   'EnlTot',
#   'HU',
#   'Know',
#   'Positiv',
#   'PowPt',
#   'PowTot',
#   'Pstv',
#   'Strong'},
#  'ASSURANCE': {'Affil',
#   'COM',
#   'ComForm',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'TrnGain'},
#  'ASSURE': {'ComForm',
#   'Complet',
#   'EMOT',
#   'IAV',
#   'Ovrst',
#   'Pleasur',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong',
#   'SureLw',
#   'TrnGain'},
#  'ASSUREDLY': {'Ovrst', 'Positiv', 'Power', 'Pstv', 'Strong', 'SureLw'},
#  'ASTOUND': {'Active', 'Ovrst', 'Positiv', 'Power', 'SV', 'Strong'},
#  'ASTUTE': {'IndAdj', 'Know', 'Positiv', 'Virtue'},
#  'ATHLETIC': {'Exprsv', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'ATTACHMENT': {'Affil', 'EMOT', 'Pleasur', 'PosAff', 'Positiv', 'SocRel'},
#  'ATTAIN': {'Active', 'Complet', 'EndsLw', 'IAV', 'Positiv', 'Pstv', 'Strong'},
#  'ATTAINMENT': {'Active', 'Complet', 'EndsLw', 'Positiv', 'Pstv', 'Strong'},
#  'ATTEND': {'Active',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Submit',
#   'Travel',
#   'WlbGain',
#   'WlbTot',
#   'Work'},
#  'ATTENDANCE': {'Active', 'Positiv', 'Stay'},
#  'ATTENTIVE': {'Passive', 'Perceiv', 'Positiv', 'Pstv', 'Submit'},
#  'ATTRACT': {'Affil', 'IAV', 'Positiv', 'Pstv', 'SocRel', 'Strong'},
#  'ATTRACTION': {'Affil', 'Pleasur', 'Positiv', 'Pstv', 'Strong'},
#  'ATTRACTIVE': {'EVAL', 'EndsLw', 'Positiv', 'Pstv', 'Virtue'},
#  'ATTRACTIVENESS': {'Eval@', 'Positiv', 'Quality'},
#  'ATTUNE': {'IndAdj', 'Positiv', 'Solve', 'Think'},
#  'AUDIBLE': {'ComForm', 'IndAdj', 'Positiv', 'Strong'},
#  'AUGMENT': {'Active', 'IAV', 'Increas', 'Positiv', 'Pstv', 'TrnGain'},
#  'AUGMENTATION': {'Increas', 'Positiv'},
#  'AUSPICIOUS': {'Eval@', 'IndAdj', 'PosAff', 'Positiv', 'Quality'},
#  'AUTHENTIC': {'Ovrst', 'Positiv', 'Pstv', 'Virtue'},
#  'AUTHENTICITY': {'Ovrst', 'Positiv', 'Pstv', 'Virtue'},
#  'AUTHORITATIVE': {'Doctrin',
#   'IPadj',
#   'Legal',
#   'Ovrst',
#   'Positiv',
#   'PowAuth',
#   'PowTot',
#   'Power',
#   'Strong',
#   'Virtue'},
#  'AUTHORITY': {'EnlPt',
#   'EnlTot',
#   'Legal',
#   'Positiv',
#   'PowAuPt',
#   'PowAuth',
#   'PowTot',
#   'Power',
#   'Strong'},
#  'AUTONOMOUS': {'IPadj', 'Legal', 'Positiv', 'Power', 'Strong', 'Undrst'},
#  'AVAILABILITY': {'Positiv', 'Pstv', 'Virtue'},
#  'AVID': {'IndAdj', 'Ovrst', 'Positiv'},
#  'AWARD': {'Active', 'ComForm', 'IAV', 'Positiv', 'Power', 'Pstv', 'Strong'},
#  'AWARE': {'EnlOth',
#   'EnlTot',
#   'IndAdj',
#   'Know',
#   'Passive',
#   'Perceiv',
#   'Positiv',
#   'Strong'},
#  'AWARENESS': {'ABS',
#   'Abs@',
#   'EnlOth',
#   'EnlTot',
#   'Passive',
#   'Perceiv',
#   'Positiv',
#   'Pstv',
#   'Strong'},
#  'BACK': {'Active',
#   'Affil',
#   'BodyPt',
#   'Fail',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowLoss',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'Time@'},
#  'BACKBONE': {'Positiv', 'Power', 'Strong'},
#  'BACKER': {'Econ@',
#   'HU',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Role',
#   'Strong'},
#  'BACKING': {'Affil', 'Positiv'},
#  'BALL': {'BodyPt',
#   'Exprsv',
#   'Object',
#   'Positiv',
#   'Pstv',
#   'Ritual',
#   'RspOth',
#   'RspTot',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Tool',
#   'Virtue',
#   'WlbGain',
#   'WlbTot'},
#  'BALMY': {'IndAdj', 'Pleasur', 'Positiv'},
#  'BAPTISM': {'Affil', 'Doctrin', 'Positiv'},
#  'BAPTIZE': {'Active', 'Affil', 'DAV', 'Doctrin', 'Positiv'},
#  'BARGAIN': {'Active', 'ComForm', 'Econ@', 'IAV', 'Positiv', 'SocRel'},
#  'BASIC': {'Ovrst', 'Positiv', 'Pstv', 'Rel', 'SureLw', 'Virtue'},
#  'BEACON': {'EnlOth', 'EnlTot', 'Positiv', 'Virtue'},
#  'BEAUTEOUS': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'BEAUTIFY': {'Active', 'Eval@', 'IAV', 'Positiv', 'Strong'},
#  'BEAUTY': {'ABS', 'Abs@', 'Positiv', 'Pstv', 'SklAsth', 'SklToT', 'Virtue'},
#  'BEFIT': {'Eval@', 'IAV', 'Passive', 'PosAff', 'Positiv'},
#  'BEFITTING': {'Eval@', 'IndAdj', 'Passive', 'Positiv'},
#  'BEFRIEND': {'Active', 'Affil', 'IAV', 'Positiv', 'SocRel'},
#  'BEHALF': {'Affil', 'Positiv', 'Pstv', 'Virtue'},
#  'BELOVED': {'AffOth', 'AffTot', 'Affil', 'Arousal', 'Positiv', 'Pstv'},
#  'BENEFACTOR': {'Econ@', 'Fetch', 'HU', 'Positiv', 'Role', 'Virtue'},
#  'BENEFICENT': {'Eval@', 'IPadj', 'Positiv', 'Virtue'},
#  'BENEFICIAL': {'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'BENEFICIARY': {'Econ@', 'Exch', 'HU', 'Positiv', 'Role'},
#  'BENEFIT': {'Affil',
#   'COM',
#   'ComForm',
#   'ECON',
#   'Econ@',
#   'Goal',
#   'IAV',
#   'MeansLw',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TrnGain',
#   'WltOth',
#   'WltTot'},
#  'BENEVOLENCE': {'Econ@', 'PosAff', 'Positiv', 'Virtue'},
#  'BENEVOLENT': {'Econ@', 'IPadj', 'Positiv', 'Virtue'},
#  'BENIGN': {'Affil', 'Passive', 'Positiv', 'Power', 'Pstv', 'Virtue'},
#  'BEQUEATH': {'Active', 'DAV', 'Econ@', 'Exch', 'Positiv'},
#  'BEST': {'Compare', 'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'BESTOW': {'Active',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TrnGain'},
#  'BETROTH': {'Active', 'Econ@', 'Exch', 'IAV', 'Positiv'},
#  'BETROTHAL': {'Econ@', 'Exch', 'Positiv'},
#  'BETTER': {'Active',
#   'Compare',
#   'EVAL',
#   'IAV',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'RspGain',
#   'RspTot',
#   'Try',
#   'Virtue'},
#  'BLAMELESS': {'Eval@', 'IndAdj', 'Legal', 'Positiv', 'Virtue'},
#  'BLESS': {'Affil',
#   'ComForm',
#   'IAV',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'RcEnds',
#   'RcTot',
#   'Relig',
#   'SocRel',
#   'Virtue'},
#  'BLISS': {'EMOT', 'Pleasur', 'Positiv'},
#  'BLISSFUL': {'EMOT', 'Eval@', 'IndAdj', 'Pleasur', 'Positiv'},
#  'BLITHE': {'IndAdj', 'Pleasur', 'Positiv'},
#  'BLOOM': {'Active', 'Begin', 'IAV', 'Increas', 'Positiv'},
#  'BLOSSOM': {'Active', 'Begin', 'IAV', 'Increas', 'Positiv'},
#  'BOARD': {'Academ',
#   'COLL',
#   'COM',
#   'ComForm',
#   'ComnObj',
#   'ECON',
#   'Econ@',
#   'EnlOth',
#   'EnlTot',
#   'HU',
#   'IAV',
#   'NegAff',
#   'Negativ',
#   'Ngtv',
#   'Object',
#   'Ovrst',
#   'POLIT',
#   'Positiv',
#   'PowAuPt',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Quality',
#   'RcEthic',
#   'RcTot',
#   'SureLw',
#   'Tool',
#   'Travel',
#   'Vice',
#   'Virtue',
#   'WlbPhys',
#   'WlbTot'},
#  'BOLDNESS': {'Positiv', 'Power', 'Strong', 'Virtue'},
#  'BOLSTER': {'Active', 'Affil', 'IAV', 'Increas', 'Positiv', 'Strong'},
#  'BONNY': {'Eval@', 'IndAdj', 'Positiv', 'Virtue'},
#  'BONUS': {'ComForm', 'ECON', 'Econ@', 'Positiv', 'Pstv', 'WltOth', 'WltTot'},
#  'BOOM': {'Econ@', 'Increas', 'Positiv', 'Strong'},
#  'BOOST': {'Active', 'IAV', 'Increas', 'Positiv', 'Pstv', 'Strong', 'TrnGain'},
#  'BOUNDLESS': {'Increas', 'IndAdj', 'Positiv', 'Quan', 'Strong'},
#  'BOUNTIFUL': {'Increas',
#   'IndAdj',
#   'Positiv',
#   'Quan',
#   'Strong',
#   'WltOth',
#   'WltTot'},
#  'BRAINY': {'IndAdj', 'Positiv', 'Think'},
#  'BRAVE': {'EVAL',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'Strong',
#   'Virtue'},
#  'BRAVERY': {'Positiv', 'Power', 'RcEthic', 'RcTot', 'Strong', 'Virtue'},
#  'BREADWINNER': {'Econ@', 'HU', 'Positiv', 'Role', 'Work'},
#  'BRIGHT': {'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Quality'},
#  'BRIGHTNESS': {'Positiv', 'Pstv', 'Quality'},
#  'BRILLIANCE': {'Positiv', 'Pstv', 'Quality'},
#  'BRILLIANT': {'EVAL', 'Ovrst', 'PosAff', 'Positiv', 'Pstv', 'Quality'},
#  'BROTHERHOOD': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'BROTHERLY': {'Affil', 'IPadj', 'Positiv', 'SocRel'},
#  'BUOYANT': {'Affil', 'IndAdj', 'Positiv', 'Strong'},
#  'BUY': {'Active',
#   'DAV',
#   'ECON',
#   'Econ@',
#   'Exch',
#   'Positiv',
#   'Pstv',
#   'Virtue',
#   'WltOth',
#   'WltTot',
#   'WltTran'},
#  'CALL': {'Affil',
#   'COM',
#   'ComForm',
#   'DAV',
#   'Doctrin',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'SocRel',
#   'Solve'},
#  'CALM': {'EMOT',
#   'IAV',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'CALMNESS': {'EMOT', 'Pleasur', 'Positiv', 'Undrst'},
#  'CANDID': {'ComForm', 'EnlOth', 'EnlTot', 'IPadj', 'Positiv', 'Strong'},
#  'CANDOR': {'ComForm', 'Positiv', 'Strong'},
#  'CAPABILITY': {'Means', 'MeansLw', 'Positiv', 'Power', 'Pstv', 'Strong'},
#  'CAPABLE': {'MeansLw', 'Positiv', 'Power', 'Pstv', 'Strong', 'Virtue'},
#  'CAPITALIZE': {'Active',
#   'Econ@',
#   'IAV',
#   'Increas',
#   'Positiv',
#   'Power',
#   'Strong'},
#  'CAPTIVATION': {'Ovrst', 'Perceiv', 'Positiv', 'Think'},
#  'CARE': {'Active',
#   'AffGain',
#   'AffOth',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'Positiv',
#   'Pstv',
#   'SV',
#   'SocRel',
#   'Undrst'},
#  'CAREFREE': {'EMOT', 'IndAdj', 'Pleasur', 'Positiv'},
#  'CAREFUL': {'Positiv', 'Pstv', 'Undrst', 'Virtue'},
#  'CARESS': {'AffGain',
#   'AffTot',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SocRel'},
#  'CASUAL': {'Passive', 'Positiv', 'Pstv', 'Undrst', 'Virtue'},
#  'CEASELESS': {'FREQ', 'IndAdj', 'Negate', 'Positiv'},
#  'CELEBRATE': {'Active', 'IAV', 'Pleasur', 'Positiv', 'RspOth', 'RspTot'},
#  'CELEBRATION': {'Active',
#   'Affil',
#   'Positiv',
#   'Pstv',
#   'Ritual',
#   'RspOth',
#   'RspTot'},
#  'CELEBRITY': {'HU', 'Ovrst', 'Positiv', 'Power', 'Role'},
#  'CEREMONIAL': {'Doctrin', 'IndAdj', 'Positiv'},
#  'CHAMP': {'HU', 'Positiv', 'Power', 'Role', 'Strong'},
#  'CHAMPION': {'Active',
#   'HU',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Role',
#   'SklPt',
#   'SklToT',
#   'Strong'},
#  'CHAMPIONSHIP': {'Positiv', 'Power', 'Strong'},
#  'CHARISMA': {'Positiv', 'Strong', 'Virtue'},
#  'CHARITABLE': {'AffOth',
#   'AffTot',
#   'Econ@',
#   'Exch',
#   'IPadj',
#   'Positiv',
#   'Virtue'},
#  'CHARITY': {'ECON', 'Econ@', 'Positiv', 'Pstv', 'Virtue'},
#  'CHARM': {'Affil',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'SocRel',
#   'Virtue'},
#  'CHASTE': {'IndAdj', 'Positiv', 'Virtue'},
#  'CHEER': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'WlbGain',
#   'WlbTot'},
#  'CHEERFUL': {'EMOT', 'Pleasur', 'Positiv', 'Pstv', 'WlbPsyc', 'WlbTot'},
#  'CHEERY': {'EMOT', 'Pleasur', 'Positiv', 'Pstv'},
#  'CHERISH': {'Affil',
#   'EndsLw',
#   'IAV',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Virtue'},
#  'CHERUB': {'HU', 'Positiv', 'Role', 'Virtue'},
#  'CHIC': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'CHIVALROUS': {'Doctrin', 'IPadj', 'Positiv', 'Virtue'},
#  'CHIVALRY': {'Doctrin', 'Positiv', 'Virtue'},
#  'CHOSEN': {'EndsLw', 'IAV', 'Passive', 'Positiv', 'Pstv', 'Solve', 'Virtue'},
#  'CHUM': {'HU', 'Positiv', 'Role', 'SocRel'},
#  'CIVIL': {'COLL',
#   'Doctrin',
#   'HU',
#   'Milit',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowAuPt',
#   'PowAuth',
#   'PowCon',
#   'PowDoct',
#   'PowTot',
#   'Pstv',
#   'Ritual',
#   'Role'},
#  'CIVILITY': {'Active', 'Positiv', 'Virtue'},
#  'CIVILIZATION': {'ABS', 'Abs@', 'ArenaLw', 'Doctrin', 'Positiv', 'Pstv'},
#  'CIVILIZE': {'Doctrin',
#   'EnlGain',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Work'},
#  'CLARIFY': {'Active',
#   'ComForm',
#   'EnlGain',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv'},
#  'CLARITY': {'EnlOth', 'EnlTot', 'Ovrst', 'Positiv', 'Pstv', 'Quality'},
#  'CLASSIC': {'Academ', 'COM', 'ComForm', 'Positiv', 'Pstv'},
#  'CLEAN': {'Active',
#   'ECON',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'Virtue',
#   'Work'},
#  'CLEANLINESS': {'Positiv', 'Virtue', 'Work'},
#  'CLEANSE': {'Active', 'DAV', 'Positiv', 'Work'},
#  'CLEAR': {'ComForm',
#   'ECON',
#   'Econ@',
#   'EnlOth',
#   'EnlTot',
#   'Exert',
#   'IAV',
#   'Know',
#   'Land',
#   'Ovrst',
#   'PLACE',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Quality',
#   'Quan',
#   'RcGain',
#   'RcTot',
#   'Social',
#   'Solve',
#   'WltOth',
#   'WltTot'},
#  'CLEARNESS': {'Know', 'Perceiv', 'Positiv'},
#  'CLEVER': {'EVAL', 'Positiv', 'Pstv', 'SklOth', 'SklToT', 'Strong', 'Virtue'},
#  'CLOSENESS': {'Positiv', 'SocRel', 'Space'},
#  'CLOUT': {'Positiv', 'Power', 'Strong'},
#  'CO-OPERATION': {'Affil', 'Positiv', 'PowGain', 'PowTot', 'Pstv', 'Virtue'},
#  'COAX': {'Active', 'ComForm', 'IAV', 'Positiv', 'SocRel'},
#  'CODDLE': {'Active', 'Affil', 'IAV', 'Positiv', 'SocRel'},
#  'COEXISTENCE': {'Doctrin',
#   'POLIT',
#   'Passive',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv'},
#  'COGENT': {'ComForm', 'IndAdj', 'Ovrst', 'Positiv', 'Power', 'Strong'},
#  'COGNIZANCE': {'Ovrst', 'Perceiv', 'Positiv', 'Think'},
#  'COGNIZANT': {'IndAdj', 'Ovrst', 'Perceiv', 'Positiv', 'Think'},
#  'COHERENT': {'IndAdj', 'Ovrst', 'Positiv', 'Rel', 'Strong'},
#  'COHESION': {'Affil', 'Ovrst', 'Positiv', 'Rel', 'Strong'},
#  'COHORT': {'Affil', 'COLL', 'Ovrst', 'Positiv'},
#  'COINCIDENT': {'Active', 'NatrPro', 'Positiv', 'Rel'},
#  'COLLABORATE': {'Active', 'Affil', 'ComForm', 'IAV', 'Positiv', 'SocRel'},
#  'COLLABORATION': {'Active',
#   'Affil',
#   'COM',
#   'POLIT',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'COLLEAGUE': {'Affil', 'HU', 'Positiv', 'PowCoop', 'PowTot', 'Pstv', 'Role'},
#  'COLOSSAL': {'Eval@', 'IndAdj', 'Ovrst', 'Positiv', 'Quality'},
#  'COMEBACK': {'Active', 'Increas', 'Positiv', 'Strong'},
#  'COMEDY': {'Exprsv', 'Positiv', 'Pstv', 'Ritual'},
#  'COMELY': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'COMESTIBLE': {'IndAdj', 'NatrPro', 'Pleasur', 'Positiv'},
#  'COMFORT': {'Affil',
#   'Arousal',
#   'IAV',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'WlbGain',
#   'WlbTot'},
#  'COMFORTABLE': {'EVAL',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'WlbPhys',
#   'WlbTot'},
#  'COMIC': {'HU', 'Pleasur', 'Positiv', 'Role', 'Work'},
#  'COMICAL': {'IndAdj', 'Pleasur', 'Positiv'},
#  'COMMEMORATE': {'Active', 'IAV', 'Positiv', 'Ritual'},
#  'COMMEMORATION': {'Positiv', 'Ritual'},
#  'COMMENCEMENT': {'Begin', 'EndsLw', 'Positiv'},
#  'COMMEND': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'RspGain',
#   'RspTot'},
#  'COMMENDABLE': {'Affil',
#   'ComForm',
#   'IndAdj',
#   'Positiv',
#   'RspGain',
#   'RspTot',
#   'Virtue'},
#  'COMMENDATION': {'Affil', 'Positiv', 'Ritual'},
#  'COMMENSURATE': {'Eval@', 'IPadj', 'Positiv', 'Quality', 'Rel'},
#  'COMMISSION': {'Affil',
#   'Know',
#   'Ovrst',
#   'Positiv',
#   'PowAuPt',
#   'PowTot',
#   'Strong'},
#  'COMMITMENT': {'Active',
#   'Affil',
#   'Positiv',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'Virtue'},
#  'COMMODIOUS': {'Affil', 'IPadj', 'Ovrst', 'Positiv'},
#  'COMMON': {'Affil',
#   'COLL',
#   'ECON',
#   'EVAL',
#   'Econ@',
#   'EnlOth',
#   'EnlTot',
#   'FREQ',
#   'HU',
#   'Ovrst',
#   'PLACE',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowAuPt',
#   'PowTot',
#   'Pstv',
#   'Social',
#   'Time@',
#   'Virtue'},
#  'COMMONSENSE': {'Know', 'Positiv'},
#  'COMMUNAL': {'Affil', 'IPadj', 'Positiv', 'Social'},
#  'COMMUNE': {'Affil', 'Positiv', 'Social'},
#  'COMMUNICATE': {'COM',
#   'ComForm',
#   'EnlGain',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv'},
#  'COMMUNICATIVE': {'ComForm', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv'},
#  'COMMUNION': {'Affil',
#   'Positiv',
#   'Pstv',
#   'RcRelig',
#   'RcTot',
#   'Relig',
#   'Ritual'},
#  'COMMUNITY': {'Affil',
#   'COLL',
#   'ECON',
#   'HU',
#   'POLIT',
#   'Positiv',
#   'PowAren',
#   'PowTot',
#   'Pstv',
#   'Strong'},
#  'COMPANION': {'AffPt', 'AffTot', 'Affil', 'HU', 'Positiv', 'Pstv', 'Role'},
#  'COMPANIONSHIP': {'AffOth', 'AffTot', 'Affil', 'Positiv'},
#  'COMPANY': {'AffPt',
#   'AffTot',
#   'Affil',
#   'COLL',
#   'ECON',
#   'Econ@',
#   'HU',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'WltPt',
#   'WltTot'},
#  'COMPASSION': {'Affil', 'EMOT', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'COMPASSIONATE': {'Affil', 'EMOT', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'COMPATIBLE': {'Affil', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'COMPENSATE': {'Active',
#   'Econ@',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'TrnGain',
#   'Work'},
#  'COMPENSATION': {'Active', 'ECON', 'Positiv', 'Pstv', 'TrnGain', 'Virtue'},
#  'COMPETENCE': {'Eval@',
#   'Know',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'COMPETENCY': {'Eval@', 'Know', 'Positiv', 'Strong'},
#  'COMPETENT': {'EVAL',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'COMPLEMENT': {'IAV', 'Positiv', 'Pstv', 'Quan', 'Rel', 'RspGain', 'RspTot'},
#  'COMPLEMENTARY': {'Eval@', 'IndAdj', 'Positiv', 'Quality', 'Rel'},
#  'COMPLETE': {'Finish',
#   'IAV',
#   'Ovrst',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Quan',
#   'Strong',
#   'SureLw'},
#  'COMPLETENESS': {'ABS', 'Abs@', 'Ovrst', 'Positiv', 'Pstv', 'Virtue'},
#  'COMPLETION': {'Finish', 'Positiv', 'Pstv'},
#  'COMPLIANCE': {'Affil', 'ComForm', 'Positiv', 'PowCoop', 'PowTot', 'SocRel'},
#  'COMPLIMENT': {'Active', 'Affil', 'ComForm', 'IAV', 'Positiv'},
#  'COMPOSURE': {'Positiv', 'Strong', 'Virtue'},
#  'COMPREHEND': {'Active',
#   'EnlOth',
#   'EnlTot',
#   'Know',
#   'Perceiv',
#   'Positiv',
#   'SV'},
#  'COMPREHENSION': {'EnlGain', 'EnlTot', 'Know', 'Positiv', 'Pstv'},
#  'COMPREHENSIVE': {'Complet', 'IndAdj', 'Ovrst', 'Positiv'},
#  'COMPROMISE': {'IAV',
#   'POLIT',
#   'Passive',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Submit'},
#  'CONCESSION': {'Passive',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Submit',
#   'Weak'},
#  'CONCLUSIVE': {'Complet', 'IndAdj', 'Know', 'Ovrst', 'Positiv'},
#  'CONCUR': {'Active',
#   'Affil',
#   'ComForm',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'SV'},
#  'CONDONE': {'Active', 'Affil', 'Positiv', 'Power', 'RcGain', 'RcTot', 'SV'},
#  'CONDUCIVE': {'Affil', 'IndAdj', 'Positiv', 'Rel', 'TrnGain'},
#  'CONFEDERATION': {'Affil', 'Polit@', 'Positiv', 'SocRel'},
#  'CONFER': {'Active',
#   'ComForm',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Think'},
#  'CONFIDANT': {'Affil', 'HU', 'Positiv', 'Role'},
#  'CONFIDE': {'Affil',
#   'ComForm',
#   'IAV',
#   'Ovrst',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot'},
#  'CONFIDENCE': {'Affil',
#   'ComForm',
#   'EMOT',
#   'Ovrst',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Submit'},
#  'CONFIDENT': {'EMOT',
#   'Ovrst',
#   'Pleasur',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong',
#   'WlbPsyc',
#   'WlbTot'},
#  'CONGENIAL': {'AffOth', 'AffTot', 'Affil', 'IPadj', 'Positiv', 'Virtue'},
#  'CONGRATULATE': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'RspGain',
#   'RspTot'},
#  'CONGRATULATION': {'Affil',
#   'COM',
#   'ComForm',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot'},
#  'CONGRATULATORY': {'Affil', 'ComForm', 'IPadj', 'Positiv'},
#  'CONGREGATE': {'Active', 'Affil', 'COLL', 'IAV', 'Positiv'},
#  'CONJUNCTION': {'Positiv', 'PowCoop', 'PowTot', 'Rel'},
#  'CONJURE': {'Active', 'Begin', 'Exprsv', 'IAV', 'Positiv', 'Strong'},
#  'CONNECT': {'Active', 'IAV', 'Positiv', 'Pstv', 'Space'},
#  'CONQUER': {'Active',
#   'IAV',
#   'Positiv',
#   'PowLoss',
#   'PowTot',
#   'Power',
#   'SocRel',
#   'Strong',
#   'Travel'},
#  'CONQUEROR': {'HU', 'Positiv', 'Power', 'Role', 'SocRel', 'Strong', 'Travel'},
#  'CONQUEST': {'Goal', 'Positiv', 'PowOth', 'PowTot'},
#  'CONSCIENCE': {'ABS',
#   'Abs@',
#   'Positiv',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'Virtue'},
#  'CONSCIENTIOUS': {'Positiv', 'Pstv', 'Virtue'},
#  'CONSENSUS': {'Affil', 'ComForm', 'Complet', 'Positiv', 'PowCoop', 'PowTot'},
#  'CONSENT': {'COM',
#   'ComForm',
#   'DAV',
#   'Passive',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Strong',
#   'Submit'},
#  'CONSERVE': {'Active', 'Fetch', 'IAV', 'MeansLw', 'Positiv', 'Try'},
#  'CONSIDER': {'IAV', 'Means', 'Positiv', 'Pstv', 'Solve'},
#  'CONSIDERATE': {'IPadj', 'Positiv', 'SocRel', 'Virtue'},
#  'CONSIDERATION': {'EnlOth', 'EnlTot', 'Know', 'Means', 'Positiv', 'Pstv'},
#  'CONSIGN': {'Active', 'Fetch', 'IAV', 'Positiv'},
#  'CONSISTENCY': {'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'CONSISTENT': {'EndsLw', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'CONSOLE': {'Active', 'Affil', 'IAV', 'Positiv'},
#  'CONSOLIDATE': {'IAV', 'Persist', 'Positiv', 'Pstv', 'Strong'},
#  'CONSTANCY': {'Positiv'},
#  'CONSTRUCTIVE': {'EVAL', 'EndsLw', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'CONSULT': {'ComForm', 'EnlOth', 'EnlTot', 'IAV', 'Positiv', 'Pstv'},
#  'CONSULTATION': {'COM', 'ComForm', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv'},
#  'CONSUMMATE': {'Active', 'ComForm', 'Complet', 'EndsLw', 'IAV', 'Positiv'},
#  'CONTACT': {'Active',
#   'Affil',
#   'COM',
#   'ComForm',
#   'DAV',
#   'EnlGain',
#   'EnlTot',
#   'Positiv',
#   'Pstv',
#   'TrnGain'},
#  'CONTENT': {'ComnObj',
#   'EMOT',
#   'IAV',
#   'Know',
#   'Object',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'TrnGain',
#   'WlbGain',
#   'WlbTot'},
#  'CONTENTMENT': {'EMOT', 'Pleasur', 'Positiv', 'Stay'},
#  'CONTINUITY': {'ABS',
#   'Abs@',
#   'Active',
#   'Persist',
#   'Positiv',
#   'Rel',
#   'Strong'},
#  'CONTRIBUTE': {'Active',
#   'Affil',
#   'Econ@',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TrnGain',
#   'Work'},
#  'CONTRIBUTION': {'Active',
#   'Affil',
#   'ECON',
#   'POLIT',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'TrnGain'},
#  'CONTRIBUTOR': {'Affil',
#   'HU',
#   'Positiv',
#   'Role',
#   'SocRel',
#   'WltPt',
#   'WltTot'},
#  'CONVENE': {'Active', 'Affil', 'Begin', 'COLL', 'IAV', 'Positiv', 'Travel'},
#  'CONVICTION': {'Positiv', 'Pstv', 'RcGain', 'RcTot', 'Strong', 'Virtue'},
#  'CONVINCE': {'Active',
#   'ComForm',
#   'EnlGain',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'COOPERATE': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong'},
#  'COOPERATION': {'ABS',
#   'Abs@',
#   'Active',
#   'Affil',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'COOPERATIVE': {'Active',
#   'Affil',
#   'COLL',
#   'ECON',
#   'Econ@',
#   'HU',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'COORDINATE': {'Active',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong'},
#  'COORDINATION': {'Affil', 'Positiv', 'Rel', 'Strong', 'Virtue'},
#  'CORDIAL': {'AffOth', 'AffTot', 'IPadj', 'Positiv', 'Virtue'},
#  'CORRECT': {'IAV',
#   'Ovrst',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'TrnGain',
#   'Virtue',
#   'Work'},
#  'CORRECTION': {'Positiv'},
#  'COUNCIL': {'COLL',
#   'HU',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowAuPt',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'COUNSEL': {'Affil',
#   'ComForm',
#   'EnlOth',
#   'EnlTot',
#   'HU',
#   'IAV',
#   'Legal',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Role'},
#  'COURAGE': {'ABS',
#   'Abs@',
#   'EMOT',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'COURAGEOUS': {'IndAdj', 'Positiv', 'RspOth', 'RspTot', 'Strong', 'Virtue'},
#  'COURTEOUS': {'Affil', 'ComForm', 'Positiv', 'Pstv', 'Virtue'},
#  'COURTESY': {'Affil', 'Positiv', 'Pstv', 'Ritual', 'Virtue'},
#  'COURTLY': {'Polit@', 'Positiv', 'Pstv', 'Virtue'},
#  'COVENANT': {'Affil', 'ComForm', 'Doctrin', 'Positiv'},
#  'COZY': {'Eval@', 'IndAdj', 'Pleasur', 'Positiv', 'Quality'},
#  'CREATE': {'Active',
#   'Begin',
#   'EndsLw',
#   'Exprsv',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Strong'},
#  'CREATIVE': {'Active',
#   'EMOT',
#   'EndsLw',
#   'Exprsv',
#   'Positiv',
#   'Pstv',
#   'Virtue'},
#  'CREATIVITY': {'ABS',
#   'Abs@',
#   'Active',
#   'EndsLw',
#   'Positiv',
#   'Pstv',
#   'Virtue'},
#  'CREDENTIALS': {'Affil', 'Eval@', 'Positiv', 'Quality'},
#  'CREDIBILITY': {'Eval@', 'Positiv', 'Quality'},
#  'CREDIBLE': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'CREDIT': {'Academ',
#   'COM',
#   'ComForm',
#   'ECON',
#   'Econ@',
#   'Exch',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot',
#   'Virtue',
#   'WltOth',
#   'WltTot',
#   'WltTran'},
#  'CRUSADE': {'Affil', 'Polit@', 'Positiv', 'Travel'},
#  'CRUSADER': {'Affil', 'HU', 'Polit@', 'Positiv', 'Role', 'Travel'},
#  'CUDDLE': {'Active', 'IAV', 'Pleasur', 'Positiv'},
#  'CULMINATE': {'Active', 'COLL', 'Complet', 'IAV', 'Positiv'},
#  'CULMINATION': {'COLL', 'Complet', 'Positiv', 'Rel'},
#  'CULTIVATE': {'Active',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'TranLw',
#   'Virtue',
#   'Work'},
#  'CULTIVATION': {'Begin', 'Increas', 'Positiv', 'Rel'},
#  'CULTURE': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'EnlOth',
#   'EnlTot',
#   'Positiv',
#   'Pstv',
#   'Virtue'},
#  'CUPID': {'EMOT', 'HU', 'Pleasur', 'Positiv'},
#  'CURE': {'Affil',
#   'Complet',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Means',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'WlbGain',
#   'WlbTot'},
#  'CURTSEY': {'Active', 'DAV', 'Positiv', 'SocRel'},
#  'CUTE': {'Eval@', 'IndAdj', 'Positiv', 'Virtue'},
#  'DANCE': {'Active',
#   'AffGain',
#   'AffOth',
#   'AffTot',
#   'DAV',
#   'Exprsv',
#   'Positiv',
#   'Pstv',
#   'Ritual',
#   'Travel'},
#  'DARE': {'EndsLw', 'IAV', 'Positiv', 'Pstv', 'Try'},
#  'DARING': {'Eval@',
#   'IndAdj',
#   'Positiv',
#   'Pstv',
#   'Quality',
#   'Strong',
#   'Virtue'},
#  'DARLING': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Eval@',
#   'HU',
#   'IndAdj',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'Virtue'},
#  'DAUNTLESS': {'FREQ', 'IndAdj', 'Positiv', 'Power', 'Strong'},
#  'DAWN': {'ABS',
#   'Begin',
#   'DAV',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Solve',
#   'TIME',
#   'Time@'},
#  'DAZZLE': {'Active', 'IAV', 'Perceiv', 'Positiv', 'Strong'},
#  'DEAL': {'Active',
#   'COM',
#   'ComForm',
#   'ECON',
#   'Econ@',
#   'Hostile',
#   'IAV',
#   'Intrj',
#   'Means',
#   'NegAff',
#   'Negativ',
#   'Ngtv',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowDoct',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'Quan',
#   'Ritual',
#   'TranLw',
#   'Work'},
#  'DEAR': {'AffOth', 'AffTot', 'Affil', 'Positiv', 'Pstv', 'SureLw', 'Virtue'},
#  'DECENCY': {'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'DECENT': {'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'DECIPHER': {'Active', 'ComForm', 'IAV', 'Positiv', 'Solve'},
#  'DECORATE': {'Active', 'Eval@', 'IAV', 'Increas', 'Pleasur', 'Positiv'},
#  'DECORATION': {'Object', 'Pleasur', 'Positiv'},
#  'DECORATIVE': {'Eval@', 'IndAdj', 'Pleasur', 'Positiv'},
#  'DEDICATE': {'IAV', 'Need', 'PosAff', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'DEDICATION': {'ABS',
#   'Abs@',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'DEDUCE': {'Active', 'IAV', 'Positiv', 'Solve', 'Think'},
#  'DEFEND': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong'},
#  'DEFENDER': {'Active', 'Affil', 'HU', 'Positiv', 'Pstv', 'Role', 'Strong'},
#  'DEFENSE': {'Active',
#   'Affil',
#   'POLIT',
#   'Positiv',
#   'PowCon',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'Strong'},
#  'DEFERENCE': {'Ought', 'Positiv'},
#  'DEFINITIVE': {'Complet', 'IndAdj', 'Know', 'Positiv', 'Strong', 'SureLw'},
#  'DELICACY': {'Eval@', 'Ovrst', 'Positiv', 'Quality'},
#  'DELICATE': {'EVAL', 'Positiv', 'Pstv', 'Quality', 'Weak'},
#  'DELIGHT': {'EMOT', 'IAV', 'Pleasur', 'Positiv', 'Pstv', 'WlbGain', 'WlbTot'},
#  'DELIGHTFUL': {'EVAL', 'Pleasur', 'Positiv', 'Pstv', 'WlbPsyc', 'WlbTot'},
#  'DEPENDABILITY': {'Ovrst', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'DEPENDABLE': {'Ovrst', 'PosAff', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'DESCRY': {'Active', 'IAV', 'Perceiv', 'Positiv'},
#  'DESERVE': {'Affil', 'IAV', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'SocRel'},
#  'DESERVEDLY': {'Ought', 'Positiv', 'Strong'},
#  'DESIRABLE': {'EVAL', 'EndsLw', 'Positiv', 'Pstv', 'Virtue'},
#  'DESIROUS': {'Eval@', 'IndAdj', 'Need', 'Positiv', 'Quality'},
#  'DEVOTE': {'Active',
#   'AffGain',
#   'AffOth',
#   'AffTot',
#   'EMOT',
#   'IAV',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'Submit',
#   'Try'},
#  'DEVOTION': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'EMOT',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Relig',
#   'Submit'},
#  'DEVOUT': {'Affil', 'Doctrin', 'IndAdj', 'Positiv', 'Strong'},
#  'DEXTERITY': {'Positiv', 'Strong', 'Vary'},
#  'DIG': {'Active',
#   'DAV',
#   'EnlGain',
#   'EnlTot',
#   'Exert',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Solve'},
#  'DIGNIFIED': {'IndAdj', 'Positiv', 'Power', 'Strong'},
#  'DIGNIFY': {'Active', 'ComForm', 'IAV', 'Positiv'},
#  'DIGNITY': {'ABS',
#   'Abs@',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'DILIGENT': {'Active',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'DISCERN': {'Active', 'Eval@', 'IAV', 'Perceiv', 'Positiv', 'Solve'},
#  'DISCREET': {'Positiv', 'Pstv', 'Virtue'},
#  'DISCRETION': {'Positiv', 'Pstv', 'Virtue'},
#  'DISCUSS': {'ComForm', 'EnlOth', 'EnlTot', 'IAV', 'Positiv', 'Pstv'},
#  'DISTINCT': {'EnlOth', 'EnlTot', 'Ovrst', 'Perceiv', 'Positiv', 'Pstv'},
#  'DISTINCTION': {'EnlOth', 'EnlTot', 'Know', 'Positiv', 'Pstv'},
#  'DISTINCTIVE': {'EVAL', 'EnlOth', 'EnlTot', 'Perceiv', 'Positiv', 'Pstv'},
#  'DISTINGUISH': {'EnlGain',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Solve',
#   'Virtue'},
#  'DISTINGUISHED': {'IndAdj', 'Positiv', 'Power', 'Strong'},
#  'DIVINE': {'EVAL',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RcRelig',
#   'RcTot',
#   'Relig',
#   'Solve',
#   'Strong',
#   'Virtue'},
#  'DIVINITY': {'Positiv',
#   'Pstv',
#   'RcRelig',
#   'RcTot',
#   'Relig',
#   'Strong',
#   'Virtue'},
#  'DOMINANCE': {'Positiv', 'Power'},
#  'DONATE': {'Active', 'DAV', 'Econ@', 'Exch', 'Exprsv', 'Fetch', 'Positiv'},
#  'DONATION': {'Econ@', 'Exch', 'Exprsv', 'Fetch', 'Positiv'},
#  'DOTE': {'Active', 'IAV', 'Pleasur', 'Positiv'},
#  'DOUBTLESS': {'Ovrst', 'Positiv', 'Pstv', 'Strong', 'SureLw', 'Virtue'},
#  'DREAMLAND': {'Perceiv', 'Pleasur', 'Positiv', 'Think'},
#  'DURABILITY': {'Positiv', 'Stay', 'Strong'},
#  'DURABLE': {'Means', 'Positiv', 'Pstv', 'Strong', 'WlbPhys', 'WlbTot'},
#  'DYNAMIC': {'Active',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue',
#   'WlbPsyc',
#   'WlbTot'},
#  'EAGER': {'EMOT', 'Pleasur', 'PosAff', 'Positiv', 'Pstv', 'Strong'},
#  'EAGERNESS': {'Feel', 'Positiv'},
#  'EARNEST': {'Pleasur', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Strong'},
#  'EARNESTNESS': {'ComForm', 'Feel', 'Positiv'},
#  'EASE': {'Decreas', 'IAV', 'Pleasur', 'Positiv', 'Pstv'},
#  'EASY': {'EVAL', 'Means', 'Positiv', 'Pstv', 'SureLw', 'Virtue'},
#  'ECONOMIZE': {'Active', 'Econ@', 'Exch', 'IAV', 'Positiv'},
#  'ECSTASY': {'EMOT', 'Pleasur', 'Positiv'},
#  'ECSTATIC': {'EMOT', 'IndAdj', 'Pleasur', 'Positiv'},
#  'EDIBLE': {'Eval@', 'IndAdj', 'NatrPro', 'Positiv', 'Quality'},
#  'EDUCATED': {'Academ',
#   'ComForm',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Virtue'},
#  'EDUCATION': {'Academ', 'Doctrin', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv'},
#  'EDUCATIONAL': {'Academ', 'Doctrin', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv'},
#  'EFFECTIVE': {'Active',
#   'EVAL',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'EFFECTIVENESS': {'Active',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'EFFICACY': {'ABS', 'Abs@', 'Active', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'EFFICIENCY': {'ABS',
#   'Abs@',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'EFFICIENT': {'EVAL',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'ELABORATE': {'Active', 'ComForm', 'IAV', 'Increas', 'Positiv'},
#  'ELABORATION': {'ComForm', 'Increas', 'Positiv'},
#  'ELATE': {'EMOT', 'Pleasur', 'Positiv', 'WlbPsyc', 'WlbTot'},
#  'ELEGANCE': {'Positiv', 'Virtue'},
#  'ELEGANT': {'EVAL', 'Positiv', 'Pstv', 'Virtue'},
#  'ELOQUENT': {'EVAL', 'Exprsv', 'IndAdj', 'Positiv', 'Pstv', 'Virtue'},
#  'EMBELLISH': {'Active', 'ComForm', 'IAV', 'Increas', 'Positiv'},
#  'EMBRACE': {'Active',
#   'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'TrnGain'},
#  'EMINENCE': {'Ovrst', 'Positiv', 'Power', 'Strong'},
#  'EMINENT': {'EVAL', 'Positiv', 'Power', 'Pstv', 'Strong', 'Virtue'},
#  'EMPATHY': {'EMOT', 'Positiv'},
#  'EMPOWER': {'Active',
#   'IAV',
#   'Increas',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Power',
#   'Strong'},
#  'EMPOWERMENT': {'Increas', 'Positiv', 'Power', 'Strong'},
#  'ENABLE': {'Complet', 'IAV', 'Positiv', 'Pstv', 'SklOth', 'SklToT', 'Strong'},
#  'ENCHANT': {'Affil', 'IAV', 'Positiv', 'Pstv', 'SocRel', 'Virtue'},
#  'ENCHANTMENT': {'EMOT', 'Pleasur', 'Positiv'},
#  'ENCOURAGE': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Pstv',
#   'SocRel',
#   'TrnGain',
#   'Virtue'},
#  'ENCOURAGEMENT': {'Active',
#   'Affil',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'Virtue'},
#  'ENDEAR': {'Active', 'Affil', 'IAV', 'Pleasur', 'Positiv'},
#  'ENDORSE': {'Affil',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'PowGain',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Strong'},
#  'ENDOW': {'Active', 'DAV', 'Econ@', 'Exch', 'Positiv'},
#  'ENDURANCE': {'Ovrst', 'Persist', 'Positiv', 'Strong', 'WlbPhys', 'WlbTot'},
#  'ENERGETIC': {'Active',
#   'EVAL',
#   'Exert',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'WlbPhys',
#   'WlbTot'},
#  'ENERGIZE': {'Active', 'IAV', 'Positiv', 'Strong'},
#  'ENGAGE': {'Active',
#   'AffGain',
#   'AffTot',
#   'Affil',
#   'EVAL',
#   'EndsLw',
#   'IAV',
#   'Kin@',
#   'Need',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'Rel',
#   'SocRel',
#   'Try'},
#  'ENHANCE': {'Complet', 'IAV', 'Positiv', 'Pstv', 'Strong', 'TrnGain'},
#  'ENHANCEMENT': {'Increas', 'Ovrst', 'Positiv'},
#  'ENJOY': {'Passive', 'Pleasur', 'Positiv', 'Pstv', 'SV', 'WlbPhys', 'WlbTot'},
#  'ENJOYABLE': {'EVAL', 'Positiv', 'Pstv', 'Virtue', 'WlbPsyc', 'WlbTot'},
#  'ENJOYMENT': {'EMOT',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Virtue',
#   'WlbPsyc',
#   'WlbTot'},
#  'ENLIGHTEN': {'EVAL',
#   'EnlGain',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Solve',
#   'Virtue'},
#  'ENLIGHTENMENT': {'EnlOth', 'EnlTot', 'Know', 'Perceiv', 'Positiv'},
#  'ENRICH': {'Active', 'IAV', 'Increas', 'Positiv', 'Strong', 'TrnGain'},
#  'ENRICHMENT': {'Increas', 'Positiv', 'Strong'},
#  'ENSEMBLE': {'COLL', 'HU', 'Positiv'},
#  'ENSURE': {'IAV',
#   'Ovrst',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TrnGain'},
#  'ENTERTAIN': {'Active',
#   'Affil',
#   'ComForm',
#   'EVAL',
#   'Exprsv',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'SocRel'},
#  'ENTERTAINMENT': {'Exprsv', 'Positiv', 'Pstv', 'Ritual', 'WlbPsyc', 'WlbTot'},
#  'ENTHUSIASM': {'Affil',
#   'EMOT',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPhys',
#   'WlbTot'},
#  'ENTHUSIASTIC': {'Affil',
#   'EMOT',
#   'Feel',
#   'IndAdj',
#   'Pleasur',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Strong'},
#  'ENTREPRENEURIAL': {'Begin', 'Econ@', 'IndAdj', 'Positiv'},
#  'ENTRUST': {'Active', 'Feel', 'Fetch', 'IAV', 'Positiv', 'TrnGain'},
#  'ENVISION': {'Active', 'IAV', 'Perceiv', 'Positiv'},
#  'EQUALITY': {'ABS',
#   'Abs@',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Virtue'},
#  'EQUITABLE': {'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'EQUITY': {'COM',
#   'ComForm',
#   'ECON',
#   'Econ@',
#   'Legal',
#   'Positiv',
#   'Pstv',
#   'WltOth',
#   'WltTot'},
#  'ESSENTIAL': {'EVAL',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'SureLw',
#   'Virtue'},
#  'ESTABLISH': {'Active',
#   'Complet',
#   'IAV',
#   'Ovrst',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Strong',
#   'TranLw',
#   'Virtue'},
#  'ESTEEM': {'Eval@', 'Feel', 'Positiv'},
#  'ETHICAL': {'EVAL', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'ETHICS': {'Doctrin', 'Positiv', 'Pstv', 'RcEthic', 'RcTot'},
#  'ETIQUETTE': {'Doctrin', 'Ought', 'Positiv'},
#  'EVEN': {'Hostile',
#   'IAV',
#   'Negativ',
#   'Ngtv',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Quality',
#   'RcGain',
#   'RcTot',
#   'SocRel',
#   'SureLw'},
#  'EVERLASTING': {'FREQ', 'IndAdj', 'Positiv', 'Stay', 'Strong'},
#  'EXACT': {'Active',
#   'IAV',
#   'Means',
#   'Ovrst',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'Virtue'},
#  'EXALT': {'Eval@', 'IAV', 'Passive', 'Positiv', 'SocRel', 'Submit'},
#  'EXCEL': {'Active', 'IAV', 'Increas', 'Positiv', 'Strong'},
#  'EXCELLENCE': {'EndsLw', 'Positiv', 'Pstv', 'Virtue'},
#  'EXCELLENT': {'EVAL', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'EXCITE': {'Active',
#   'IAV',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'EXCITED': {'EMOT',
#   'IAV',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'EXCITEDNESS': {'Pleasur', 'Positiv'},
#  'EXCITEMENT': {'EMOT',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'EXERTION': {'Positiv', 'Work'},
#  'EXHILARATION': {'Pleasur', 'Positiv'},
#  'EXOTIC': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'EXPERIENCE': {'Complet',
#   'EnlGain',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Means',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'EXPERT': {'EVAL',
#   'HU',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'Role',
#   'SklOth',
#   'SklPt',
#   'SklToT',
#   'Strong',
#   'Virtue'},
#  'EXQUISITE': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'EXTOL': {'Eval@', 'IAV', 'Passive', 'Positiv', 'SocRel', 'Submit'},
#  'EXTRAORDINARY': {'EVAL',
#   'IndAdj',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Quality',
#   'SureLw',
#   'Virtue'},
#  'EXTRAVAGANCE': {'Eval@', 'MeansLw', 'Ovrst', 'Positiv'},
#  'EXUBERANCE': {'Feel', 'Ovrst', 'Positiv'},
#  'EXUBERANT': {'Feel', 'IndAdj', 'Ovrst', 'Positiv'},
# ...
#  'HUMAN': {'AffPt', 'AffTot', 'HU', 'Positiv', 'Pstv', 'Role'},
#  'HUMANITARIAN': {'IndAdj', 'Polit@', 'Positiv', 'Virtue'},
#  'HUMANITY': {'ABS', 'AffPt', 'AffTot', 'COLL', 'HU', 'Positiv', 'Pstv'},
#  'HUMBLE': {'Passive',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Submit',
#   'Virtue',
#   'Weak'},
#  'HUMILITY': {'Positiv', 'RspOth', 'RspTot', 'Virtue'},
#  'HUMOR': {'ABS',
#   'Abs@',
#   'IAV',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'HUMOROUS': {'IndAdj', 'Pleasur', 'Positiv', 'Pstv', 'WlbPsyc', 'WlbTot'},
#  'HYGIENE': {'Positiv'},
#  'IDEAL': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'EndsLw',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Virtue'},
#  'IDEALISM': {'Doctrin', 'Positiv', 'Think'},
#  'IDOL': {'Goal', 'HU', 'Positiv', 'Role'},
#  'IDOLIZE': {'Active', 'Goal', 'Positiv', 'SV'},
#  'ILLUMINATE': {'Active', 'ComForm', 'IAV', 'Ovrst', 'Positiv'},
#  'ILLUSTRIOUS': {'Eval@', 'IndAdj', 'Ovrst', 'Positiv', 'Quality'},
#  'IMAGINATION': {'Exprsv',
#   'Know',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT'},
#  'IMAGINATIVE': {'EVAL',
#   'Exprsv',
#   'Positiv',
#   'Pstv',
#   'SklOth',
#   'SklToT',
#   'Virtue'},
#  'IMMACULATE': {'IndAdj', 'Ovrst', 'Positiv', 'Virtue'},
#  'IMMORTAL': {'IndAdj', 'Ovrst', 'Positiv', 'Power', 'Stay'},
#  'IMPARTIAL': {'Arousal', 'IndAdj', 'Know', 'Positiv', 'RcEthic', 'RcTot'},
#  'IMPARTIALITY': {'Arousal', 'Know', 'Positiv'},
#  'IMPERATIVE': {'EndsLw', 'Eval@', 'IndAdj', 'Ought', 'Positiv'},
#  'IMPERVIOUS': {'IndAdj', 'Positiv', 'Quality', 'Strong'},
#  'IMPETUS': {'Causal', 'Positiv', 'Strong'},
#  'IMPORTANCE': {'EndsLw', 'Know', 'Ovrst', 'Positiv', 'Pstv'},
#  'IMPORTANT': {'EVAL', 'EndsLw', 'Ovrst', 'Positiv', 'Pstv', 'Virtue'},
#  'IMPRESS': {'Active',
#   'EndsLw',
#   'IAV',
#   'Passive',
#   'Perceiv',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong'},
#  'IMPRESSIVE': {'EVAL',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'IMPROVE': {'Active',
#   'IAV',
#   'Increas',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'TrnGain',
#   'Virtue',
#   'Work'},
#  'IMPROVEMENT': {'Active', 'Positiv', 'Pstv', 'Strong', 'TrnGain', 'Virtue'},
#  'IMPUNITY': {'Legal', 'Positiv', 'Power'},
#  'INAUGURATE': {'Active', 'Affil', 'Begin', 'IAV', 'Positiv', 'Ritual'},
#  'INAUGURATION': {'Positiv', 'Ritual'},
#  'INDEPENDENCE': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'Strong'},
#  'INDEPENDENT': {'Doctrin',
#   'HU',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowOth',
#   'PowPt',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'Role',
#   'Strong',
#   'Virtue'},
#  'INDESCRIBABLE': {'ComForm',
#   'Eval@',
#   'IndAdj',
#   'Negate',
#   'Positiv',
#   'Quality'},
#  'INDICATIVE': {'Causal', 'ComForm', 'IndAdj', 'Positiv'},
#  'INDISPENSABILITY': {'Positiv', 'Power', 'Strong', 'Virtue'},
#  'INDISPENSABLE': {'EndsLw', 'Means', 'Ovrst', 'Positiv', 'Pstv', 'Strong'},
#  'INDIVIDUALITY': {'Ovrst', 'Positiv', 'RspOth', 'RspTot'},
#  'INDOMITABLE': {'IndAdj', 'Positiv', 'Power', 'Strong'},
#  'INDULGENCE': {'Arousal', 'Ovrst', 'Pleasur', 'Positiv'},
#  'INDUSTRIOUS': {'IndAdj',
#   'Positiv',
#   'Strong',
#   'Try',
#   'WltOth',
#   'WltTot',
#   'Work'},
#  'INEXPENSIVE': {'Econ@', 'IndAdj', 'Negate', 'Positiv'},
#  'INFALLIBILITY': {'Know', 'Positiv', 'Strong', 'Virtue'},
#  'INFALLIBLE': {'Negate',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'SureLw',
#   'Virtue'},
#  'INFER': {'Active', 'IAV', 'Know', 'Positiv', 'Think'},
#  'INFERENCE': {'Know', 'Positiv', 'Think'},
#  'INFORM': {'Active',
#   'ComForm',
#   'EVAL',
#   'EnlGain',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Means',
#   'Passive',
#   'Positiv',
#   'Pstv'},
#  'INGENIOUS': {'IndAdj', 'Know', 'Positiv', 'Virtue'},
#  'INGENUITY': {'Know', 'Positiv', 'Think', 'Try'},
#  'INHERIT': {'DAV', 'Econ@', 'Exch', 'Passive', 'Positiv'},
#  'INNOCENCE': {'ABS', 'Abs@', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'INNOCENT': {'EVAL',
#   'Legal',
#   'Positiv',
#   'Pstv',
#   'RcEthic',
#   'RcTot',
#   'Virtue'},
#  'INNOVATE': {'Active', 'Begin', 'IAV', 'Positiv'},
#  'INNOVATIVE': {'Begin', 'Positiv', 'Virtue'},
#  'INQUISITIVE': {'ComForm', 'IndAdj', 'Positiv', 'Think'},
#  'INSEPARABLE': {'Affil', 'IPadj', 'Negate', 'Positiv', 'SocRel'},
#  'INSIGHT': {'ABS',
#   'Abs@',
#   'EnlOth',
#   'EnlTot',
#   'Know',
#   'Passive',
#   'Positiv',
#   'Pstv'},
#  'INSISTENT': {'Arousal',
#   'ComForm',
#   'IndAdj',
#   'Know',
#   'Positiv',
#   'Strong',
#   'SureLw'},
#  'INSPIRATION': {'Arousal', 'EnlOth', 'EnlTot', 'Goal', 'Positiv'},
#  'INSPIRATIONAL': {'Arousal', 'Goal', 'IndAdj', 'Positiv'},
#  'INSPIRE': {'Active',
#   'Affil',
#   'EVAL',
#   'IAV',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'Virtue'},
#  'INSTINCTIVE': {'IndAdj', 'Know', 'NatrPro', 'Positiv'},
#  'INTEGRITY': {'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Strong', 'Virtue'},
#  'INTELLECT': {'Academ',
#   'EnlOth',
#   'EnlTot',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'INTELLECTUAL': {'Academ',
#   'EnlOth',
#   'EnlPt',
#   'EnlTot',
#   'HU',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'Strong',
#   'Virtue'},
#  'INTELLIGENCE': {'ABS',
#   'Abs@',
#   'Academ',
#   'EnlOth',
#   'EnlTot',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'INTELLIGENT': {'EVAL',
#   'EnlOth',
#   'EnlTot',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'INTELLIGIBLE': {'ComForm', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv'},
#  'INTERCEDE': {'Active', 'Exert', 'IAV', 'Positiv', 'SocRel'},
#  'INTERCOURSE': {'Active', 'DAV', 'NatrPro', 'Positiv', 'SocRel', 'TranLw'},
#  'INTEREST': {'COM',
#   'ComForm',
#   'ECON',
#   'EMOT',
#   'EVAL',
#   'Econ@',
#   'EndsLw',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Need',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'WltOth',
#   'WltTot'},
#  'INTERESTED': {'EndsLw',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Need',
#   'Passive',
#   'Positiv',
#   'Pstv'},
#  'INTERPOSE': {'Active', 'Exert', 'IAV', 'Positiv', 'SocRel'},
#  'INTIMACY': {'AffOth', 'AffTot', 'EMOT', 'Pleasur', 'Positiv', 'SocRel'},
#  'INTIMATE': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'Passive',
#   'Positiv',
#   'Pstv'},
#  'INTRICATE': {'IndAdj', 'Ovrst', 'Positiv'},
#  'INTRIGUE': {'IAV', 'Passive', 'Positiv', 'PowCon', 'PowTot', 'Think'},
#  'INVALUABLE': {'Econ@', 'Eval@', 'IndAdj', 'PosAff', 'Positiv', 'Quality'},
#  'INVENTOR': {'Active', 'HU', 'Positiv', 'Pstv', 'Role', 'SklPt', 'SklToT'},
#  'INVINCIBLE': {'IndAdj',
#   'Negate',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Power',
#   'Strong',
#   'Virtue'},
#  'INVITATION': {'Active',
#   'Affil',
#   'COM',
#   'ComForm',
#   'Positiv',
#   'Pstv',
#   'TrnGain'},
#  'INVITE': {'Active',
#   'Affil',
#   'DAV',
#   'EVAL',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TrnGain',
#   'Virtue'},
#  'INVULNERABLE': {'IndAdj', 'Negate', 'Positiv', 'Power', 'Strong', 'Virtue'},
#  'IRRESISTIBLE': {'Eval@', 'IPadj', 'Need', 'Negate', 'Positiv'},
#  'JEST': {'Active', 'ComForm', 'IAV', 'Pleasur', 'Positiv'},
#  'JOIN': {'Active',
#   'Affil',
#   'DAV',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Rel',
#   'SocRel',
#   'Strong',
#   'TranLw'},
#  'JOINTLY': {'Affil', 'Positiv', 'PowCoop', 'PowTot', 'Pstv', 'Rel', 'Strong'},
#  'JOKE': {'ComForm', 'Exprsv', 'IAV', 'Positiv', 'Pstv'},
#  'JOLLY': {'EMOT', 'IndAdj', 'Pleasur', 'Positiv'},
#  'JOY': {'EMOT', 'Pleasur', 'Positiv', 'Pstv', 'WlbPsyc', 'WlbTot'},
#  'JOYFUL': {'EMOT', 'IndAdj', 'Pleasur', 'Positiv', 'WlbPsyc', 'WlbTot'},
#  'JUBILANT': {'EMOT', 'IndAdj', 'Pleasur', 'Positiv', 'WlbPsyc', 'WlbTot'},
#  'JUBILEE': {'Pleasur', 'Positiv', 'Ritual'},
#  'JUST': {'Legal',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Quan',
#   'RcEthic',
#   'RcTot',
#   'Time@',
#   'Virtue'},
#  'JUSTICE': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'Legal',
#   'POLIT',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'RcEthic',
#   'RcTot'},
#  'JUSTIFIABLY': {'Ovrst', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'JUSTIFICATION': {'Ovrst', 'Positiv', 'Pstv', 'RcEthic', 'RcTot', 'Virtue'},
#  'JUSTIFY': {'ComForm', 'IAV', 'Ovrst', 'Positiv', 'Pstv', 'RcGain', 'RcTot'},
#  'KEEN': {'PosAff', 'Positiv', 'Pstv', 'Strong', 'Virtue'},
#  'KID': {'Affil',
#   'ComForm',
#   'Exprsv',
#   'HU',
#   'IAV',
#   'Nonadlt',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'RspOth',
#   'RspTot'},
#  'KIND': {'ABS',
#   'Abs@',
#   'Affil',
#   'ComForm',
#   'EVAL',
#   'Know',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Undrst',
#   'Virtue'},
#  'KINDNESS': {'Affil', 'PosAff', 'Positiv', 'Pstv', 'Virtue'},
#  'KISS': {'Active',
#   'AffGain',
#   'AffTot',
#   'Affil',
#   'ComForm',
#   'DAV',
#   'Positiv',
#   'Pstv',
#   'SocRel'},
#  'KNOW': {'Active',
#   'EnlOth',
#   'EnlTot',
#   'Intrj',
#   'Know',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'SV',
#   'Solve'},
#  'KNOWLEDGE': {'ABS',
#   'Abs@',
#   'Academ',
#   'EnlOth',
#   'EnlTot',
#   'Know',
#   'Positiv',
#   'Pstv',
#   'Strong'},
#  'LAUDABLE': {'Affil', 'Eval@', 'IPadj', 'Positiv', 'Quality'},
#  'LAUGH': {'Active',
#   'COM',
#   'ComForm',
#   'DAV',
#   'Exprsv',
#   'Hostile',
#   'IAV',
#   'Negativ',
#   'Ngtv',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'RspLoss',
#   'RspTot',
#   'Undrst',
#   'WlbPsyc',
#   'WlbTot'},
#  'LAUGHTER': {'COM',
#   'ComForm',
#   'Exprsv',
#   'Passive',
#   'Positiv',
#   'Pstv',
#   'WlbPsyc',
#   'WlbTot'},
#  'LAVISH': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'LAW': {'Doctrin', 'Legal', 'POLIT', 'Positiv', 'PowAuth', 'PowTot', 'Pstv'},
#  'LAWFUL': {'IndAdj', 'Legal', 'Positiv', 'PowAuth', 'PowTot', 'Virtue'},
#  'LEAD': {'Active',
#   'Causal',
#   'ComForm',
#   'EVAL',
#   'Hostile',
#   'IAV',
#   'Means',
#   'Ovrst',
#   'Persist',
#   'PosAff',
#   'Positiv',
#   'PowCon',
#   'PowOth',
#   'PowTot',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Strong',
#   'TranLw',
#   'Virtue',
#   'WlbPhys',
#   'WlbTot'},
#  'LEARN': {'ABS',
#   'Abs@',
#   'Academ',
#   'Active',
#   'EnlEnds',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'Solve',
#   'Virtue'},
#  'LEARNER': {'Academ',
#   'EnlPt',
#   'EnlTot',
#   'HU',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'Submit'},
#  'LEGAL': {'Doctrin',
#   'ECON',
#   'Legal',
#   'POLIT',
#   'Positiv',
#   'PowAuth',
#   'PowTot',
#   'Pstv'},
#  'LEGITIMACY': {'Legal', 'Positiv', 'Virtue'},
#  'LEGITIMATE': {'Legal', 'Positiv', 'PowAuth', 'PowTot', 'Pstv', 'Virtue'},
#  'LEISURE': {'Exprsv', 'Passive', 'Positiv', 'Pstv', 'Virtue'},
#  'LIBERAL': {'Academ',
#   'Affil',
#   'Doctrin',
#   'EnlOth',
#   'EnlTot',
#   'HU',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Pstv',
#   'Role',
#   'Virtue'},
#  'LIBERALISM': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'PowDoct',
#   'PowTot',
#   'Pstv'},
#  'LIBERATE': {'Active',
#   'Affil',
#   'IAV',
#   'Positiv',
#   'Power',
#   'RcEthic',
#   'RcTot'},
#  'LIBERTY': {'ABS',
#   'Abs@',
#   'Doctrin',
#   'Polit@',
#   'Positiv',
#   'PowOth',
#   'PowTot',
#   'Power',
#   'Pstv'},
#  'LIFELONG': {'IndAdj', 'Positiv', 'Stay'},
#  'LIGHT': {'Active',
#   'ComForm',
#   'DAV',
#   'EnlOth',
#   'EnlTot',
#   'Exert',
#   'IAV',
#   'Know',
#   'NatrPro',
#   'Positiv',
#   'Pstv',
#   'Quality',
#   'TranLw',
#   'Undrst',
#   'Weak'},
#  'LIKABLE': {'Eval@', 'IPadj', 'Positiv', 'Quality', 'Virtue'},
#  'LIKE': {'AffGain',
#   'AffTot',
#   'Affil',
#   'Arousal',
#   'EMOT',
#   'Passive',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Rel',
#   'SV'},
#  'LIVE': {'Complet',
#   'ECON',
#   'Econ@',
#   'IAV',
#   'Means',
#   'NatrPro',
#   'Positiv',
#   'Pstv',
#   'RspGain',
#   'RspTot',
#   'SV',
#   'Strong',
#   'WlbPhys',
#   'WlbTot'},
#  'LIVELY': {'Active',
#   'Positiv',
#   'Pstv',
#   'Quality',
#   'Strong',
#   'WlbPhys',
#   'WlbTot'},
#  'LOGIC': {'EnlOth', 'EnlTot', 'Know', 'Positiv', 'Pstv'},
#  'LOGICAL': {'EnlOth', 'EnlTot', 'Know', 'Positiv', 'Pstv'},
#  'LONGEVITY': {'Positiv', 'Stay', 'Strong'},
#  'LOVE': {'Active',
#   'AffGain',
#   'AffOth',
#   'AffTot',
#   'Affil',
#   'EMOT',
#   'IAV',
#   'Passive',
#   'Pleasur',
#   'Positiv',
#   'Pstv',
#   'SV',
#   'SocRel',
#   'Strong'},
#  'LOVELINESS': {'Positiv', 'Virtue'},
#  'LOVELY': {'EVAL', 'Positiv', 'Pstv', 'SklAsth', 'SklToT', 'Virtue'},
#  'LOVER': {'AffPt', 'AffTot', 'Affil', 'HU', 'Positiv', 'Pstv', 'Role'},
#  'LOYAL': {'AffOth',
#   'AffTot',
#   'Polit@',
#   'Positiv',
#   'Pstv',
#   'Submit',
#   'Virtue'},
#  'LOYALTY': {'ABS',
#   'Abs@',
#   'AffOth',
#   'AffTot',
#   'POLIT',
#   'Polit@',
#   'Positiv',
#   'Pstv',
#   'Submit',
#   'Virtue'},
#  'LUCID': {'ComForm', 'IndAdj', 'Ovrst', 'Positiv'},
#  'LUCK': {'ABS',
#   'Abs@',
#   'EndsLw',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Undrst',
#   'Virtue'},
#  'LUCKILY': {'EndsLw', 'Positiv', 'Pstv', 'Undrst', 'Virtue'},
#  'LUCKY': {'EndsLw', 'Passive', 'Positiv', 'Pstv', 'Virtue'},
#  'LUCRATIVE': {'Econ@', 'Exch', 'Increas', 'IndAdj', 'Positiv'},
#  'LUMINOUS': {'IndAdj', 'Ovrst', 'Positiv'},
#  'LUST': {'EMOT', 'Need', 'Pleasur', 'Positiv'},
#  'LUSTER': {'Positiv', 'Quality'},
#  'LUSTROUS': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'LUXURIANT': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'LUXURIOUS': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'LUXURY': {'ECON', 'Econ@', 'Positiv', 'Pstv', 'Virtue', 'WltOth', 'WltTot'},
#  'LYRIC': {'COM', 'ComForm', 'Exprsv', 'Positiv', 'Pstv'},
#  'LYRICAL': {'ComForm', 'Exprsv', 'Positiv', 'Pstv'},
#  'MAGICAL': {'Eval@', 'IndAdj', 'Positiv', 'Quality', 'Relig'},
#  'MAGNETIC': {'IPadj', 'NatrPro', 'Positiv', 'Rel'},
#  'MAGNIFICENCE': {'Ovrst', 'Positiv', 'Virtue'},
#  'MAGNIFICENT': {'EVAL',
#   'Ovrst',
#   'PosAff',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue'},
#  'MAIN': {'EVAL', 'Know', 'Ovrst', 'Positiv', 'Pstv', 'Strong', 'SureLw'},
#  'MAJESTIC': {'IndAdj', 'Ovrst', 'Positiv', 'Virtue'},
#  'MAJESTY': {'Positiv', 'Virtue'},
#  'MAJOR': {'Academ',
#   'Doctrin',
#   'EVAL',
#   'EnlOth',
#   'EnlTot',
#   'IAV',
#   'Know',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Work'},
#  'MAKE': {'Active',
#   'Affil',
#   'Complet',
#   'Hostile',
#   'IAV',
#   'Means',
#   'Negativ',
#   'Ngtv',
#   'Object',
#   'Perceiv',
#   'Positiv',
#   'Power',
#   'Pstv',
#   'SocRel',
#   'Solve',
#   'Strong',
#   'Tool',
#   'Work'},
#  'MANAGEABLE': {'Causal', 'IndAdj', 'Ovrst', 'Positiv', 'Strong'},
#  'MANLY': {'IndAdj',
#   'MALE',
#   'Positiv',
#   'Pstv',
#   'Strong',
#   'Virtue',
#   'WlbPsyc',
#   'WlbTot'},
#  'MARITAL': {'AffOth', 'AffTot', 'Kin@', 'Positiv', 'Pstv', 'Ritual'},
#  'MARRIAGE': {'AffOth',
#   'AffTot',
#   'Affil',
#   'Kin@',
#   'Positiv',
#   'Pstv',
#   'Ritual'},
#  'MARRY': {'AffGain',
#   'AffOth',
#   'AffTot',
#   'Affil',
#   'DAV',
#   'Kin@',
#   'Positiv',
#   'Pstv',
#   'SocRel'},
#  'MARVEL': {'Active', 'IAV', 'Ovrst', 'Positiv', 'Think'},
#  'MARVELOUS': {'IndAdj', 'PosAff', 'Positiv', 'Think', 'Virtue'},
#  'MASTERFUL': {'IndAdj', 'Know', 'Positiv', 'Power', 'Strong'},
#  'MASTERY': {'Know', 'Positiv', 'Strong'},
#  'MATCHLESS': {'IndAdj', 'Negate', 'Ovrst', 'Positiv'},
#  'MATE': {'AffGain',
#   'AffPt',
#   'AffTot',
#   'Affil',
#   'DAV',
#   'HU',
#   'Positiv',
#   'Pstv',
#   'Role',
#   'SocRel'},
#  'MATTER': {'ABS',
#   'COM',
#   'EVAL',
#   'EndsLw',
#   'IAV',
#   'Know',
#   'NegAff',
#   'Negativ',
#   'Ngtv',
#   'Ovrst',
#   'Positiv',
#   'Pstv',
#   'Solve',
#   'Strong',
#   'SureLw',
#   'Undrst',
#   'Vice'},
#  'MATURE': {'IAV',
#   'Increas',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Virtue'},
#  'MATURITY': {'ABS',
#   'Abs@',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'Strong',
#   'Time@'},
#  'MAXIMIZE': {'Active', 'IAV', 'Increas', 'Positiv'},
#  'MEANINGFUL': {'EVAL', 'EnlOth', 'EnlTot', 'Positiv', 'Pstv', 'Virtue'},
#  'MEASURABLE': {'IndAdj', 'Positiv', 'Quan'},
#  'MEDIATE': {'Active',
#   'ComForm',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'SocRel',
#   'Solve'},
#  'MEDITATION': {'Arousal', 'Positiv', 'Think'},
#  'MEET': {'Active',
#   'Affil',
#   'COM',
#   'ComForm',
#   'DAV',
#   'Exch',
#   'IAV',
#   'Positiv',
#   'PowCoop',
#   'PowTot',
#   'Pstv',
#   'Ritual',
#   'SocRel',
#   'Solve',
#   'TranLw',
#   'WltOth',
#   'WltTot'},
#  'MELLOW': {'Arousal', 'IndAdj', 'Positiv'},
#  'MELODY': {'COM',
#   'ComForm',
#   'Exprsv',
#   'Positiv',
#   'Pstv',
#   'SklAsth',
#   'SklToT'},
#  'MEMORABLE': {'Eval@', 'IndAdj', 'Positiv', 'Quality'},
#  'MEND': {'Active', 'IAV', 'Positiv', 'Pstv', 'TrnGain', 'Work'},
#  'MENTOR': {'HU', 'Know', 'Positiv', 'Power', 'Role'},
#  'MERCIFUL': {'IPadj', 'Positiv', 'Virtue'},
#  'MERCY': {'ABS', 'Abs@', 'AffGain', 'AffTot', 'Positiv', 'Pstv', 'Virtue'},
#  'MERIT': {'Affil',
#   'IAV',
#   'Positiv',
#   'Pstv',
#   'RspOth',
#   'RspTot',
#   'SocRel',
#   'Strong',
#   'Virtue'},
#  'MERITORIOUS': {'Econ@', 'Goal', 'IndAdj', 'Positiv', 'Virtue'},
#  'MERRILY': {'EMOT', 'Pleasur', 'Positiv'},
#  'MERRIMENT': {'EMOT', 'Pleasur', 'Positiv'},
#  ...}

# %% [markdown]
# # Calculating the Category Amount.
#
# Now that we have the data frame it is time to count how many of the words in the tweet belong to each category. However to calculate this for every single entry is very time intensive. Therefore we are going to collapse the entries by date and then calculate the algorthmn.
#
# ## Note:
# When matching with the dicitonary for LIWC all tokens are capitalized. This is to help speed up and simplifies the edge cases for the analysis.
#
# Depending on how large you dataset is, you could calculate the categories for each individual tweet. In order to do this simply comment out the first line in the code below.

# %%
# Collapsing the tokens by time_stamp (in this case by day)
# the agg specifies what to do with the other columns, in this case sum them up
CategoryTweetFrame = CategoryTweetFrame[["tokens", "count_tokens"]].groupby('time_stamp').agg({'tokens': 'sum', 'count_tokens':'sum'})

# Create save files as we calculate categories
create_save_section(100,CategoryTweetFrame , "CategoryTweetFrameSum", 3, "Tweet_Category")

# Load back the csvs (we don't need to convert the tokens again since we are done calculating)
# In this case since we are going to graph the results we are going to load them into a new dataframe
CategoryTweetFrame = loading_multiple_file_path("./Tweet_Category", list(range(0, len(["time_stamp","tokens","count_tokens"] + categories))), ["time_stamp","tokens","count_tokens"] + categories)

# Set the index
CategoryTweetFrame = CategoryTweetFrame.set_index("time_stamp")

# Resort the index (This is because we read from Mulitple Files)
CategoryTweetFrame.sort_index(inplace=True)

# Find the top category of each day as well
CategoryTweetFrame["top_category"] = CategoryTweetFrame.iloc[:,1:].idxmax(axis=1)

# See first 5 results
CategoryTweetFrame[:5]
# Out:
# Looking at section: 1
# Finish looking at section: 1
# Saving the section: 1 into csv
# Finish saving into ./Tweet_Category/CategoryTweetFrameSum_1.csv
# Looking at section: 2
# Finish looking at section: 2
# Saving the section: 2 into csv
# Finish saving into ./Tweet_Category/CategoryTweetFrameSum_2.csv
# Finised saving all the files into ./Tweet_Category/CategoryTweetFrameSum
# Begin reading .csv in ./Tweet_Category....
#
# Reading file: ./Tweet_Category/CategoryTweetFrameSum_2.csv....
# Reading file: ./Tweet_Category/CategoryTweetFrameSum_1.csv....
#
# Finished reading all files in ./Tweet_Category
#
# Merge all individual file dataframes together into a single dataframe...
#
# Finished merging all the files into a single dataframe.
#                                                        tokens  count_tokens  \
# time_stamp
# 2016-08-04  ['GamerGate', 'didn', 't', 'help', 'my', 'care...          6875
# 2016-08-05  ['Sigh', 'time', 'to', 'beat', 'the', 'dead', ...          7190
# 2016-08-06  ['@LINK', 'GamerGate', 'Because', 'most', 'of'...          6267
# 2016-08-07  ['@LINK', 'GamerGate', 'Gamers', 'Resurrected'...         10560
# 2016-08-08  ['The', 'GamerGate', 'word', 'for', 'today', '...          9189
#
#             Positiv  Negativ  Pstv  Affil  Ngtv  Hostile  Strong  Power  \
# time_stamp
# 2016-08-04      390      272   366    189   229      164     464    182
# 2016-08-05      387      302   363    201   251      206     478    219
# 2016-08-06      309      241   295    171   200      161     405    188
# 2016-08-07      520      442   488    246   373      286     700    314
# 2016-08-08      478      396   455    250   332      233     630    300
#
#                 ...       Nation  Anomie  NegAff  PosAff  SureLw  If  NotLw  \
# time_stamp      ...
# 2016-08-04      ...            7       0      49      71     156   0      0
# 2016-08-05      ...           14       1      44      85     127   0      0
# 2016-08-06      ...           17       2      48      75     140   0      0
# 2016-08-07      ...           14       2      82     104     242   0      0
# 2016-08-08      ...           13       0      70      90     219   0      0
#
#             TimeSpc  FormLw  top_category
# time_stamp
# 2016-08-04        0       0  count_tokens
# 2016-08-05        0       0  count_tokens
# 2016-08-06        0       0  count_tokens
# 2016-08-07        0       0  count_tokens
# 2016-08-08        0       0  count_tokens
#
# [5 rows x 185 columns]

# %% [markdown]
# # Plotting the Results
#
# Now that we have the amount of each category for every tweet sorted by date. We can now graph it to see the overall change during this period of time. For starters lets plot both the postive and negative percent amounts. You can switch out the categories for any you prefer.

# %%
# Save over the columns we want
CategoryTweetGraphFrame = CategoryTweetFrame[["count_tokens","Positiv","Negativ"]].copy()

# Calulate percent of Positiv and Negativ when compared to total amount of tokens that day
# This is done by dividing the category amount with total amount of tweet (*100 to get a percent)
CategoryTweetGraphFrame["percent_Positiv"] = (CategoryTweetGraphFrame["Positiv"] / CategoryTweetGraphFrame["count_tokens"]) * 100
CategoryTweetGraphFrame["percent_Negativ"] = (CategoryTweetGraphFrame["Negativ"] / CategoryTweetGraphFrame["count_tokens"]) * 100

# Plotting both the postive and negative category percentage
for columns in CategoryTweetGraphFrame[["percent_Positiv", "percent_Negativ"]]:
    basic_plot_generator(columns, CategoryTweetGraphFrame.index, CategoryTweetGraphFrame, intervalValue= 3)

# %% [markdown]
# # Plotting Different LIWC Category Against Eachother
#
# Now that we have the values in each category. We can plot different categories against eachother

# %%
# Ploting Negativ and Postiv against one another in the same graph
plot_compare_generator(['percent_Positiv', 'percent_Negativ'], CategoryTweetGraphFrame.index, CategoryTweetGraphFrame, intervalValue= 3, saveImage=True, fileName="Pos_Neg_Compare")

# %% [markdown]
# # Conclusion
#
# In this IPython Notebook we went over a wide varity of data manipulation and analysis. From tokenizing the text, word count, extracting hashtag and content analysis.
#
# This IPython Notebook provides a foundation for future research. It also written in a modular format to allow for easy code modification to adapt this IPython Notebook to fit other datasets. Although some aspect are exclusive to the example dataset (column names), all the functionality had been purposely made generic to be transferable for other use (MasterTweetFrame is a generic name).
