# %%
# Finding topics of interest by using the filtering capablities it offers.
import twitter
import json
import sys
import csv

csvfile = open('metoochina.csv','a')
csvwriter = csv.writer(csvfile)
 
# == OAuth Authentication ==
# The consumer keys can be found on your application's Details
# page located at https://dev.twitter.com/apps (under "Keys and tokens")
 # PUT YOUR KEYS AND SECRETS IN HERE, IT WONT WORK WITHOUT YOUR KEYS FROM TWITTER !!!!!
consumer_key="WRzrHerkO3PQFE9PsbOSVJxUO"
consumer_secret="l2F8owgWRm33SeK7ts5Vs6yBU3Qd2FbXzVoM2x9k0BFsXbqLfr"
 
# After the step above, you will be redirected to your app's page.
# Create an access token under the the "Your access token" section
access_token="527454179-JZ7zT9M4jgffQYqn3SG7W1z3UdphCT5irgXI96Qa"
access_token_secret="Ljtj25dztSwJ4OGs2IfB2vkGhdghmvZl4cLMSkCssKxnJ"
 
auth = twitter.oauth.OAuth(access_token, access_token_secret,consumer_key, consumer_secret)
twitter_api = twitter.Twitter(auth=auth)
# Query terms
q = '#metoo' 
# Comma-separated list of terms, start with something busy to test your script, then once you know its working put your hashtags in, max 400 tags
print >> sys.stderr, 'Filtering the public timeline for track="%s"' % (q,)
# Reference the self.auth parameter
twitter_stream = twitter.TwitterStream(auth=twitter_api.auth)
# See https://dev.twitter.com/docs/streaming-apis
stream = twitter_stream.statuses.filter(track=q)
# For illustrative purposes, when all else fails, search for a relevant topic such as Madonna
# and something is sure to turn up (at least, on Twitter)
# note that stream is a special never ending list so this loops non stop
# to stop it type CMD-C at the terminal where its running
for tweet in stream:
	# what is this thing called a tweet?
	# its a structured object in JSON format. We can treat this as a python dictionary - http://learnpythonthehardway.org/book/ex39.html
	# sometimes it helps to dump an entire tweet using the line below so you can see the names of the fields
	# print json.dumps(tweet, indent=1')
	print tweet['text']
	
	csvwriter.writerow([tweet['text'].encode('utf-8'),tweet['user']['screen_name'].encode('utf-8'),tweet['created_at']])
# Out:
# Filtering the public timeline for track="#metoo"
# RT @srecordati: Le nostre ragazze insultate sulla pagina Facebook del ministro dell'interno per aver manifestato a Milano. Sono indignata,…
# @thehill @IvankaTrump https://t.co/shtMOHfnsV
# RT @NinerNabs49: @AdmiralRodgers @Alyssa_Milano @MichaelAvenatti She's a huge fraud. She sat there a few rows behind Kavanaugh as he defend…
# Overheard a lawyer in the lift lamenting the “dearth of jokes these days”, now he doesn’t know what’s acceptable an… https://t.co/8778MBKivM
# There are not Obama judges, or Trump judges. There's just judges who sexually abuse women and those who don't.… https://t.co/Csp47JGKlp
# RT @B52Malmet: I give thanks this #Thanksgiving to #ChristineBlaseyFord for being a brave voice for all women who have had our mouths cover…
# RT @shelleypetersen: #Tekashi69's team are now taking down all comments pertaining to his sex offender status which saw him make child porn…
# #touch #intimacy #appropriatetouch #metoo #metoomovement #ourbodiesourselves #molestation #incest #pedosexual… https://t.co/FQASd9wZhW
# @renato_mariotti @GomezSantos22 @AP A challenge 2 print journalists: Use all the following words to describe… https://t.co/6sBJGrE2w0
# Hycklare!
# RT @MAGAREX1: I note however that it's easy $ for the parasites that hang around the #MeToo movement, ginning up hysteria and fear about ra…
# RT @MAGAREX1: 'Intimacy Directors'.
#
# No different than priests &amp; nuns who patrolled school dances, regulating behavior between boys and gir…
# @piersmorgan Sexual harassment and sexual assault has nothing to do with masculinity. #MeToo and #TimesUp have call… https://t.co/4fKJYgOzZN
# RT @akgulelif: Bu hafta @cicektahaoglu ve @b__yaz @bianet_org ten istifa ettiğini duyurmuştu. Ben 6 yıl boyunca büyük heyecanla yaptığım if…
# @pena_matthew @MoczyTV @MattDRamirez #MeToo
# @renato_mariotti @GomezSantos22 @AP A challenge 2 print journalists: Use all the following words to describe… https://t.co/TWYEmECSsM
# RT @EvolvingInside: Healing Trauma takes time, less time if you know what to do...
# Took me years... So I got me the qualifications I needed…
# #MeToo
# RT @worrynet: 이 기사에 달린 댓글 중 하나가 정말 인상적이다. "태론, 너는 밤에 주차한 자동차까지 걸어가는 동안 손가락 사이에 열쇠를 끼우고 걸어가나? 내가 아는 여자들은 혹시나 남자가 공격할까봐 그러고 그걸 딸들에게 가르친다. 네가…
# Säg upp dig du också och syssla med något som passar dig. sopgubbe eller nåt.
# @Tefftchippersun @MrWilliamJSmith @carlruiz #MeToo
# @CNNSitRoom @Susan_Hennessey @Acosta I suspect Trump is waiting for Kavanaugh to speak out in support of the President #BlueWave #metoo
# RT @KaceyKells: KELLCEY, by Kacey Kells, is available all over the world on AMAZON, BARNES &amp; NOBLE, ABEBOOKS, ALIBRIS, BLACKWELL'S.....…
# RT @B52Malmet: I give thanks this #Thanksgiving to #ChristineBlaseyFord for being a brave voice for all women who have had our mouths cover…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f496df7b21ba> in <module>()
#      34 # note that stream is a special never ending list so this loops non stop
#      35 # to stop it type CMD-C at the terminal where its running
# ---> 36 for tweet in stream:
#      37         # what is this thing called a tweet?
#      38         # its a structured object in JSON format. We can treat this as a python dictionary - http://learnpythonthehardway.org/book/ex39.html
#
# /Users/zjm/anaconda/lib/python2.7/site-packages/twitter/stream.pyc in __iter__(self)
#     175             # Decode all the things:
#     176             try:
# --> 177                 data = sock_reader.read()
#     178             except SSLError:
#     179                 yield Hangup
#
# /Users/zjm/anaconda/lib/python2.7/site-packages/twitter/stream.pyc in read(self)
#     131     def read(self):
#     132         try:
# --> 133             ready_to_read = select.select([self.sock], [], [], self.sock_timeout)[0]
#     134             if ready_to_read:
#     135                 return self.sock.read()
#
# KeyboardInterrupt:
