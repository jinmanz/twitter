# %%
import csv
from collections import defaultdict

f = open("tokens.txt", "r")
text = f.read()
text_clean = ''.join([i for i in text if not i.isdigit()])

# %%
text_clean = text_clean.replace("'", " ")
text_clean = text_clean.replace("(", "")
text_clean = text_clean.replace(")","")
text_clean = text_clean.replace(",","")
text_clean = text_clean.replace("「","")
text_clean = text_clean.replace("."," ")
text_clean = text_clean.replace("#"," ")
text_clean = text_clean.replace("   "," ")
text_clean = text_clean.replace("  "," ")
text_clean
# Out:
# '[ METOO LINK  TWITTER COM PIC 中国 运动 性骚扰 女性 性侵 说 MENTION 事件 中 指控 美国 兔 米 CHINA 侵 受害者 社会 想 媒体 泛亚 强奸 年 做 女 性 朱军 女人 男性 暴力 法律 证据 支持 月 IN 事情 女生 女权 调查 男 里 圈 站 缺 た "" 郭文贵 骚扰 前 学生 发生 真的 男人 P 这是 微博 韩国 性别 政府 勇敢 疫苗 政治 话题 遭 国家 侵害 全球 新闻 事 一名 教授 时 自由 有人 岳昕 岁 日 网路 舆论 PICOTARO 丑闻 朋友 反 讲 发声 关注 卡瓦 举报 台湾 ️ 反性 希望 名 曝光 包括 记者 新 受害人 讨论 持续 太 报道 老师 BBC 北大 世界 想法 THE 公开 保护 香港 日本 诺 公益 XIJINPING 侵案 GOOGLE 刘瑜 内容 METOOCHINA 好莱坞 经历 系 故事 走 龙泉寺 武器 大法官 成 CNN 揭露 感到 权力 名人 学诚 FT ME 解决问题 习近平 WTO 适合 员工 一位 唔 受 RT 沉默 搞 当事人 人类 官骗 ABC AFP 良心 彭丽媛 云南 NOTEARSFORARIANA HAPPYEVERAFTER あ な に し HEATWAVE FILMSTRUCK  伤害 警方 国内 活动 情况 请 公司 爆 时间 主持人 文章 遭受 电视 相关 发起 一种 佢 OF 谈 当年 影响 男女 面对 社交 \\\\UB 两个 打压 人士 多名 本质 董瑶琼 TRUMP TOO 起诉 案件 转 有罪 法官 发现 喜欢 🤣 参与 😂 厉害 时代 瑞典 写 FOXNEWSUS 人权 噗 自杀 威胁 态度 TO 平等 中文 利用 控诉 女星 报警 同学 视频 央视 MYTAUCKLAND 公知 嘅 手 最新 年前 职场 反对 越来越 直播  大陆 发酵 声音 最终 一路 福特 揭发 弦子 释 圈公知 意识 关系 迷 回应 女子 国际 NEWS 只能 教育 父权 权利 特别 文化 专访 打破 风暴 称 终于 维权 信息 审查 实名 魔鬼 原因 REUTERS 改变 发展 淫秽 非礼 侵犯  AND 尊重 教练 地方 女士 可怕 证明 感觉 拒绝  知名 纽约 性侵犯 学院 METOOMATTERS 猥亵 自我 攻击 GETONBOARDQLD UWWC THEBACHELORAU 展开 逼 转发 最初 TVB WORLDNEWS ZTE 找 WOMANY 大学 今日 路 同意 环境 多年 浪潮 席卷 ON 选择 平台 涉嫌 民主 S 先 制造 伊藤 诗织 过程 真 正确 BY 辞职 点 一带 记得 力量 版 年轻 女权运动 正义 目的 性丑闻 诺贝尔文学奖 女孩 著名 生活 策划者 我成 残疾人 威望 摸 贸易战 SINA 早点 言论 告诉 引导 机构 被控 玩 机会 一点 刘强 贴 \\\\UD 反抗 确实 质疑 骚 受害 印度 鼓励 端 经验 公共 去年 微博上 删除 警察 公众 自由派 听 MASTERCHEFAU NEWS CROENG 😊 唐人 醒 一年 事实 律师 之际 推定 爆发 死 群体 想要 风潮 提出 成功 越 I 话 法院 平权 视为 投诉 提名 教会 深度 传媒 ⋯ 观点 遭遇 公布 指 一场 勇气 妇女 孩子 北京 标签 移民 爆出 MUFC NEWS GOOGLEPAY 声明 背后 KOSAKA DAIMAO 意味着 拦截 坚信 屈服于 困惑 发起人 难以 坐 HUAWEI PANDA RFI CCTV UN  美中 新华社 至少 钮承泽 案  学校 禁止 名单 东 无罪 男生 制度  式 小姐 报告 听证会 MEDIA 假 郭 VIA 工作 错 SOUTHKOREA 司法 引发  心理 中共 渣 这件 之间 领袖 烂 V 号 羞辱 导演 倒 YAMATO FAIRFUNDINGNOW 本来 PLANNING 体制 爆料 不到 推 著 价值 一篇 道德 呼吁 承认 代表 报 性骚 跑 实在 恶心 感受 IS 比尔 全美 令  男士 定罪 罪 MORE 强制 问 几个 权益 赌 宗教 容忍 WOMEN INITIUM 传播 推特 地位 马蕊 颁发 现实 麦烧 国 女儿 传统 担心 🙈 老子 两名 谴责 不知 收到 家庭 昨天 佛教 姑娘 网民 MACMILLER RIPMAC RISEFORCLIMATE 笑 BTSPORTSCORE CRAZYRICHASIANS 曝 当局 印象 想到 近日 交易 强奸犯 正 恶意 UNIVERSITY 进化 北大学生 高岩 THURSDAYTHOUGHTS 抗议 影片 令人 后续 性暴力 NO 案例 概念 提供 偏见 SEXUAL 说话 定义 图片 唯一 精神 东西 X 男子 近期 犯罪 – 挺 南韩 理解 好好 砸锅 离职 估计 NEW 找到 记录 字 没想到 一周年 帮 高 母亲 接受 表达 官员 文学奖 类似 回家 老婆 • 文字 明白 被迫 女权主义者 惹 任何人  也许 之声 知识分子 CBS 推友 空调 办公室 悉尼 经济 内部 评论 封 女方 荡妇 党 \\\\U 途径 演员 林 穿 义大利 基多 恩斯 匿名 删帖 和谐 方式 几天 走过 主意 PIKOTARO 蹭 法治 沈梦雨 纷纷 章文 禁 爆性 张鹏 关键 总统 整理 支持者 抱 中心 蔓延 不当 标准 喊 歧视 未 FB 小时 纽约时报 被告 这位 值得 懂 控制 郭文鬼 买 不该 约 突破 网友 指证 涉及 妳 身上 议员 感谢 乐园 期间 是因为 ♀ 觉醒 组织 分 事后 愤怒 更是 早就 嘉宾 美 细节 技巧 对抗 解决 生 男孩 原则 两位 作证 大部分 ASIA 抓 上任 女权主义 考斯比  微信 导致 一生 大佬 服务 封杀 QANDA SKODAINDIA AFLSWANSGIANTS 资料 线 PAYPAL CASHAPP 领导 推上 项目 一部 政策 女作家 文 韦 年龄 元 YOU 个体 校方 女弟子 政庇 被害人 延烧 调情 盛行 指责 作家 METOOINCHINA 住持 转载 撕裂 下药 迷奸 肯定 有没有 屏蔽 密歇根 睡 总 🏃 教友 梦 裁决 图 各国 进展 喝 网站 虐待 不想 ─ TAIWAN 证实 完 身边 状况 身为 女演员 博士 网路上 意见 网上 被判 笑话 压力 电影 THIS 历史 讲句 提到 外国 法庭 责任 运动员 报复 逻辑 特权 告 同事 语言 称为 词 声援 校园 北京大学 压制 远 日前 性爱 方法 性行为 青年 作者 左 参议院 法国 高管 权势 CHINESE  保守派 全文 见到 CHURCHTOO 涉性 级别 老板 胶事 拍 寻找 恶 被删 这场 真系 资深 妈妈 人性 变化 末日 掀起 批评 痛苦 TAG 能力 早报 负责 一步 共和党 多久 扯 一条 穿着 节目 应诉 不让 MATTERS 办法 合作 派  一句 阻止 带来 真相 提起 提醒 今晚 程度 T 未来 ARGENTO 国外 正式 男星 道歉 未遂 挑战 官方 机制 讲述 白宫 毁掉 抹黑 金盛 集团 秘书 邓飞 内地 下台 BE 做出 声势浩大 立案 蒋方舟 院长 WEIBO 看过 兴起 人生  差别 坦 封锁 会长 衣服 电梯 敏感 少女 海外 傻 鄢烈山 好像 清华 转移 SEE 圈子 屁股 果酱 字幕组 不堪 想起 对不起 张紫妍 圈性  春树 阴谋 中山大学 纽约州 摩根 最严 黄粱美梦 罪行累累 凌辱 爆尿 一身 PEKING 陪审团 麦当劳 走向 原本 种种 变态 困境 ⬇ 我会 忍受 分享 风起云涌 周二 倾向 厕所 增加 推动 NOTME 出面 达 HARASSMENT 投票 可惜 更大 少 所有人 期望 形容 手机 吕丽瑶 作用 独立 利益 完美 HK  不错 判断 HOW 群众 咁 佳士 嫌疑人 内心 强 港闻 早前 个案 重视 消灭 罢工 高层 简单 知识 妹妹 身体 借用 完整 上帝 包庇 占 一半 刘 算是 胶事录 POST 家 博客 回避 全记录 判刑 随便 时报 知名人士 影响力 人类学 民主党 真实 幸存者 学会 核心 儿子 现象 李偲嫣 妈 女强人 恐怖 性质 讽刺 UP 应 最高法院 候选人 非 工作人员 男友 这一 时刻 里程碑 谋杀 邀请 链接 说出 卷入 这才 好友 声称 主持 舒服 强奸案 争议 提告 ▍ 晚上 🤔 警告 红利 巨婴 成员 互联网 暴露 作品 意义 👇 人数 九点 维护 救济 超级 昨日 分裂 如火如荼 诉讼 反思 脸 放 好多 上诉 起诉书 危险 罪犯 第一个 喜剧演员 监狱 加拿大 实施 第一次 目标 反省 李 公开信 意愿 一会 造谣 飞机 留言 ANZSPM 免费 韩 隐忍 吃 行业 施害 天 来源 YOUR 惩罚 和尚 骂 新浪 受伤 豆瓣 事实上 副 睇 ACTIVIST ACCUSED 传出 哈维 采访 强吻 史 热 安熙 发布 结束 剩下 游行 回去 主流 偷拍 面前 文明 发 明明 每次 发挥 牧师 B 想想 争论 系列 民运 CENSORED 备受 神 赢 委屈 怀疑 发出 视线 TOP STORY 肉 结构 你国 答案 作出 民事诉讼 启发  民众 腿 贺卫方 学者 赵秉志 立法 一向  恐吓 WEINSTEIN 高校 德语 认罪 卢贝松 倪立贤 源头 联合国 房思琪 初恋 站队 演艺圈 YES 被害者 公民 ㄋ ㄟ 医生 同性恋   伸出 知 挂 重点  ...

# %%
token_li = text_clean.split(" ")
token_li
# Out:
# ['[',
#  'METOO',
#  'LINK',
#  '',
#  'TWITTER',
#  'COM',
#  'PIC',
#  '中国',
#  '运动',
#  '性骚扰',
#  '女性',
#  '性侵',
#  '说',
#  'MENTION',
#  '事件',
#  '中',
#  '指控',
#  '美国',
#  '兔',
#  '米',
#  'CHINA',
#  '侵',
#  '受害者',
#  '社会',
#  '想',
#  '媒体',
#  '泛亚',
#  '强奸',
#  '年',
#  '做',
#  '女',
#  '性',
#  '朱军',
#  '女人',
#  '男性',
#  '暴力',
#  '法律',
#  '证据',
#  '支持',
#  '月',
#  'IN',
#  '事情',
#  '女生',
#  '女权',
#  '调查',
#  '男',
#  '里',
#  '圈',
#  '站',
#  '缺',
#  'た',
#  '""',
#  '郭文贵',
#  '骚扰',
#  '前',
#  '学生',
#  '发生',
#  '真的',
#  '男人',
#  'P',
#  '这是',
#  '微博',
#  '韩国',
#  '性别',
#  '政府',
#  '勇敢',
#  '疫苗',
#  '政治',
#  '话题',
#  '遭',
#  '国家',
#  '侵害',
#  '全球',
#  '新闻',
#  '事',
#  '一名',
#  '教授',
#  '时',
#  '自由',
#  '有人',
#  '岳昕',
#  '岁',
#  '日',
#  '网路',
#  '舆论',
#  'PICOTARO',
#  '丑闻',
#  '朋友',
#  '反',
#  '讲',
#  '发声',
#  '关注',
#  '卡瓦',
#  '举报',
#  '台湾',
#  '️',
#  '反性',
#  '希望',
#  '名',
#  '曝光',
#  '包括',
#  '记者',
#  '新',
#  '受害人',
#  '讨论',
#  '持续',
#  '太',
#  '报道',
#  '老师',
#  'BBC',
#  '北大',
#  '世界',
#  '想法',
#  'THE',
#  '公开',
#  '保护',
#  '香港',
#  '日本',
#  '诺',
#  '公益',
#  'XIJINPING',
#  '侵案',
#  'GOOGLE',
#  '刘瑜',
#  '内容',
#  'METOOCHINA',
#  '好莱坞',
#  '经历',
#  '系',
#  '故事',
#  '走',
#  '龙泉寺',
#  '武器',
#  '大法官',
#  '成',
#  'CNN',
#  '揭露',
#  '感到',
#  '权力',
#  '名人',
#  '学诚',
#  'FT',
#  'ME',
#  '解决问题',
#  '习近平',
#  'WTO',
#  '适合',
#  '员工',
#  '一位',
#  '唔',
#  '受',
#  'RT',
#  '沉默',
#  '搞',
#  '当事人',
#  '人类',
#  '官骗',
#  'ABC',
#  'AFP',
#  '良心',
#  '彭丽媛',
#  '云南',
#  'NOTEARSFORARIANA',
#  'HAPPYEVERAFTER',
#  'あ',
#  'な',
#  'に',
#  'し',
#  'HEATWAVE',
#  'FILMSTRUCK',
#  '',
#  '伤害',
#  '警方',
#  '国内',
#  '活动',
#  '情况',
#  '请',
#  '公司',
#  '爆',
#  '时间',
#  '主持人',
#  '文章',
#  '遭受',
#  '电视',
#  '相关',
#  '发起',
#  '一种',
#  '佢',
#  'OF',
#  '谈',
#  '当年',
#  '影响',
#  '男女',
#  '面对',
#  '社交',
#  '\\\\UB',
#  '两个',
#  '打压',
#  '人士',
#  '多名',
#  '本质',
#  '董瑶琼',
#  'TRUMP',
#  'TOO',
#  '起诉',
#  '案件',
#  '转',
#  '有罪',
#  '法官',
#  '发现',
#  '喜欢',
#  '🤣',
#  '参与',
#  '😂',
#  '厉害',
#  '时代',
#  '瑞典',
#  '写',
#  'FOXNEWSUS',
#  '人权',
#  '噗',
#  '自杀',
#  '威胁',
#  '态度',
#  'TO',
#  '平等',
#  '中文',
#  '利用',
#  '控诉',
#  '女星',
#  '报警',
#  '同学',
#  '视频',
#  '央视',
#  'MYTAUCKLAND',
#  '公知',
#  '嘅',
#  '手',
#  '最新',
#  '年前',
#  '职场',
#  '反对',
#  '越来越',
#  '直播',
#  '',
#  '大陆',
#  '发酵',
#  '声音',
#  '最终',
#  '一路',
#  '福特',
#  '揭发',
#  '弦子',
#  '释',
#  '圈公知',
#  '意识',
#  '关系',
#  '迷',
#  '回应',
#  '女子',
#  '国际',
#  'NEWS',
#  '只能',
#  '教育',
#  '父权',
#  '权利',
#  '特别',
#  '文化',
#  '专访',
#  '打破',
#  '风暴',
#  '称',
#  '终于',
#  '维权',
#  '信息',
#  '审查',
#  '实名',
#  '魔鬼',
#  '原因',
#  'REUTERS',
#  '改变',
#  '发展',
#  '淫秽',
#  '非礼',
#  '侵犯',
#  '',
#  'AND',
#  '尊重',
#  '教练',
#  '地方',
#  '女士',
#  '可怕',
#  '证明',
#  '感觉',
#  '拒绝',
#  '',
#  '知名',
#  '纽约',
#  '性侵犯',
#  '学院',
#  'METOOMATTERS',
#  '猥亵',
#  '自我',
#  '攻击',
#  'GETONBOARDQLD',
#  'UWWC',
#  'THEBACHELORAU',
#  '展开',
#  '逼',
#  '转发',
#  '最初',
#  'TVB',
#  'WORLDNEWS',
#  'ZTE',
#  '找',
#  'WOMANY',
#  '大学',
#  '今日',
#  '路',
#  '同意',
#  '环境',
#  '多年',
#  '浪潮',
#  '席卷',
#  'ON',
#  '选择',
#  '平台',
#  '涉嫌',
#  '民主',
#  'S',
#  '先',
#  '制造',
#  '伊藤',
#  '诗织',
#  '过程',
#  '真',
#  '正确',
#  'BY',
#  '辞职',
#  '点',
#  '一带',
#  '记得',
#  '力量',
#  '版',
#  '年轻',
#  '女权运动',
#  '正义',
#  '目的',
#  '性丑闻',
#  '诺贝尔文学奖',
#  '女孩',
#  '著名',
#  '生活',
#  '策划者',
#  '我成',
#  '残疾人',
#  '威望',
#  '摸',
#  '贸易战',
#  'SINA',
#  '早点',
#  '言论',
#  '告诉',
#  '引导',
#  '机构',
#  '被控',
#  '玩',
#  '机会',
#  '一点',
#  '刘强',
#  '贴',
#  '\\\\UD',
#  '反抗',
#  '确实',
#  '质疑',
#  '骚',
#  '受害',
#  '印度',
#  '鼓励',
#  '端',
#  '经验',
#  '公共',
#  '去年',
#  '微博上',
#  '删除',
#  '警察',
#  '公众',
#  '自由派',
#  '听',
#  'MASTERCHEFAU',
#  'NEWS',
#  'CROENG',
#  '😊',
#  '唐人',
#  '醒',
#  '一年',
#  '事实',
#  '律师',
#  '之际',
#  '推定',
#  '爆发',
#  '死',
#  '群体',
#  '想要',
#  '风潮',
#  '提出',
#  '成功',
#  '越',
#  'I',
#  '话',
#  '法院',
#  '平权',
#  '视为',
#  '投诉',
#  '提名',
#  '教会',
#  '深度',
#  '传媒',
#  '⋯',
#  '观点',
#  '遭遇',
#  '公布',
#  '指',
#  '一场',
#  '勇气',
#  '妇女',
#  '孩子',
#  '北京',
#  '标签',
#  '移民',
#  '爆出',
#  'MUFC',
#  'NEWS',
#  'GOOGLEPAY',
#  '声明',
#  '背后',
#  'KOSAKA',
#  'DAIMAO',
#  '意味着',
#  '拦截',
#  '坚信',
#  '屈服于',
#  '困惑',
#  '发起人',
#  '难以',
#  '坐',
#  'HUAWEI',
#  'PANDA',
#  'RFI',
#  'CCTV',
#  'UN',
#  '',
#  '美中',
#  '新华社',
#  '至少',
#  '钮承泽',
#  '案',
#  '',
#  '学校',
#  '禁止',
#  '名单',
#  '东',
#  '无罪',
#  '男生',
#  '制度',
#  '',
#  '式',
#  '小姐',
#  '报告',
#  '听证会',
#  'MEDIA',
#  '假',
#  '郭',
#  'VIA',
#  '工作',
#  '错',
#  'SOUTHKOREA',
#  '司法',
#  '引发',
#  '',
#  '心理',
#  '中共',
#  '渣',
#  '这件',
#  '之间',
#  '领袖',
#  '烂',
#  'V',
#  '号',
#  '羞辱',
#  '导演',
#  '倒',
#  'YAMATO',
#  'FAIRFUNDINGNOW',
#  '本来',
#  'PLANNING',
#  '体制',
#  '爆料',
#  '不到',
#  '推',
#  '著',
#  '价值',
#  '一篇',
#  '道德',
#  '呼吁',
#  '承认',
#  '代表',
#  '报',
#  '性骚',
#  '跑',
#  '实在',
#  '恶心',
#  '感受',
#  'IS',
#  '比尔',
#  '全美',
#  '令',
#  '',
#  '男士',
#  '定罪',
#  '罪',
#  'MORE',
#  '强制',
#  '问',
#  '几个',
#  '权益',
#  '赌',
#  '宗教',
#  '容忍',
#  'WOMEN',
#  'INITIUM',
#  '传播',
#  '推特',
#  '地位',
#  '马蕊',
#  '颁发',
#  '现实',
#  '麦烧',
#  '国',
#  '女儿',
#  '传统',
#  '担心',
#  '🙈',
#  '老子',
#  '两名',
#  '谴责',
#  '不知',
#  '收到',
#  '家庭',
#  '昨天',
#  '佛教',
#  '姑娘',
#  '网民',
#  'MACMILLER',
#  'RIPMAC',
#  'RISEFORCLIMATE',
#  '笑',
#  'BTSPORTSCORE',
#  'CRAZYRICHASIANS',
#  '曝',
#  '当局',
#  '印象',
#  '想到',
#  '近日',
#  '交易',
#  '强奸犯',
#  '正',
#  '恶意',
#  'UNIVERSITY',
#  '进化',
#  '北大学生',
#  '高岩',
#  'THURSDAYTHOUGHTS',
#  '抗议',
#  '影片',
#  '令人',
#  '后续',
#  '性暴力',
#  'NO',
#  '案例',
#  '概念',
#  '提供',
#  '偏见',
#  'SEXUAL',
#  '说话',
#  '定义',
#  '图片',
#  '唯一',
#  '精神',
#  '东西',
#  'X',
#  '男子',
#  '近期',
#  '犯罪',
#  '–',
#  '挺',
#  '南韩',
#  '理解',
#  '好好',
#  '砸锅',
#  '离职',
#  '估计',
#  'NEW',
#  '找到',
#  '记录',
#  '字',
#  '没想到',
#  '一周年',
#  '帮',
#  '高',
#  '母亲',
#  '接受',
#  '表达',
#  '官员',
#  '文学奖',
#  '类似',
#  '回家',
#  '老婆',
#  '•',
#  '文字',
#  '明白',
#  '被迫',
#  '女权主义者',
#  '惹',
#  '任何人',
#  '',
#  '也许',
#  '之声',
#  '知识分子',
#  'CBS',
#  '推友',
#  '空调',
#  '办公室',
#  '悉尼',
#  '经济',
#  '内部',
#  '评论',
#  '封',
#  '女方',
#  '荡妇',
#  '党',
#  '\\\\U',
#  '途径',
#  '演员',
#  '林',
#  '穿',
#  '义大利',
#  '基多',
#  '恩斯',
#  '匿名',
#  '删帖',
#  '和谐',
#  '方式',
#  '几天',
#  '走过',
#  '主意',
#  'PIKOTARO',
#  '蹭',
#  '法治',
#  '沈梦雨',
#  '纷纷',
#  '章文',
#  '禁',
#  '爆性',
#  '张鹏',
#  '关键',
#  '总统',
#  '整理',
#  '支持者',
#  '抱',
#  '中心',
#  '蔓延',
#  '不当',
#  '标准',
#  '喊',
#  '歧视',
#  '未',
#  'FB',
#  '小时',
#  '纽约时报',
#  '被告',
#  '这位',
#  '值得',
#  '懂',
#  '控制',
#  '郭文鬼',
#  '买',
#  '不该',
#  '约',
#  '突破',
#  '网友',
#  '指证',
#  '涉及',
#  '妳',
#  '身上',
#  '议员',
#  '感谢',
#  '乐园',
#  '期间',
#  '是因为',
#  '♀',
#  '觉醒',
#  '组织',
#  '分',
#  '事后',
#  '愤怒',
#  '更是',
#  '早就',
#  '嘉宾',
#  '美',
#  '细节',
#  '技巧',
#  '对抗',
#  '解决',
#  '生',
#  '男孩',
#  '原则',
#  '两位',
#  '作证',
#  '大部分',
#  'ASIA',
#  '抓',
#  '上任',
#  '女权主义',
#  '考斯比',
#  '',
#  '微信',
#  '导致',
#  '一生',
#  '大佬',
#  '服务',
#  '封杀',
#  'QANDA',
#  'SKODAINDIA',
#  'AFLSWANSGIANTS',
#  '资料',
#  '线',
#  'PAYPAL',
#  'CASHAPP',
#  '领导',
#  '推上',
#  '项目',
#  '一部',
#  '政策',
#  '女作家',
#  '文',
#  '韦',
#  '年龄',
#  '元',
#  'YOU',
#  '个体',
#  '校方',
#  '女弟子',
#  '政庇',
#  '被害人',
#  '延烧',
#  '调情',
#  '盛行',
#  '指责',
#  '作家',
#  'METOOINCHINA',
#  '住持',
#  '转载',
#  '撕裂',
#  '下药',
#  '迷奸',
#  '肯定',
#  '有没有',
#  '屏蔽',
#  '密歇根',
#  '睡',
#  '总',
#  '🏃',
#  '教友',
#  '梦',
#  '裁决',
#  '图',
#  '各国',
#  '进展',
#  '喝',
#  '网站',
#  '虐待',
#  '不想',
#  '─',
#  'TAIWAN',
#  '证实',
#  '完',
#  '身边',
#  '状况',
#  '身为',
#  '女演员',
#  '博士',
#  '网路上',
#  '意见',
#  '网上',
#  '被判',
#  '笑话',
#  '压力',
#  '电影',
#  'THIS',
#  '历史',
#  '讲句',
#  '提到',
#  '外国',
#  '法庭',
#  '责任',
#  '运动员',
#  '报复',
#  '逻辑',
#  '特权',
#  '告',
#  '同事',
#  '语言',
#  '称为',
#  '词',
#  '声援',
#  '校园',
#  '北京大学',
#  '压制',
#  '远',
#  '日前',
#  '性爱',
#  '方法',
#  '性行为',
#  '青年',
#  '作者',
#  '左',
#  '参议院',
#  '法国',
#  '高管',
#  '权势',
#  'CHINESE',
#  '',
#  '保守派',
#  '全文',
#  '见到',
#  'CHURCHTOO',
#  '涉性',
#  '级别',
#  '老板',
#  '胶事',
#  '拍',
#  '寻找',
#  '恶',
#  '被删',
#  '这场',
#  '真系',
#  '资深',
#  '妈妈',
#  '人性',
#  '变化',
#  '末日',
#  '掀起',
#  '批评',
#  '痛苦',
#  'TAG',
#  '能力',
#  '早报',
#  '负责',
#  '一步',
#  '共和党',
#  '多久',
#  '扯',
#  '一条',
#  '穿着',
#  '节目',
#  '应诉',
#  '不让',
#  'MATTERS',
#  '办法',
#  '合作',
#  '派',
#  '',
#  '一句',
#  '阻止',
#  '带来',
#  '真相',
#  '提起',
#  '提醒',
#  '今晚',
#  '程度',
#  'T',
#  '未来',
#  'ARGENTO',
#  '国外',
#  '正式',
#  '男星',
#  '道歉',
#  '未遂',
#  '挑战',
#  '官方',
#  '机制',
#  '讲述',
#  '白宫',
#  '毁掉',
#  '抹黑',
#  '金盛',
#  '集团',
#  '秘书',
#  '邓飞',
#  '内地',
#  '下台',
#  'BE',
#  '做出',
#  '声势浩大',
#  '立案',
#  '蒋方舟',
#  '院长',
#  'WEIBO',
#  '看过',
#  '兴起',
#  '人生',
#  '',
#  '差别',
#  '坦',
#  '封锁',
#  '会长',
#  '衣服',
#  '电梯',
#  '敏感',
#  '少女',
#  '海外',
#  '傻',
#  '鄢烈山',
#  '好像',
#  '清华',
#  '转移',
#  'SEE',
#  '圈子',
#  '屁股',
#  '果酱',
#  '字幕组',
#  '不堪',
#  '想起',
#  '对不起',
#  '张紫妍',
#  '圈性',
#  '',
#  '春树',
#  '阴谋',
#  '中山大学',
#  '纽约州',
#  '摩根',
#  '最严',
#  '黄粱美梦',
#  '罪行累累',
#  '凌辱',
#  '爆尿',
#  '一身',
#  'PEKING',
#  '陪审团',
#  '麦当劳',
#  '走向',
#  '原本',
#  '种种',
#  '变态',
#  '困境',
#  '⬇',
#  '我会',
#  '忍受',
#  '分享',
#  '风起云涌',
#  '周二',
#  '倾向',
#  '厕所',
#  '增加',
#  '推动',
#  'NOTME',
#  '出面',
#  '达',
#  'HARASSMENT',
#  '投票',
#  '可惜',
#  '更大',
#  '少',
#  '所有人',
#  '期望',
#  '形容',
#  '手机',
#  '吕丽瑶',
#  '作用',
#  '独立',
#  '利益',
#  '完美',
#  'HK',
#  '',
#  '不错',
#  '判断',
#  'HOW',
#  '群众',
#  '咁',
#  '佳士',
#  '嫌疑人',
#  '内心',
#  '强',
#  '港闻',
#  '早前',
#  '个案',
#  '重视',
#  '消灭',
#  ...]

# %%
import codecs
from nltk.tokenize import word_tokenize
from collections import defaultdict

person_counter = defaultdict(int)  
person_per_line = []
relationships = {}

# %%
with open('tweets_simpleZH.csv',encoding="utf8", errors='ignore') as csvfile:
    readCSV = csv.reader(csvfile,delimiter=',')
    
    tweets = []
    for row in readCSV:
        tweets.append(row[10])
print (tweets[:10])
# Out:
# ['tweet', '应该意识到，合格的、没有 #MeToo 污点的大法官至少好几位。这个单一裁决并不能洗清他是个戏精、撒谎者、为上位无所不用其极的投机份子。 况且，最关键要看，如果需要裁定「司法部能否起诉现任总统」时，他怎么站队？#KavaNo https://twitter.com/mranti/status/1072864535814516736\xa0…', '今年九月，麦当劳员工大动作起身抗议，呼吁麦当劳不要再漠视性骚扰案件。一起看 #MeToo 运动如何从政治、演艺圈走向蓝领阶层。   https://womany.net/read/article/17372?utm_campaign=integromat&utm_medium=social&utm_source=twitter\xa0…', '「如果洁身自爱，性侵害就不会找上你」：#Metoo 一年了，世界改变了吗？  https://ift.tt/2SJ0wlY\xa0', '「要保护自己」原本是善意，怎么变成毒药了呢？看图了解更多！ 延伸阅读： 关于Only Yes means yes更多你可能忽略的事实  https://goo.gl/5fuvHc\xa0 影片：为什么我们会责怪被害者  https://goo.gl/bVwqmk\xa0 #Metoo #OnlyYesmeansyes #性侵 #我也是 pic.twitter.com/p49TMIJ31n', '2018年，东亚各国推行的种种压制性措施令人忧虑，我们看见公民社会空间日渐紧缩、律师及人权捍卫者被镇压、各国在废除死刑的问题上进展悲观。  但 #metoo 运动以及承认同性伴侣关系方面的积极迹象，让我们在迈入2019年之际仍能看到一些曙光。   http://amn.st/6016EH45C\xa0', '哦耶～夜夜夜～给我喝ㄋㄟㄋㄟ #梦魔的游记 #梦魔の纪行 #催眠疗法 #喝ㄋㄟㄋㄟ #伊藤润二 #神交 #metoo #变态医生  https://www.instagram.com/p/BrQLO56AtuH/?utm_source=ig_twitter_share&igshid=51oscmjgn7nn\xa0…', '转噗 女人迷 womany: 钮承泽事件后续的回应，可以看见媒体与社会的有罪推定、咎责被害者的言论等，这与 #MeToo 运动后续发展的瓶颈与困境，有许多相似之处，那我们接下来该如何做呢？\n\n https://womany...  https://plurk.com/p/n2yutt\xa0', '转噗 女人迷 womany: 钮承泽事件后续的回应，可以看见媒体与社会的有罪推定、咎责被害者的言论等，这与 #MeToo 运动后续发展的瓶颈与困境，有许多相似之处，那我们接下来该如何做呢？\n\n https://womany...  https://plurk.com/p/n2yutt\xa0', '钮承泽事件后续的回应，可以看见媒体与社会的有罪推定、咎责被害者的言论等，这与 #MeToo 运动后续发展的瓶颈与困境，有许多相似之处，那我们接下来该如何做呢？   https://womany.net/read/article/17352?utm_campaign=integromat&utm_medium=social&utm_source=twitter\xa0…']

# %%
import jieba
# divide the text into paragraghs
for line in tweets:
    # tokenize each paragragh
    poss = (" ".join(jieba.cut(line,cut_all=False))).split()
    # for each paragragh, we append a list in the list: person_per_line. 
    #The list will record the characters appearing in the current paragragh. 
    person_per_line.append([])
    # if a word is not a character name, then continue;
    # else, store the name in the last list in person_per_line.
    for w in poss:
        if w not in token_li:
            continue
        person_per_line[-1].append(w)
    #if the word is not in the person_counter, which means the relationship start with this name does not exist,then add the name to the relationship dictionary.
        if person_counter.get(w) is None: #Python 字典(Dictionary) get() 函数返回指定键的值，如果值不在字典中返回默认值None
            relationships[w] = {}
    # else, the key of person_counter[w] + 1
        person_counter[w] +=1
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/1c/sjx2kd7523d2thgdgkplrhf80000gn/T/jieba.cache
# Loading model cost 1.060 seconds.
# Prefix dict has been built succesfully.

# %%
print ("start to process edges")
#遍历每一段，笛卡尔积形式统计人物关系
# p is a list in person_per_line, if name1 and name 2 both in p, and name1 != name2, then add a relationship to the dictionary. 
for p in person_per_line:
    for name1 in p:
        for name2 in p:
            if name1 == name2:
                continue
            if relationships[name1].get(name2) is None:
                relationships[name1][name2] = 1
            else:
                relationships[name1][name2] +=1
# Out:
# start to process edges

# %%
# for nodes.csv, name in person_counter is Id and Label, and the frequency of each character is Weight.
with codecs.open("node.csv","a+","utf-8") as f:
    f.write("Id,Label,Weight\r\n")
    for name, times in person_counter.items():
        f.write(name+","+name+","+str(times)+"\r\n")
# for edge.csv, name in relationships{} is         
with codecs.open("edge.csv","a+","utf-8") as f:
    f.write("Source,Target,Weight\r\n")
    # name is the key(Source), and edges is the value of name. edges is also a dictionary, which stores the target names and the weight of each target.
    for name, edges in relationships.items():
        # v is the target name, w is the weight.
        for v,w in edges.items():
            #
            if w >3:
                f.write(name+","+ v + "," + str(w) + "\r\n")
